# %% [markdown]
# # Project 02 - Due Friday, November 11 at 12pm
#
# *Objectives*: Gain experience loading a transactional dataset into a relational database model you define yourself and using SQL to explore its contents. Transform the data into a star schema, documenting the schema visually, and explore the transformed data analytically by writing and executing a number of SQL queries using common syntax and functions and describing your findings.  Gain practice working on these tasks with a partner.
#
# *Grading criteria*: The tasks should all be completed, and questions should all be answered with SQL queries, diagrams, and charts in the space provided, unless a text answer is requested.  The notebook itself should be completely reproducible at datanotebook.org, from start to finish: another person should be able to use the same code to obtain the same results as yours.  Note that you will receive no more than partial credit if you do not add text/markdown cells explaining your thinking at each major step in each problem.
#
# *Attestation*: **Work in pairs**.  At the end of your submitted notebook, identify the work each partner performed and attest that each contributed substantially to the work.
#
# *Deadline*: Friday, November 11, 12pm.  One member of each pair must submit your notebook to Blackboard; you should not both submit it separately.  You may each push a copy to your own GitHub repository.
#
#
# ## Setup - select and obtain data
#
# The US City Open Data Census has a variety of [transactional data from all over the country](http://us-city.census.okfn.org/).  Select one topic and one city from this Census, download the data, and explain your reason for this choice before proceeding.  Provide a link to the web page for the data set you've chosen.
#
# I strongly encourage you to select a dataset from among the following topics:  Crime, Property Assessment, Campaign Finance Contributions, Service Requests (311), and Web Analytics.
#
# By *transactional* data I mean records at the grain of one event per business process.  In the case of Service Requests (311), for example, that would require data at the level of each individual report of a service request.  If this isn't clear, think about the bike trip data - each individual ride was included - and look for data at that level of event/process specificity.  Avoid data like the Connecticut boating data, which was summarized by year, not individual transactions.
#
# Please aim for a dataset of at least 10,000 individual records, but less than 250,000 records.  A little more or a little less is okay, but try to stay within these limits.

# %% [markdown]
# ---------------------------------------------------------------------
# We selected the Baltimore Crime dataset which provides data on incidences of crime recorded in Baltimore. The dataset contains records with detail on the type of crime, the weapon used, and several ways for categorizing the location (including district, neighborhood, and geographical coordinates.)

# %%
# !wget https://data.baltimorecity.gov/api/views/wsfq-mvij/rows.csv
# Out:
# --2016-11-09 01:35:27--  https://data.baltimorecity.gov/api/views/wsfq-mvij/rows.csv
# Resolving data.baltimorecity.gov (data.baltimorecity.gov)... 52.206.68.26
# Connecting to data.baltimorecity.gov (data.baltimorecity.gov)|52.206.68.26|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/csv]
# Saving to: ‘rows.csv’
#
# rows.csv                [   <=>                ]  32.92M  67.7MB/s   in 0.5s
#
# Last-modified header invalid -- time-stamp ignored.
# 2016-11-09 01:35:28 (67.7 MB/s) - ‘rows.csv’ saved [34515653]

# %% [markdown]
# ## Problem 1 - examine the data (20 points)
#
# Use `csvstat`, `pandas`, or other tools as you see fit and observe the contents of your dataset.  Review important points from any metadata provided.  Describe what you see:  What do the columns mean?  Are there null values?  Which columns interest you the most?  Which columns present some opportunities, challenges, or questions you would like to ask?

# %% [markdown]
# ------------------------------------------
# To begin, we wanted to see the size of the dataset, as this would guide our approach to navigating the data. At 283,615 rows, it is a fairly large dataset. At first, we attempted to work with the full dataset but due to slow processing times for our operations, we ultimately decided to do our final analysis on only 2016 data.

# %%
# !wc -l rows.csv
# Out:
# 283615 rows.csv

# %% [markdown]
# We used csvstat to learn more about the columns in the dataset. Due to the size of the dataset, we limited csvstat to a random sample of 10,000 rows. We noted that only the location-focused columns seem to have null values [Location, Inside/Outside, District, Neighborhood, and Location_1 (geographic coordinates)].

# %%
# !shuf -n 10000 rows.csv | csvstat
# Out:
#   1. 05/18/2013
# 	<class 'datetime.date'>
# 	Nulls: False
# 	Min: 2011-01-01
# 	Max: 2016-10-28
# 	Unique values: 2104
# 	5 most frequent values:
# 		2015-04-27:	23
# 		2011-10-08:	15
# 		2011-09-03:	14
# 		2011-05-13:	14
# 		2012-04-18:	13
#   2. 21:00:00
# 	<class 'str'>
# 	Nulls: False
# 	Unique values: 1263
# 	5 most frequent values:
# 		17:00:00:	243
# 		20:00:00:	243
# 		18:00:00:	241
# 		16:00:00:	235
# 		19:00:00:	231
# 	Max length: 8
#   3. 4E
# 	<class 'str'>
# 	Nulls: False
# 	Unique values: 69
# 	5 most frequent values:
# 		4E:	1723
# 		6D:	1424
# 		5A:	937
# 		7A:	860
# 		6G:	563
# 	Max length: 4
#   4. 100 WATER ST
# 	<class 'str'>
# 	Nulls: True
# 	Unique values: 6194
# 	5 most frequent values:
# 		200 E PRATT ST:	25
# 		3200 TIOGA PW:	24
# 		300 LIGHT ST:	21
# 		6300 EASTERN AV:	18
# 		1500 RUSSELL ST:	17
# 	Max length: 32
#   5. COMMON ASSAULT
# 	<class 'str'>
# 	Nulls: False
# 	Unique values: 15
# 	5 most frequent values:
# 		LARCENY:	2145
# 		COMMON ASSAULT:	1723
# 		BURGLARY:	1540
# 		LARCENY FROM AUTO:	1424
# 		AGG. ASSAULT:	1005
# 	Max length: 20
#   6. O
# 	<class 'str'>
# 	Nulls: True
# 	Values: Inside, Outside, I, O
#   7. HANDS
# 	<class 'str'>
# 	Nulls: True
# 	Values: FIREARM, OTHER, HANDS, KNIFE
#   8. 111
# 	<class 'int'>
# 	Nulls: True
# 	Min: 111
# 	Max: 944
# 	Sum: 5039916
# 	Mean: 504.3446412488742
# 	Median: 445
# 	Standard Deviation: 261.0723636291098
# 	Unique values: 139
# 	5 most frequent values:
# 		111:	352
# 		212:	188
# 		731:	173
# 		922:	164
# 		913:	152
#   9. CENTRAL
# 	<class 'str'>
# 	Nulls: True
# 	Unique values: 10
# 	5 most frequent values:
# 		NORTHEASTERN:	1557
# 		SOUTHEASTERN:	1371
# 		CENTRAL:	1202
# 		SOUTHERN:	1112
# 		NORTHERN:	1100
# 	Max length: 12
#  10. Downtown
# 	<class 'str'>
# 	Nulls: True
# 	Unique values: 273
# 	5 most frequent values:
# 		Downtown:	349
# 		Frankford:	229
# 		Belair-Edison:	194
# 		Mondawmin:	157
# 		Brooklyn:	155
# 	Max length: 33
#  11. (39.2883700000, -76.6128700000)
# 	<class 'str'>
# 	Nulls: True
# 	Unique values: 8162
# 	5 most frequent values:
# 		(39.3180000000, -76.6582100000):	32
# 		(39.3186800000, -76.6539900000):	23
# 		(39.2876100000, -76.5398200000):	17
# 		(39.2850000000, -76.6130900000):	17
# 		(39.2606200000, -76.6088600000):	16
# 	Max length: 31
#  12. 1
# 	<class 'int'>
# 	Nulls: False
# 	Values: 1
#
# Row count: 9999

# %%
# !csvcut -n rows.csv
# Out:
#   1: CrimeDate
#   2: CrimeTime
#   3: CrimeCode
#   4: Location
#   5: Description
#   6: Inside/Outside
#   7: Weapon
#   8: Post
#   9: District
#  10: Neighborhood
#  11: Location 1
#  12: Total Incidents

# %% [markdown]
# ## Problem 2 - define a database model, load the data, and explore (20 points)
#
# Based on what you found above, create and connect to a new database, define a database table in it, and load this dataset into it.  You may use either of the methods for this step you have seen in earlier class notebooks.  You may choose to eliminate variables/columns if they are not relevant or interesting to you - explain your reasoning if you do.  Either way, you should load a majority of the columns present in the source dataset as it is in its raw form into the database, and all of its rows.
#
# Once your data has loaded successfully, run a `COUNT(*)` query to verify that all the data has loaded correctly.
#
# Explore the data to zero in on a few themes you would like to further study analytically.  Discuss columns that present opportunities for extraction into dimensions, and identify the specific columns that contain facts you want to measure.

# %%
# %load_ext sql
# !echo 'redspot' | sudo -S service postgresql restart
# !createdb -U dbuser BaltimoreCrime
# %sql postgresql://dbuser@localhost:5432/BaltimoreCrime
# Out:
# /opt/conda/lib/python3.5/site-packages/IPython/config.py:13: ShimWarning: The `IPython.config` package has been deprecated. You should import from traitlets.config instead.
#   "You should import from traitlets.config instead.", ShimWarning)
# /opt/conda/lib/python3.5/site-packages/IPython/utils/traitlets.py:5: UserWarning: IPython.utils.traitlets has moved to a top-level traitlets package.
#   warn("IPython.utils.traitlets has moved to a top-level traitlets package.")
# [sudo] password for jovyan: Restarting PostgreSQL 9.5 database server: main.
# 'Connected: dbuser@BaltimoreCrime'

# %%
# %%sql
# DROP TABLE IF EXISTS BaltimoreCrime;
# CREATE TABLE BaltimoreCrime (
#     CrimeDate TIMESTAMP,
#     CrimeTime VARCHAR(64),
#     CrimeCode VARCHAR(64),
#     Location VARCHAR(64),
#     Description VARCHAR(64),
#     Inside_Outside VARCHAR(64),
#     Weapon VARCHAR(64),
#     Post INTEGER,
#     District VARCHAR(64),
#     Neighborhood VARCHAR(64),
#     Location_1 VARCHAR(64),
#     Total_Incidents INTEGER
# )
# Out:
# Done.
# Done.
# []

# %%
# %%sql
# COPY BaltimoreCrime FROM '/home/jovyan/work/rows.csv'
# CSV
# HEADER
# QUOTE '"'
# DELIMITER ',';
# Out:
# 283614 rows affected.
# []

# %% [markdown]
# We used COUNT() to verify that the data was all loaded into the table.

# %%
# %%sql
# SELECT COUNT(*) FROM BaltimoreCrime;
# Out:
# 1 rows affected.
# [(283614,)]

# %% [markdown]
# We checked the first five rows to see that the data formats carried over properly.

# %%
# %%sql
# SELECT *
# FROM BaltimoreCrime
# LIMIT 5;
# Out:
# 5 rows affected.
# [(datetime.datetime(2016, 10, 29, 0, 0), '00:01:00', '6E', '4700 FURLEY AVE', 'LARCENY', 'O', None, 443, 'NORTHEASTERN', 'Frankford', '(39.3285900000, -76.5517800000)', 1),
#  (datetime.datetime(2016, 10, 29, 0, 0), '00:01:00', '7A', '3500 LIBERTY HEIGHTS AVE', 'AUTO THEFT', 'O', None, 642, 'NORTHWESTERN', 'Forest Park', '(39.3250400000, -76.6748500000)', 1),
#  (datetime.datetime(2016, 10, 29, 0, 0), '00:58:00', '6C', '0 LIGHT ST', 'LARCENY', 'I', None, 111, 'CENTRAL', 'Downtown', '(39.2884300000, -76.6137200000)', 1),
#  (datetime.datetime(2016, 10, 29, 0, 0), '01:00:00', '6D', '2200 BERLIN ST', 'LARCENY FROM AUTO', 'O', None, 921, 'SOUTHERN', 'Saint Paul', '(39.2695600000, -76.6447300000)', 1),
#  (datetime.datetime(2016, 10, 29, 0, 0), '01:00:00', '7A', '2800 E FEDERAL ST', 'AUTO THEFT', 'O', None, 332, 'EASTERN', 'Berea', '(39.3091700000, -76.5780900000)', 1)]

# %% [markdown]
# To make the data easier to explore, we separated the data column into year, month, and day. We also added a unique id called incident_id.

# %%
# %%sql
# ALTER TABLE BaltimoreCrime
# ADD COLUMN incident_id SERIAL;
# Out:
# Done.
# []

# %%
# %%sql
# ALTER TABLE BaltimoreCrime
# ADD COLUMN year NUMERIC;
# Out:
# Done.
# []

# %%
# %%sql
# ALTER TABLE BaltimoreCrime
# ADD COLUMN month NUMERIC;
# Out:
# Done.
# []

# %%
# %%sql
# ALTER TABLE BaltimoreCrime
# ADD COLUMN day NUMERIC;
# Out:
# Done.
# []

# %%
# %%sql
# UPDATE BaltimoreCrime
# SET year = EXTRACT(YEAR FROM crimedate),
#     month = EXTRACT(MONTH FROM crimedate),
#     day = EXTRACT(DAY FROM crimedate);
# Out:
# 283614 rows affected.
# []

# %% [markdown]
# The following cell lets us test that the year, month, and day columns were created and filled correctly.

# %%
# %%sql
# SELECT *
# FROM BaltimoreCrime
# LIMIT 5;
# Out:
# 5 rows affected.
# [(datetime.datetime(2016, 10, 29, 0, 0), '15:00:00', '7A', None, 'AUTO THEFT', 'O', None, 532, 'NORTHERN', None, None, 1, 39, Decimal('2016'), Decimal('10'), Decimal('29')),
#  (datetime.datetime(2016, 10, 22, 0, 0), '18:30:00', '4E', None, 'COMMON ASSAULT', 'O', 'HANDS', 143, 'CENTRAL', None, None, 1, 954, Decimal('2016'), Decimal('10'), Decimal('22')),
#  (datetime.datetime(2016, 10, 17, 0, 0), '17:56:00', '6D', None, 'LARCENY FROM AUTO', 'I', None, 514, 'NORTHERN', None, None, 1, 1719, Decimal('2016'), Decimal('10'), Decimal('17')),
#  (datetime.datetime(2015, 5, 25, 0, 0), '15:00:00', '4D', None, 'AGG. ASSAULT', 'I', 'HANDS', 924, 'SOUTHERN', None, None, 1, 2038, Decimal('2015'), Decimal('5'), Decimal('25')),
#  (datetime.datetime(2016, 10, 2, 0, 0), '11:20:00', '6J', None, 'LARCENY', 'I', None, 243, 'SOUTHEASTERN', None, None, 1, 3834, Decimal('2016'), Decimal('10'), Decimal('2'))]

# %% [markdown]
# By sampling the data in our database, and by reviewing the results provided by csvstat, we see some clear relationships between the columns that can form the basis for our facts and dimensions. Some interesting subjects for analysis may be the relationships between locations, details of the crime, and the time/date. This breakdown is a good basis for the dimension tables in the star schema that we will define. To link these three dimensions to specific incidents, it makes sense to create a fact table using a unique identifier for incidents and connecting this to our three dimensions using keys.

# %% [markdown]
# ## Problem 3 - define a star schema, and load your data into it (30 points)
#
# Define a star schema consisting of at least one fact table and at least two dimensions.  Transform your source data into the new fact table and dimensions.  Discuss your key modeling decisions.
#
# Document your star schema with a diagram.  There several tools available for this, such as Google Docs and Microsoft Visio.

# %% [markdown]
# For purposes of this exercise, we will limit data in the star schema to year 2016 so as to minimize data processing time. Due to null values in specific fields, coalesce function is used which will allow for join needed to create the dimension keys to execute properly in subsequent step.

# %%
# %%sql
# DROP TABLE IF EXISTS BaltimoreCrime2016;
# CREATE TABLE BaltimoreCrime2016 as (
# SELECT
#     crimedate
#     , crimetime
#     , coalesce(crimecode, 'n/a') as crimecode
#     , coalesce(location, 'n/a') as location
#     , coalesce(description, 'n/a') as description
#     , coalesce(inside_outside, 'n/a') as inside_outside
#     , coalesce(weapon, 'n/a') as weapon
#     , coalesce(post, 0) as post
#     , coalesce(district, 'n/a') as district
#     , coalesce(neighborhood, 'n/a') as neighborhood
#     , coalesce(location_1, 'n/a') as location_1
#     , total_incidents
#     , incident_id
#     , year
#     , month
#     , day
# FROM BaltimoreCrime
# WHERE year = '2016'
# );
# Out:
# Done.
# 39100 rows affected.
# []

# %% [markdown]
# **Step 1: Create date_time dimension table** <br> This table will contain fields: crimedate, crimetime, year, month, and day.

# %%
# %%sql
# DROP TABLE IF EXISTS dim_date_time;
# CREATE TABLE dim_date_time as (
# SELECT distinct
#     crimedate
#     , crimetime
#     , year
#     , month
#     , day
# FROM BaltimoreCrime2016
# ORDER BY 1, 2
# );
# Out:
# Done.
# 26110 rows affected.
# []

# %%
# %%sql
# ALTER TABLE dim_date_time
# ADD COLUMN date_time_key SERIAL;
# Out:
# Done.
# []

# %% [markdown]
# Review sample of records to confirm dimension table was created correctly.

# %%
# %%sql
# SELECT *
# FROM dim_date_time
# ORDER BY 1, 2
# LIMIT 10;
# Out:
# 10 rows affected.
# [(datetime.datetime(2016, 1, 1, 0, 0), '00:42:00', Decimal('2016'), Decimal('1'), Decimal('1'), 1),
#  (datetime.datetime(2016, 1, 1, 0, 0), '00:50:00', Decimal('2016'), Decimal('1'), Decimal('1'), 2),
#  (datetime.datetime(2016, 1, 1, 0, 0), '01:00:00', Decimal('2016'), Decimal('1'), Decimal('1'), 3),
#  (datetime.datetime(2016, 1, 1, 0, 0), '01:01:00', Decimal('2016'), Decimal('1'), Decimal('1'), 4),
#  (datetime.datetime(2016, 1, 1, 0, 0), '01:13:00', Decimal('2016'), Decimal('1'), Decimal('1'), 5),
#  (datetime.datetime(2016, 1, 1, 0, 0), '01:30:00', Decimal('2016'), Decimal('1'), Decimal('1'), 6),
#  (datetime.datetime(2016, 1, 1, 0, 0), '01:55:00', Decimal('2016'), Decimal('1'), Decimal('1'), 7),
#  (datetime.datetime(2016, 1, 1, 0, 0), '02:00:00', Decimal('2016'), Decimal('1'), Decimal('1'), 8),
#  (datetime.datetime(2016, 1, 1, 0, 0), '02:13:00', Decimal('2016'), Decimal('1'), Decimal('1'), 9),
#  (datetime.datetime(2016, 1, 1, 0, 0), '02:24:00', Decimal('2016'), Decimal('1'), Decimal('1'), 10)]

# %% [markdown]
# **Step 2: Create crime_details dimension table** <br> This table will contain fields: crimecode, description, inside_outside, and weapon.

# %%
# %%sql
# DROP TABLE IF EXISTS dim_crime_details;
# CREATE TABLE dim_crime_details as (
# SELECT distinct
#     crimecode
#     , description
#     , inside_outside
#     , weapon
# FROM BaltimoreCrime2016
# ORDER BY 1, 2, 3, 4
# );
# Out:
# Done.
# 165 rows affected.
# []

# %%
# %%sql
# ALTER TABLE dim_crime_details
# ADD COLUMN crime_details_key SERIAL;
# Out:
# Done.
# []

# %% [markdown]
# Review sample of records to confirm dimension table was created correctly.

# %%
# %%sql
# SELECT *
# FROM dim_crime_details
# ORDER BY 1, 2, 3, 4
# LIMIT 10;
# Out:
# 10 rows affected.
# [('1F', 'HOMICIDE', 'Inside', 'FIREARM', 1),
#  ('1F', 'HOMICIDE', 'Outside', 'FIREARM', 2),
#  ('1K', 'HOMICIDE', 'Inside', 'KNIFE', 3),
#  ('1K', 'HOMICIDE', 'Outside', 'KNIFE', 4),
#  ('1O', 'HOMICIDE', 'Inside', 'OTHER', 5),
#  ('1O', 'HOMICIDE', 'Outside', 'OTHER', 6),
#  ('2A', 'RAPE', 'I', 'OTHER', 7),
#  ('2A', 'RAPE', 'O', 'OTHER', 8),
#  ('2A', 'RAPE', 'n/a', 'OTHER', 9),
#  ('2B', 'RAPE', 'I', 'n/a', 10)]

# %% [markdown]
# **Step 3: Create location_details dimension table** <br> This table will contain fields: location, post, district, neighborhood, and lat_long (coordinates).

# %%
# %%sql
# DROP TABLE IF EXISTS dim_location_details;
# CREATE TABLE dim_location_details as (
# SELECT distinct
#     location
#     , post
#     , district
#     , neighborhood
#     , location_1 as lat_long
#     , substring(location_1, 2, 6) as lat
#     , substring(location_1, 17, 7) as long
# FROM BaltimoreCrime2016
# ORDER BY 1, 2, 3, 4, 5
# )
# ;
# Out:
# Done.
# 24624 rows affected.
# []

# %%
# %%sql
# ALTER TABLE dim_location_details
# ADD COLUMN location_details_key SERIAL;
# Out:
# Done.
# []

# %% [markdown]
# Review sample of records to confirm dimension table was created correctly.

# %%
# %%sql
# SELECT *
# FROM dim_location_details
# LIMIT 10;
# Out:
# 10 rows affected.
# [('0 AISQUITH ST', 211, 'SOUTHEASTERN', 'Jonestown', '(39.2910600000, -76.6012700000)', '39.291', '-76.601', 1),
#  ('0 ALBEMARLE ST', 211, 'SOUTHEASTERN', 'Jonestown', '(39.2890900000, -76.6042200000)', '39.289', '-76.604', 2),
#  ('0 ANDREW PL', 941, 'SOUTHERN', 'Otterbein', '(39.2832200000, -76.6152000000)', '39.283', '-76.615', 3),
#  ('0 ART MUSEUM DR', 511, 'NORTHERN', 'Johns Hopkins Homewood', '(39.3250500000, -76.6194500000)', '39.325', '-76.619', 4),
#  ('0 ASHBURTON ST', 721, 'WESTERN', 'Mosher', '(39.2954300000, -76.6614300000)', '39.295', '-76.661', 5),
#  ('0 BELLEMORE RD', 521, 'NORTHERN', 'The Orchards', '(39.3677800000, -76.6271500000)', '39.367', '-76.627', 6),
#  ('0 BENKERT AVE', 842, 'SOUTHWESTERN', 'Saint Josephs', '(39.2852500000, -76.6744000000)', '39.285', '-76.674', 7),
#  ('0 BENKERT AVE', 842, 'SOUTHWESTERN', 'Saint Josephs', '(39.2853400000, -76.6743000000)', '39.285', '-76.674', 8),
#  ('0 BENKERT AVE', 842, 'SOUTHWESTERN', 'Saint Josephs', '(39.2857500000, -76.6738700000)', '39.285', '-76.673', 9),
#  ('0 BENKERT AVE', 842, 'SOUTHWESTERN', 'Saint Josephs', '(39.2859300000, -76.6736300000)', '39.285', '-76.673', 10)]

# %% [markdown]
# **Step 4: Create incident fact table** <br> This table will contain fields: incident_id (primary key), date_time_key, crime_details_key, location_details_key.

# %% [markdown]
# Add dimension key fields to new fact table.

# %%
# %%sql
# DROP TABLE IF EXISTS fact_incidents_2016;
# CREATE TABLE fact_incidents_2016 as (
# SELECT a.*
#     , b.date_time_key as date_time_key
#     , c.crime_details_key as crime_details_key
#     , d.location_details_key as location_details_key
# FROM BaltimoreCrime2016 a
# LEFT JOIN dim_date_time b ON
#     a.crimedate = b.crimedate
#     AND a.crimetime = b.crimetime
#     AND a.year = b.year
#     AND a.month = b.month
#     AND a.day = b.day
# LEFT JOIN dim_crime_details c ON
#     a.crimecode = c.crimecode
#     AND a.description = c.description
#     AND a.inside_outside = c.inside_outside
#     AND a.weapon = c.weapon
# LEFT JOIN dim_location_details d ON
#     a.location = d.location
#     AND a.post = d.post
#     AND a.district = d.district
#     AND a.neighborhood = d.neighborhood
#     AND a.location_1 = d.lat_long
# )
# ;
# Out:
# Done.
# 39100 rows affected.
# []

# %% [markdown]
# Spotcheck a sample of records.

# %%
# %%sql
# SELECT *
# FROM fact_incidents_2016
# LIMIT 5;
# Out:
# 5 rows affected.
# [(datetime.datetime(2016, 4, 27, 0, 0), '16:40:00', '4A', '0 AISQUITH ST', 'AGG. ASSAULT', 'O', 'FIREARM', 211, 'SOUTHEASTERN', 'Jonestown', '(39.2910600000, -76.6012700000)', 1, 25804, Decimal('2016'), Decimal('4'), Decimal('27'), 9206, 76, 1),
#  (datetime.datetime(2016, 6, 12, 0, 0), '11:21:00', '6J', '0 ALBEMARLE ST', 'LARCENY', 'I', 'n/a', 211, 'SOUTHEASTERN', 'Jonestown', '(39.2890900000, -76.6042200000)', 1, 19379, Decimal('2016'), Decimal('6'), Decimal('12'), 13333, 130, 2),
#  (datetime.datetime(2016, 6, 12, 0, 0), '11:21:00', '6J', '0 ALBEMARLE ST', 'LARCENY', 'I', 'n/a', 211, 'SOUTHEASTERN', 'Jonestown', '(39.2890900000, -76.6042200000)', 1, 19377, Decimal('2016'), Decimal('6'), Decimal('12'), 13333, 130, 2),
#  (datetime.datetime(2016, 6, 12, 0, 0), '11:21:00', '6J', '0 ALBEMARLE ST', 'LARCENY', 'I', 'n/a', 211, 'SOUTHEASTERN', 'Jonestown', '(39.2890900000, -76.6042200000)', 1, 19378, Decimal('2016'), Decimal('6'), Decimal('12'), 13333, 130, 2),
#  (datetime.datetime(2016, 10, 19, 0, 0), '10:00:00', '6J', '0 ANDREW PL', 'LARCENY', 'I', 'n/a', 941, 'SOUTHERN', 'Otterbein', '(39.2832200000, -76.6152000000)', 1, 1353, Decimal('2016'), Decimal('10'), Decimal('19'), 25180, 130, 3)]

# %% [markdown]
# Confirm that there are no missing values in dimension key fields

# %%
# %%sql
# SELECT *
# FROM fact_incidents_2016
# WHERE date_time_key is null
# ;
# Out:
# 0 rows affected.
# []

# %%
# %%sql
# SELECT *
# FROM fact_incidents_2016
# WHERE crime_details_key is null
# ;
# Out:
# 0 rows affected.
# []

# %%
# %%sql
# SELECT *
# FROM fact_incidents_2016
# WHERE location_details_key is null
# ;
# Out:
# 0 rows affected.
# []

# %% [markdown]
# Drop columns that are no longer needed in fact_incidents_2016 table.

# %%
# %%sql
# ALTER TABLE fact_incidents_2016
# DROP COLUMN crimedate;
#
# ALTER TABLE fact_incidents_2016
# DROP COLUMN crimetime;
#
# ALTER TABLE fact_incidents_2016
# DROP COLUMN crimecode;
#
# ALTER TABLE fact_incidents_2016
# DROP COLUMN location;
#
# ALTER TABLE fact_incidents_2016
# DROP COLUMN description;
#
# ALTER TABLE fact_incidents_2016
# DROP COLUMN inside_outside;
#
# ALTER TABLE fact_incidents_2016
# DROP COLUMN weapon;
#
# ALTER TABLE fact_incidents_2016
# DROP COLUMN post;
#
# ALTER TABLE fact_incidents_2016
# DROP COLUMN district;
#
# ALTER TABLE fact_incidents_2016
# DROP COLUMN neighborhood;
#
# ALTER TABLE fact_incidents_2016
# DROP COLUMN location_1;
#
# ALTER TABLE fact_incidents_2016
# DROP COLUMN year;
#
# ALTER TABLE fact_incidents_2016
# DROP COLUMN month;
#
# ALTER TABLE fact_incidents_2016
# DROP COLUMN day;
# Out:
# Done.
# Done.
# Done.
# Done.
# Done.
# Done.
# Done.
# Done.
# Done.
# Done.
# Done.
# Done.
# Done.
# Done.
# []

# %% [markdown]
# Verify updated fact table no longer has removed fields.

# %%
# %%sql
# SELECT *
# FROM fact_incidents_2016
# LIMIT 5;
# Out:
# 5 rows affected.
# [(1, 25804, 9206, 76, 1),
#  (1, 19379, 13333, 130, 2),
#  (1, 19377, 13333, 130, 2),
#  (1, 19378, 13333, 130, 2),
#  (1, 1353, 25180, 130, 3)]

# %% [markdown]
# Verify that results match from original data compared to star schema for incident_id 38975.

# %%
# %%sql
# SELECT *
# FROM BaltimoreCrime2016
# WHERE incident_id = '38975';
# Out:
# 1 rows affected.
# [(datetime.datetime(2016, 1, 1, 0, 0), '00:42:00', '3AF', '6900 HARFORD RD', 'ROBBERY - STREET', 'O', 'FIREARM', 424, 'NORTHEASTERN', 'North Harford Road', '(39.3661600000, -76.5495000000)', 1, 38975, Decimal('2016'), Decimal('1'), Decimal('1'))]

# %%
# %%sql
# SELECT
#     b.crimedate
#     , b.crimetime
#     , c.crimecode
#     , d.location
#     , c.description
#     , c.inside_outside
#     , c.weapon
#     , d.post
#     , d.district
#     , d.neighborhood
#     , d.lat_long
#     , a.total_incidents
#     , a.incident_id
#     , b.year
#     , b.month
#     , b.day
# FROM fact_incidents_2016 a
# JOIN dim_date_time b ON
#     a.date_time_key = b.date_time_key
# JOIN dim_crime_details c ON
#     a.crime_details_key = c.crime_details_key
# JOIN dim_location_details d ON
#     a.location_details_key = d.location_details_key
# WHERE a.incident_id = '38975';
# Out:
# 1 rows affected.
# [(datetime.datetime(2016, 1, 1, 0, 0), '00:42:00', '3AF', '6900 HARFORD RD', 'ROBBERY - STREET', 'O', 'FIREARM', 424, 'NORTHEASTERN', 'North Harford Road', '(39.3661600000, -76.5495000000)', 1, 38975, Decimal('2016'), Decimal('1'), Decimal('1'))]

# %% [markdown]
# ## Problem 4 - explore your data in its new schema (30 points)
#
# Strictly using the dimensional model tables you defined and populated for Problem 3, explore your data in its new form.  Use any of the query strategies we've seen in class, including transformations, aggregates, subqueries, rollups, and, of course, joins.  Add plots to highlight particular themes that stand out.  Describe your thinking and observations along the way.

# %% [markdown]
# To begin, we checked to see how the incidence of crime changes over time.

# %%
# %%sql
# SELECT
#     b.month,
#     COUNT(c.description)
# FROM fact_incidents_2016 a
# JOIN dim_date_time b ON
#     a.date_time_key = b.date_time_key
# JOIN dim_crime_details c ON
#     a.crime_details_key = c.crime_details_key
# JOIN dim_location_details d ON
#     a.location_details_key = d.location_details_key
# GROUP BY month
# ORDER BY month
# Out:
# 10 rows affected.
# [(Decimal('1'), 3382),
#  (Decimal('2'), 2873),
#  (Decimal('3'), 3617),
#  (Decimal('4'), 3847),
#  (Decimal('5'), 4219),
#  (Decimal('6'), 4407),
#  (Decimal('7'), 4082),
#  (Decimal('8'), 4218),
#  (Decimal('9'), 4407),
#  (Decimal('10'), 4048)]

# %%
# %matplotlib inline
result = _
result.bar()
# Out:
# /opt/conda/lib/python3.5/site-packages/matplotlib/font_manager.py:273: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   warnings.warn('Matplotlib is building the font cache using fc-list. This may take a moment.')
# /opt/conda/lib/python3.5/site-packages/matplotlib/font_manager.py:273: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   warnings.warn('Matplotlib is building the font cache using fc-list. This may take a moment.')
# <Container object of 10 artists>

# %% [markdown]
# Next, we looked at one of the months with a higher incidence of crime: June.

# %%
# %%sql
# SELECT
#     b.month,
#     b.day,
#     COUNT(c.description)
# FROM fact_incidents_2016 a
# JOIN dim_date_time b ON
#     a.date_time_key = b.date_time_key
# JOIN dim_crime_details c ON
#     a.crime_details_key = c.crime_details_key
# JOIN dim_location_details d ON
#     a.location_details_key = d.location_details_key
# WHERE month = 6
# GROUP BY month, day
# ORDER BY month, day
# Out:
# 30 rows affected.
# [(Decimal('6'), Decimal('1'), 129),
#  (Decimal('6'), Decimal('2'), 132),
#  (Decimal('6'), Decimal('3'), 137),
#  (Decimal('6'), Decimal('4'), 156),
#  (Decimal('6'), Decimal('5'), 254),
#  (Decimal('6'), Decimal('6'), 174),
#  (Decimal('6'), Decimal('7'), 130),
#  (Decimal('6'), Decimal('8'), 157),
#  (Decimal('6'), Decimal('9'), 138),
#  (Decimal('6'), Decimal('10'), 166),
#  (Decimal('6'), Decimal('11'), 149),
#  (Decimal('6'), Decimal('12'), 127),
#  (Decimal('6'), Decimal('13'), 171),
#  (Decimal('6'), Decimal('14'), 130),
#  (Decimal('6'), Decimal('15'), 160),
#  (Decimal('6'), Decimal('16'), 126),
#  (Decimal('6'), Decimal('17'), 131),
#  (Decimal('6'), Decimal('18'), 137),
#  (Decimal('6'), Decimal('19'), 143),
#  (Decimal('6'), Decimal('20'), 185),
#  (Decimal('6'), Decimal('21'), 138),
#  (Decimal('6'), Decimal('22'), 150),
#  (Decimal('6'), Decimal('23'), 160),
#  (Decimal('6'), Decimal('24'), 132),
#  (Decimal('6'), Decimal('25'), 152),
#  (Decimal('6'), Decimal('26'), 129),
#  (Decimal('6'), Decimal('27'), 121),
#  (Decimal('6'), Decimal('28'), 135),
#  (Decimal('6'), Decimal('29'), 146),
#  (Decimal('6'), Decimal('30'), 112)]

# %%
# %matplotlib inline
result = _
result.bar()
# Out:
# <Container object of 30 artists>

# %% [markdown]
# This highlights June 5th as a day with a particularly high amount of crime. The next chart shows the crime breakdown on this day by the type of crime.

# %%
# %%sql
# SELECT
#     c.description,
#     count(c.description)
# FROM fact_incidents_2016 a
# JOIN dim_date_time b ON
#     a.date_time_key = b.date_time_key
# JOIN dim_crime_details c ON
#     a.crime_details_key = c.crime_details_key
# JOIN dim_location_details d ON
#     a.location_details_key = d.location_details_key
# WHERE month = 6 and day = 5
# GROUP BY description
# Out:
# 13 rows affected.
# [('AGG. ASSAULT', 12),
#  ('RAPE', 1),
#  ('ASSAULT BY THREAT', 1),
#  ('SHOOTING', 2),
#  ('AUTO THEFT', 14),
#  ('BURGLARY', 145),
#  ('LARCENY FROM AUTO', 20),
#  ('ROBBERY - STREET', 9),
#  ('COMMON ASSAULT', 26),
#  ('ARSON', 2),
#  ('ROBBERY - RESIDENCE', 1),
#  ('ROBBERY - COMMERCIAL', 2),
#  ('LARCENY', 19)]

# %%
# %matplotlib inline
result = _
result.bar()
# Out:
# <Container object of 13 artists>

# %% [markdown]
# It seems that an extremely high incidence of burgularies were reported on that day. We wanted to compare this to the typical amount of burglaries compared to other types of crime to see if this is truly an anomaly.

# %%
# %%sql
# SELECT
#     b.month,
#     b.day,
#     c.description,
#     count(c.description)
# FROM fact_incidents_2016 a
# JOIN dim_date_time b ON
#     a.date_time_key = b.date_time_key
# JOIN dim_crime_details c ON
#     a.crime_details_key = c.crime_details_key
# JOIN dim_location_details d ON
#     a.location_details_key = d.location_details_key
# WHERE month = 6
# GROUP BY description, month, day
# ORDER BY description, month, day
# Out:
# 378 rows affected.
# [(Decimal('6'), Decimal('1'), 'AGG. ASSAULT', 13),
#  (Decimal('6'), Decimal('2'), 'AGG. ASSAULT', 16),
#  (Decimal('6'), Decimal('3'), 'AGG. ASSAULT', 11),
#  (Decimal('6'), Decimal('4'), 'AGG. ASSAULT', 18),
#  (Decimal('6'), Decimal('5'), 'AGG. ASSAULT', 12),
#  (Decimal('6'), Decimal('6'), 'AGG. ASSAULT', 14),
#  (Decimal('6'), Decimal('7'), 'AGG. ASSAULT', 18),
#  (Decimal('6'), Decimal('8'), 'AGG. ASSAULT', 23),
#  (Decimal('6'), Decimal('9'), 'AGG. ASSAULT', 15),
#  (Decimal('6'), Decimal('10'), 'AGG. ASSAULT', 20),
#  (Decimal('6'), Decimal('11'), 'AGG. ASSAULT', 32),
#  (Decimal('6'), Decimal('12'), 'AGG. ASSAULT', 13),
#  (Decimal('6'), Decimal('13'), 'AGG. ASSAULT', 24),
#  (Decimal('6'), Decimal('14'), 'AGG. ASSAULT', 6),
#  (Decimal('6'), Decimal('15'), 'AGG. ASSAULT', 17),
#  (Decimal('6'), Decimal('16'), 'AGG. ASSAULT', 12),
#  (Decimal('6'), Decimal('17'), 'AGG. ASSAULT', 12),
#  (Decimal('6'), Decimal('18'), 'AGG. ASSAULT', 16),
#  (Decimal('6'), Decimal('19'), 'AGG. ASSAULT', 19),
#  (Decimal('6'), Decimal('20'), 'AGG. ASSAULT', 13),
#  (Decimal('6'), Decimal('21'), 'AGG. ASSAULT', 11),
#  (Decimal('6'), Decimal('22'), 'AGG. ASSAULT', 16),
#  (Decimal('6'), Decimal('23'), 'AGG. ASSAULT', 22),
#  (Decimal('6'), Decimal('24'), 'AGG. ASSAULT', 21),
#  (Decimal('6'), Decimal('25'), 'AGG. ASSAULT', 14),
#  (Decimal('6'), Decimal('26'), 'AGG. ASSAULT', 14),
#  (Decimal('6'), Decimal('27'), 'AGG. ASSAULT', 8),
#  (Decimal('6'), Decimal('28'), 'AGG. ASSAULT', 20),
#  (Decimal('6'), Decimal('29'), 'AGG. ASSAULT', 7),
#  (Decimal('6'), Decimal('30'), 'AGG. ASSAULT', 15),
#  (Decimal('6'), Decimal('1'), 'ARSON', 1),
#  (Decimal('6'), Decimal('2'), 'ARSON', 1),
#  (Decimal('6'), Decimal('3'), 'ARSON', 1),
#  (Decimal('6'), Decimal('5'), 'ARSON', 2),
#  (Decimal('6'), Decimal('6'), 'ARSON', 1),
#  (Decimal('6'), Decimal('9'), 'ARSON', 1),
#  (Decimal('6'), Decimal('10'), 'ARSON', 1),
#  (Decimal('6'), Decimal('11'), 'ARSON', 1),
#  (Decimal('6'), Decimal('12'), 'ARSON', 1),
#  (Decimal('6'), Decimal('15'), 'ARSON', 2),
#  (Decimal('6'), Decimal('16'), 'ARSON', 1),
#  (Decimal('6'), Decimal('18'), 'ARSON', 1),
#  (Decimal('6'), Decimal('19'), 'ARSON', 1),
#  (Decimal('6'), Decimal('20'), 'ARSON', 2),
#  (Decimal('6'), Decimal('21'), 'ARSON', 3),
#  (Decimal('6'), Decimal('22'), 'ARSON', 1),
#  (Decimal('6'), Decimal('23'), 'ARSON', 1),
#  (Decimal('6'), Decimal('25'), 'ARSON', 1),
#  (Decimal('6'), Decimal('26'), 'ARSON', 1),
#  (Decimal('6'), Decimal('27'), 'ARSON', 2),
#  (Decimal('6'), Decimal('28'), 'ARSON', 2),
#  (Decimal('6'), Decimal('29'), 'ARSON', 3),
#  (Decimal('6'), Decimal('30'), 'ARSON', 1),
#  (Decimal('6'), Decimal('1'), 'ASSAULT BY THREAT', 2),
#  (Decimal('6'), Decimal('2'), 'ASSAULT BY THREAT', 2),
#  (Decimal('6'), Decimal('3'), 'ASSAULT BY THREAT', 3),
#  (Decimal('6'), Decimal('4'), 'ASSAULT BY THREAT', 2),
#  (Decimal('6'), Decimal('5'), 'ASSAULT BY THREAT', 1),
#  (Decimal('6'), Decimal('6'), 'ASSAULT BY THREAT', 2),
#  (Decimal('6'), Decimal('7'), 'ASSAULT BY THREAT', 1),
#  (Decimal('6'), Decimal('8'), 'ASSAULT BY THREAT', 1),
#  (Decimal('6'), Decimal('9'), 'ASSAULT BY THREAT', 2),
#  (Decimal('6'), Decimal('10'), 'ASSAULT BY THREAT', 5),
#  (Decimal('6'), Decimal('14'), 'ASSAULT BY THREAT', 3),
#  (Decimal('6'), Decimal('15'), 'ASSAULT BY THREAT', 2),
#  (Decimal('6'), Decimal('16'), 'ASSAULT BY THREAT', 3),
#  (Decimal('6'), Decimal('17'), 'ASSAULT BY THREAT', 3),
#  (Decimal('6'), Decimal('18'), 'ASSAULT BY THREAT', 5),
#  (Decimal('6'), Decimal('20'), 'ASSAULT BY THREAT', 1),
#  (Decimal('6'), Decimal('22'), 'ASSAULT BY THREAT', 3),
#  (Decimal('6'), Decimal('24'), 'ASSAULT BY THREAT', 1),
#  (Decimal('6'), Decimal('25'), 'ASSAULT BY THREAT', 1),
#  (Decimal('6'), Decimal('26'), 'ASSAULT BY THREAT', 1),
#  (Decimal('6'), Decimal('27'), 'ASSAULT BY THREAT', 2),
#  (Decimal('6'), Decimal('29'), 'ASSAULT BY THREAT', 3),
#  (Decimal('6'), Decimal('1'), 'AUTO THEFT', 6),
#  (Decimal('6'), Decimal('2'), 'AUTO THEFT', 10),
#  (Decimal('6'), Decimal('3'), 'AUTO THEFT', 15),
#  (Decimal('6'), Decimal('4'), 'AUTO THEFT', 11),
#  (Decimal('6'), Decimal('5'), 'AUTO THEFT', 14),
#  (Decimal('6'), Decimal('6'), 'AUTO THEFT', 19),
#  (Decimal('6'), Decimal('7'), 'AUTO THEFT', 22),
#  (Decimal('6'), Decimal('8'), 'AUTO THEFT', 8),
#  (Decimal('6'), Decimal('9'), 'AUTO THEFT', 10),
#  (Decimal('6'), Decimal('10'), 'AUTO THEFT', 17),
#  (Decimal('6'), Decimal('11'), 'AUTO THEFT', 8),
#  (Decimal('6'), Decimal('12'), 'AUTO THEFT', 16),
#  (Decimal('6'), Decimal('13'), 'AUTO THEFT', 16),
#  (Decimal('6'), Decimal('14'), 'AUTO THEFT', 24),
#  (Decimal('6'), Decimal('15'), 'AUTO THEFT', 19),
#  (Decimal('6'), Decimal('16'), 'AUTO THEFT', 12),
#  (Decimal('6'), Decimal('17'), 'AUTO THEFT', 15),
#  (Decimal('6'), Decimal('18'), 'AUTO THEFT', 10),
#  (Decimal('6'), Decimal('19'), 'AUTO THEFT', 7),
#  (Decimal('6'), Decimal('20'), 'AUTO THEFT', 20),
#  (Decimal('6'), Decimal('21'), 'AUTO THEFT', 10),
#  (Decimal('6'), Decimal('22'), 'AUTO THEFT', 13),
#  (Decimal('6'), Decimal('23'), 'AUTO THEFT', 17),
#  (Decimal('6'), Decimal('24'), 'AUTO THEFT', 9),
#  (Decimal('6'), Decimal('25'), 'AUTO THEFT', 24),
#  (Decimal('6'), Decimal('26'), 'AUTO THEFT', 9),
#  (Decimal('6'), Decimal('27'), 'AUTO THEFT', 11),
#  (Decimal('6'), Decimal('28'), 'AUTO THEFT', 13),
#  (Decimal('6'), Decimal('29'), 'AUTO THEFT', 20),
#  (Decimal('6'), Decimal('30'), 'AUTO THEFT', 12),
#  (Decimal('6'), Decimal('1'), 'BURGLARY', 17),
#  (Decimal('6'), Decimal('2'), 'BURGLARY', 23),
#  (Decimal('6'), Decimal('3'), 'BURGLARY', 19),
#  (Decimal('6'), Decimal('4'), 'BURGLARY', 26),
#  (Decimal('6'), Decimal('5'), 'BURGLARY', 145),
#  (Decimal('6'), Decimal('6'), 'BURGLARY', 29),
#  (Decimal('6'), Decimal('7'), 'BURGLARY', 19),
#  (Decimal('6'), Decimal('8'), 'BURGLARY', 32),
#  (Decimal('6'), Decimal('9'), 'BURGLARY', 23),
#  (Decimal('6'), Decimal('10'), 'BURGLARY', 28),
#  (Decimal('6'), Decimal('11'), 'BURGLARY', 18),
#  (Decimal('6'), Decimal('12'), 'BURGLARY', 14),
#  (Decimal('6'), Decimal('13'), 'BURGLARY', 28),
#  (Decimal('6'), Decimal('14'), 'BURGLARY', 30),
#  (Decimal('6'), Decimal('15'), 'BURGLARY', 19),
#  (Decimal('6'), Decimal('16'), 'BURGLARY', 22),
#  (Decimal('6'), Decimal('17'), 'BURGLARY', 18),
#  (Decimal('6'), Decimal('18'), 'BURGLARY', 21),
#  (Decimal('6'), Decimal('19'), 'BURGLARY', 20),
#  (Decimal('6'), Decimal('20'), 'BURGLARY', 29),
#  (Decimal('6'), Decimal('21'), 'BURGLARY', 21),
#  (Decimal('6'), Decimal('22'), 'BURGLARY', 26),
#  (Decimal('6'), Decimal('23'), 'BURGLARY', 14),
#  (Decimal('6'), Decimal('24'), 'BURGLARY', 21),
#  (Decimal('6'), Decimal('25'), 'BURGLARY', 21),
#  (Decimal('6'), Decimal('26'), 'BURGLARY', 22),
#  (Decimal('6'), Decimal('27'), 'BURGLARY', 15),
#  (Decimal('6'), Decimal('28'), 'BURGLARY', 17),
#  (Decimal('6'), Decimal('29'), 'BURGLARY', 25),
#  (Decimal('6'), Decimal('30'), 'BURGLARY', 9),
#  (Decimal('6'), Decimal('1'), 'COMMON ASSAULT', 18),
#  (Decimal('6'), Decimal('2'), 'COMMON ASSAULT', 14),
#  (Decimal('6'), Decimal('3'), 'COMMON ASSAULT', 21),
#  (Decimal('6'), Decimal('4'), 'COMMON ASSAULT', 41),
#  (Decimal('6'), Decimal('5'), 'COMMON ASSAULT', 26),
#  (Decimal('6'), Decimal('6'), 'COMMON ASSAULT', 25),
#  (Decimal('6'), Decimal('7'), 'COMMON ASSAULT', 15),
#  (Decimal('6'), Decimal('8'), 'COMMON ASSAULT', 17),
#  (Decimal('6'), Decimal('9'), 'COMMON ASSAULT', 26),
#  (Decimal('6'), Decimal('10'), 'COMMON ASSAULT', 22),
#  (Decimal('6'), Decimal('11'), 'COMMON ASSAULT', 17),
#  (Decimal('6'), Decimal('12'), 'COMMON ASSAULT', 26),
#  (Decimal('6'), Decimal('13'), 'COMMON ASSAULT', 22),
#  (Decimal('6'), Decimal('14'), 'COMMON ASSAULT', 16),
#  (Decimal('6'), Decimal('15'), 'COMMON ASSAULT', 24),
#  (Decimal('6'), Decimal('16'), 'COMMON ASSAULT', 25),
#  (Decimal('6'), Decimal('17'), 'COMMON ASSAULT', 23),
#  (Decimal('6'), Decimal('18'), 'COMMON ASSAULT', 29),
#  (Decimal('6'), Decimal('19'), 'COMMON ASSAULT', 28),
#  (Decimal('6'), Decimal('20'), 'COMMON ASSAULT', 26),
#  (Decimal('6'), Decimal('21'), 'COMMON ASSAULT', 25),
#  (Decimal('6'), Decimal('22'), 'COMMON ASSAULT', 23),
#  (Decimal('6'), Decimal('23'), 'COMMON ASSAULT', 19),
#  (Decimal('6'), Decimal('24'), 'COMMON ASSAULT', 20),
#  (Decimal('6'), Decimal('25'), 'COMMON ASSAULT', 26),
#  (Decimal('6'), Decimal('26'), 'COMMON ASSAULT', 19),
#  (Decimal('6'), Decimal('27'), 'COMMON ASSAULT', 29),
#  (Decimal('6'), Decimal('28'), 'COMMON ASSAULT', 16),
#  (Decimal('6'), Decimal('29'), 'COMMON ASSAULT', 21),
#  (Decimal('6'), Decimal('30'), 'COMMON ASSAULT', 20),
#  (Decimal('6'), Decimal('3'), 'HOMICIDE', 2),
#  (Decimal('6'), Decimal('4'), 'HOMICIDE', 1),
#  (Decimal('6'), Decimal('6'), 'HOMICIDE', 2),
#  (Decimal('6'), Decimal('8'), 'HOMICIDE', 2),
#  (Decimal('6'), Decimal('9'), 'HOMICIDE', 2),
#  (Decimal('6'), Decimal('10'), 'HOMICIDE', 2),
#  (Decimal('6'), Decimal('11'), 'HOMICIDE', 2),
#  (Decimal('6'), Decimal('13'), 'HOMICIDE', 1),
#  (Decimal('6'), Decimal('14'), 'HOMICIDE', 1),
#  (Decimal('6'), Decimal('21'), 'HOMICIDE', 1),
#  (Decimal('6'), Decimal('22'), 'HOMICIDE', 2),
#  (Decimal('6'), Decimal('23'), 'HOMICIDE', 1),
#  (Decimal('6'), Decimal('24'), 'HOMICIDE', 1),
#  (Decimal('6'), Decimal('25'), 'HOMICIDE', 1),
#  (Decimal('6'), Decimal('26'), 'HOMICIDE', 2),
#  (Decimal('6'), Decimal('28'), 'HOMICIDE', 3),
#  (Decimal('6'), Decimal('30'), 'HOMICIDE', 1),
#  (Decimal('6'), Decimal('1'), 'LARCENY', 34),
#  (Decimal('6'), Decimal('2'), 'LARCENY', 33),
#  (Decimal('6'), Decimal('3'), 'LARCENY', 30),
#  (Decimal('6'), Decimal('4'), 'LARCENY', 22),
#  (Decimal('6'), Decimal('5'), 'LARCENY', 19),
#  (Decimal('6'), Decimal('6'), 'LARCENY', 30),
#  (Decimal('6'), Decimal('7'), 'LARCENY', 26),
#  (Decimal('6'), Decimal('8'), 'LARCENY', 35),
#  (Decimal('6'), Decimal('9'), 'LARCENY', 27),
#  (Decimal('6'), Decimal('10'), 'LARCENY', 25),
#  (Decimal('6'), Decimal('11'), 'LARCENY', 24),
#  (Decimal('6'), Decimal('12'), 'LARCENY', 33),
#  (Decimal('6'), Decimal('13'), 'LARCENY', 33),
#  (Decimal('6'), Decimal('14'), 'LARCENY', 28),
#  (Decimal('6'), Decimal('15'), 'LARCENY', 45),
#  (Decimal('6'), Decimal('16'), 'LARCENY', 24),
#  (Decimal('6'), Decimal('17'), 'LARCENY', 28),
#  (Decimal('6'), Decimal('18'), 'LARCENY', 22),
#  (Decimal('6'), Decimal('19'), 'LARCENY', 20),
#  (Decimal('6'), Decimal('20'), 'LARCENY', 30),
#  (Decimal('6'), Decimal('21'), 'LARCENY', 29),
#  (Decimal('6'), Decimal('22'), 'LARCENY', 23),
#  (Decimal('6'), Decimal('23'), 'LARCENY', 30),
#  (Decimal('6'), Decimal('24'), 'LARCENY', 21),
#  (Decimal('6'), Decimal('25'), 'LARCENY', 33),
#  (Decimal('6'), Decimal('26'), 'LARCENY', 34),
#  (Decimal('6'), Decimal('27'), 'LARCENY', 25),
#  (Decimal('6'), Decimal('28'), 'LARCENY', 28),
#  (Decimal('6'), Decimal('29'), 'LARCENY', 27),
#  (Decimal('6'), Decimal('30'), 'LARCENY', 26),
#  (Decimal('6'), Decimal('1'), 'LARCENY FROM AUTO', 12),
#  (Decimal('6'), Decimal('2'), 'LARCENY FROM AUTO', 8),
#  (Decimal('6'), Decimal('3'), 'LARCENY FROM AUTO', 19),
#  (Decimal('6'), Decimal('4'), 'LARCENY FROM AUTO', 18),
#  (Decimal('6'), Decimal('5'), 'LARCENY FROM AUTO', 20),
#  (Decimal('6'), Decimal('6'), 'LARCENY FROM AUTO', 25),
#  (Decimal('6'), Decimal('7'), 'LARCENY FROM AUTO', 15),
#  (Decimal('6'), Decimal('8'), 'LARCENY FROM AUTO', 18),
#  (Decimal('6'), Decimal('9'), 'LARCENY FROM AUTO', 22),
#  (Decimal('6'), Decimal('10'), 'LARCENY FROM AUTO', 22),
#  (Decimal('6'), Decimal('11'), 'LARCENY FROM AUTO', 19),
#  (Decimal('6'), Decimal('12'), 'LARCENY FROM AUTO', 16),
#  (Decimal('6'), Decimal('13'), 'LARCENY FROM AUTO', 22),
#  (Decimal('6'), Decimal('14'), 'LARCENY FROM AUTO', 13),
#  (Decimal('6'), Decimal('15'), 'LARCENY FROM AUTO', 18),
#  (Decimal('6'), Decimal('16'), 'LARCENY FROM AUTO', 18),
#  (Decimal('6'), Decimal('17'), 'LARCENY FROM AUTO', 21),
#  (Decimal('6'), Decimal('18'), 'LARCENY FROM AUTO', 21),
#  (Decimal('6'), Decimal('19'), 'LARCENY FROM AUTO', 30),
#  (Decimal('6'), Decimal('20'), 'LARCENY FROM AUTO', 37),
#  (Decimal('6'), Decimal('21'), 'LARCENY FROM AUTO', 17),
#  (Decimal('6'), Decimal('22'), 'LARCENY FROM AUTO', 22),
#  (Decimal('6'), Decimal('23'), 'LARCENY FROM AUTO', 31),
#  (Decimal('6'), Decimal('24'), 'LARCENY FROM AUTO', 17),
#  (Decimal('6'), Decimal('25'), 'LARCENY FROM AUTO', 21),
#  (Decimal('6'), Decimal('26'), 'LARCENY FROM AUTO', 15),
#  (Decimal('6'), Decimal('27'), 'LARCENY FROM AUTO', 11),
#  (Decimal('6'), Decimal('28'), 'LARCENY FROM AUTO', 20),
#  (Decimal('6'), Decimal('29'), 'LARCENY FROM AUTO', 24),
#  (Decimal('6'), Decimal('30'), 'LARCENY FROM AUTO', 16),
#  (Decimal('6'), Decimal('2'), 'RAPE', 1),
#  (Decimal('6'), Decimal('4'), 'RAPE', 3),
#  (Decimal('6'), Decimal('5'), 'RAPE', 1),
#  (Decimal('6'), Decimal('6'), 'RAPE', 1),
#  (Decimal('6'), Decimal('10'), 'RAPE', 2),
#  (Decimal('6'), Decimal('12'), 'RAPE', 2),
#  (Decimal('6'), Decimal('13'), 'RAPE', 1),
#  (Decimal('6'), Decimal('17'), 'RAPE', 1),
#  (Decimal('6'), Decimal('18'), 'RAPE', 2),
#  (Decimal('6'), Decimal('19'), 'RAPE', 1),
#  (Decimal('6'), Decimal('21'), 'RAPE', 1),
#  (Decimal('6'), Decimal('25'), 'RAPE', 1),
#  (Decimal('6'), Decimal('27'), 'RAPE', 1),
#  (Decimal('6'), Decimal('29'), 'RAPE', 3),
#  (Decimal('6'), Decimal('1'), 'ROBBERY - CARJACKING', 1),
#  (Decimal('6'), Decimal('2'), 'ROBBERY - CARJACKING', 1),
#  (Decimal('6'), Decimal('3'), 'ROBBERY - CARJACKING', 1),
#  (Decimal('6'), Decimal('6'), 'ROBBERY - CARJACKING', 1),
#  (Decimal('6'), Decimal('7'), 'ROBBERY - CARJACKING', 3),
#  (Decimal('6'), Decimal('12'), 'ROBBERY - CARJACKING', 1),
#  (Decimal('6'), Decimal('13'), 'ROBBERY - CARJACKING', 4),
#  (Decimal('6'), Decimal('14'), 'ROBBERY - CARJACKING', 1),
#  (Decimal('6'), Decimal('15'), 'ROBBERY - CARJACKING', 3),
#  (Decimal('6'), Decimal('19'), 'ROBBERY - CARJACKING', 1),
#  (Decimal('6'), Decimal('20'), 'ROBBERY - CARJACKING', 1),
#  (Decimal('6'), Decimal('22'), 'ROBBERY - CARJACKING', 2),
#  (Decimal('6'), Decimal('23'), 'ROBBERY - CARJACKING', 3),
#  (Decimal('6'), Decimal('24'), 'ROBBERY - CARJACKING', 3),
#  (Decimal('6'), Decimal('27'), 'ROBBERY - CARJACKING', 2),
#  (Decimal('6'), Decimal('30'), 'ROBBERY - CARJACKING', 1),
#  (Decimal('6'), Decimal('1'), 'ROBBERY - COMMERCIAL', 5),
#  (Decimal('6'), Decimal('2'), 'ROBBERY - COMMERCIAL', 3),
#  (Decimal('6'), Decimal('3'), 'ROBBERY - COMMERCIAL', 2),
#  (Decimal('6'), Decimal('4'), 'ROBBERY - COMMERCIAL', 3),
#  (Decimal('6'), Decimal('5'), 'ROBBERY - COMMERCIAL', 2),
#  (Decimal('6'), Decimal('6'), 'ROBBERY - COMMERCIAL', 8),
#  (Decimal('6'), Decimal('7'), 'ROBBERY - COMMERCIAL', 2),
#  (Decimal('6'), Decimal('8'), 'ROBBERY - COMMERCIAL', 5),
#  (Decimal('6'), Decimal('9'), 'ROBBERY - COMMERCIAL', 3),
#  (Decimal('6'), Decimal('10'), 'ROBBERY - COMMERCIAL', 1),
#  (Decimal('6'), Decimal('11'), 'ROBBERY - COMMERCIAL', 5),
#  (Decimal('6'), Decimal('13'), 'ROBBERY - COMMERCIAL', 5),
#  (Decimal('6'), Decimal('14'), 'ROBBERY - COMMERCIAL', 3),
#  (Decimal('6'), Decimal('15'), 'ROBBERY - COMMERCIAL', 1),
#  (Decimal('6'), Decimal('16'), 'ROBBERY - COMMERCIAL', 3),
#  (Decimal('6'), Decimal('17'), 'ROBBERY - COMMERCIAL', 1),
#  (Decimal('6'), Decimal('18'), 'ROBBERY - COMMERCIAL', 2),
#  (Decimal('6'), Decimal('19'), 'ROBBERY - COMMERCIAL', 3),
#  (Decimal('6'), Decimal('20'), 'ROBBERY - COMMERCIAL', 1),
#  (Decimal('6'), Decimal('21'), 'ROBBERY - COMMERCIAL', 3),
#  (Decimal('6'), Decimal('22'), 'ROBBERY - COMMERCIAL', 2),
#  (Decimal('6'), Decimal('23'), 'ROBBERY - COMMERCIAL', 3),
#  (Decimal('6'), Decimal('24'), 'ROBBERY - COMMERCIAL', 2),
#  (Decimal('6'), Decimal('25'), 'ROBBERY - COMMERCIAL', 1),
#  (Decimal('6'), Decimal('26'), 'ROBBERY - COMMERCIAL', 3),
#  (Decimal('6'), Decimal('27'), 'ROBBERY - COMMERCIAL', 1),
#  (Decimal('6'), Decimal('28'), 'ROBBERY - COMMERCIAL', 3),
#  (Decimal('6'), Decimal('29'), 'ROBBERY - COMMERCIAL', 1),
#  (Decimal('6'), Decimal('30'), 'ROBBERY - COMMERCIAL', 1),
#  (Decimal('6'), Decimal('1'), 'ROBBERY - RESIDENCE', 2),
#  (Decimal('6'), Decimal('2'), 'ROBBERY - RESIDENCE', 4),
#  (Decimal('6'), Decimal('3'), 'ROBBERY - RESIDENCE', 1),
#  (Decimal('6'), Decimal('4'), 'ROBBERY - RESIDENCE', 2),
#  (Decimal('6'), Decimal('5'), 'ROBBERY - RESIDENCE', 1),
#  (Decimal('6'), Decimal('6'), 'ROBBERY - RESIDENCE', 3),
#  (Decimal('6'), Decimal('9'), 'ROBBERY - RESIDENCE', 2),
#  (Decimal('6'), Decimal('10'), 'ROBBERY - RESIDENCE', 1),
#  (Decimal('6'), Decimal('11'), 'ROBBERY - RESIDENCE', 5),
#  (Decimal('6'), Decimal('13'), 'ROBBERY - RESIDENCE', 3),
#  (Decimal('6'), Decimal('16'), 'ROBBERY - RESIDENCE', 1),
#  (Decimal('6'), Decimal('20'), 'ROBBERY - RESIDENCE', 2),
#  (Decimal('6'), Decimal('21'), 'ROBBERY - RESIDENCE', 1),
#  (Decimal('6'), Decimal('22'), 'ROBBERY - RESIDENCE', 2),
#  (Decimal('6'), Decimal('24'), 'ROBBERY - RESIDENCE', 2),
#  (Decimal('6'), Decimal('25'), 'ROBBERY - RESIDENCE', 1),
#  (Decimal('6'), Decimal('26'), 'ROBBERY - RESIDENCE', 1),
#  (Decimal('6'), Decimal('27'), 'ROBBERY - RESIDENCE', 1),
#  (Decimal('6'), Decimal('28'), 'ROBBERY - RESIDENCE', 1),
#  (Decimal('6'), Decimal('29'), 'ROBBERY - RESIDENCE', 3),
#  (Decimal('6'), Decimal('30'), 'ROBBERY - RESIDENCE', 2),
#  (Decimal('6'), Decimal('1'), 'ROBBERY - STREET', 16),
#  (Decimal('6'), Decimal('2'), 'ROBBERY - STREET', 13),
#  (Decimal('6'), Decimal('3'), 'ROBBERY - STREET', 12),
#  (Decimal('6'), Decimal('4'), 'ROBBERY - STREET', 7),
#  (Decimal('6'), Decimal('5'), 'ROBBERY - STREET', 9),
#  (Decimal('6'), Decimal('6'), 'ROBBERY - STREET', 12),
#  (Decimal('6'), Decimal('7'), 'ROBBERY - STREET', 5),
#  (Decimal('6'), Decimal('8'), 'ROBBERY - STREET', 11),
#  (Decimal('6'), Decimal('9'), 'ROBBERY - STREET', 5),
#  (Decimal('6'), Decimal('10'), 'ROBBERY - STREET', 15),
#  (Decimal('6'), Decimal('11'), 'ROBBERY - STREET', 15),
#  (Decimal('6'), Decimal('12'), 'ROBBERY - STREET', 4),
#  (Decimal('6'), Decimal('13'), 'ROBBERY - STREET', 10),
#  (Decimal('6'), Decimal('14'), 'ROBBERY - STREET', 5),
#  (Decimal('6'), Decimal('15'), 'ROBBERY - STREET', 8),
#  (Decimal('6'), Decimal('16'), 'ROBBERY - STREET', 4),
#  (Decimal('6'), Decimal('17'), 'ROBBERY - STREET', 9),
#  (Decimal('6'), Decimal('18'), 'ROBBERY - STREET', 5),
#  (Decimal('6'), Decimal('19'), 'ROBBERY - STREET', 11),
#  (Decimal('6'), Decimal('20'), 'ROBBERY - STREET', 17),
#  (Decimal('6'), Decimal('21'), 'ROBBERY - STREET', 12),
#  (Decimal('6'), Decimal('22'), 'ROBBERY - STREET', 12),
#  (Decimal('6'), Decimal('23'), 'ROBBERY - STREET', 14),
#  (Decimal('6'), Decimal('24'), 'ROBBERY - STREET', 11),
#  (Decimal('6'), Decimal('25'), 'ROBBERY - STREET', 6),
#  (Decimal('6'), Decimal('26'), 'ROBBERY - STREET', 7),
#  (Decimal('6'), Decimal('27'), 'ROBBERY - STREET', 11),
#  (Decimal('6'), Decimal('28'), 'ROBBERY - STREET', 6),
#  (Decimal('6'), Decimal('29'), 'ROBBERY - STREET', 8),
#  (Decimal('6'), Decimal('30'), 'ROBBERY - STREET', 7),
#  (Decimal('6'), Decimal('1'), 'SHOOTING', 2),
#  (Decimal('6'), Decimal('2'), 'SHOOTING', 3),
#  (Decimal('6'), Decimal('4'), 'SHOOTING', 2),
#  (Decimal('6'), Decimal('5'), 'SHOOTING', 2),
#  (Decimal('6'), Decimal('6'), 'SHOOTING', 2),
#  (Decimal('6'), Decimal('7'), 'SHOOTING', 4),
#  (Decimal('6'), Decimal('8'), 'SHOOTING', 5),
#  (Decimal('6'), Decimal('10'), 'SHOOTING', 5),
#  (Decimal('6'), Decimal('11'), 'SHOOTING', 3),
#  (Decimal('6'), Decimal('12'), 'SHOOTING', 1),
#  (Decimal('6'), Decimal('13'), 'SHOOTING', 2),
#  (Decimal('6'), Decimal('15'), 'SHOOTING', 2),
#  (Decimal('6'), Decimal('16'), 'SHOOTING', 1),
#  (Decimal('6'), Decimal('18'), 'SHOOTING', 3),
#  (Decimal('6'), Decimal('19'), 'SHOOTING', 2),
#  (Decimal('6'), Decimal('20'), 'SHOOTING', 6),
#  (Decimal('6'), Decimal('21'), 'SHOOTING', 4),
#  (Decimal('6'), Decimal('22'), 'SHOOTING', 3),
#  (Decimal('6'), Decimal('23'), 'SHOOTING', 5),
#  (Decimal('6'), Decimal('24'), 'SHOOTING', 3),
#  (Decimal('6'), Decimal('25'), 'SHOOTING', 1),
#  (Decimal('6'), Decimal('26'), 'SHOOTING', 1),
#  (Decimal('6'), Decimal('27'), 'SHOOTING', 2),
#  (Decimal('6'), Decimal('28'), 'SHOOTING', 6),
#  (Decimal('6'), Decimal('29'), 'SHOOTING', 1),
#  (Decimal('6'), Decimal('30'), 'SHOOTING', 1)]

# %%
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt
from matplotlib import rc

d = _.DataFrame()
rc('figure', figsize=(20, 8))
splt = sns.barplot(x='description', y='count', data=d)
labels = [l for l in splt.get_xmajorticklabels()]
splt.set_xticklabels(labels, rotation=30)
# Out:
# [<matplotlib.text.Text at 0x7f91d47e8198>,
#  <matplotlib.text.Text at 0x7f91d47f3a90>,
#  <matplotlib.text.Text at 0x7f91d490ccf8>,
#  <matplotlib.text.Text at 0x7f91d4913828>,
#  <matplotlib.text.Text at 0x7f91d4918358>,
#  <matplotlib.text.Text at 0x7f91d4918e48>,
#  <matplotlib.text.Text at 0x7f91d4919978>,
#  <matplotlib.text.Text at 0x7f91d49204a8>,
#  <matplotlib.text.Text at 0x7f91d4920f98>,
#  <matplotlib.text.Text at 0x7f91d4923ac8>,
#  <matplotlib.text.Text at 0x7f91d49225f8>,
#  <matplotlib.text.Text at 0x7f91d4927128>,
#  <matplotlib.text.Text at 0x7f91d4927c18>,
#  <matplotlib.text.Text at 0x7f91d492e748>,
#  <matplotlib.text.Text at 0x7f91d4932278>]

# %% [markdown]
# Inspired by Wei Zheng's use of seaborn on a previous assignment, we decided to use it as well to give us more options for easily visualizing data. The plot above shows the typical distribution for the month of June, and we can see that the relative amount of burglaries reported on June 5th is atypical.

# %%
# %%sql
# SELECT
#     b.month,
#     b.day,
#     c.description,
#     count(c.description)
# FROM fact_incidents_2016 a
# JOIN dim_date_time b ON
#     a.date_time_key = b.date_time_key
# JOIN dim_crime_details c ON
#     a.crime_details_key = c.crime_details_key
# JOIN dim_location_details d ON
#     a.location_details_key = d.location_details_key
# GROUP BY description, month, day
# ORDER BY description, month, day
# Out:
# 3710 rows affected.
# [(Decimal('1'), Decimal('1'), 'AGG. ASSAULT', 17),
#  (Decimal('1'), Decimal('2'), 'AGG. ASSAULT', 13),
#  (Decimal('1'), Decimal('3'), 'AGG. ASSAULT', 13),
#  (Decimal('1'), Decimal('4'), 'AGG. ASSAULT', 5),
#  (Decimal('1'), Decimal('5'), 'AGG. ASSAULT', 12),
#  (Decimal('1'), Decimal('6'), 'AGG. ASSAULT', 8),
#  (Decimal('1'), Decimal('7'), 'AGG. ASSAULT', 10),
#  (Decimal('1'), Decimal('8'), 'AGG. ASSAULT', 10),
#  (Decimal('1'), Decimal('9'), 'AGG. ASSAULT', 13),
#  (Decimal('1'), Decimal('10'), 'AGG. ASSAULT', 10),
#  (Decimal('1'), Decimal('11'), 'AGG. ASSAULT', 11),
#  (Decimal('1'), Decimal('12'), 'AGG. ASSAULT', 8),
#  (Decimal('1'), Decimal('13'), 'AGG. ASSAULT', 8),
#  (Decimal('1'), Decimal('14'), 'AGG. ASSAULT', 14),
#  (Decimal('1'), Decimal('15'), 'AGG. ASSAULT', 12),
#  (Decimal('1'), Decimal('16'), 'AGG. ASSAULT', 19),
#  (Decimal('1'), Decimal('17'), 'AGG. ASSAULT', 23),
#  (Decimal('1'), Decimal('18'), 'AGG. ASSAULT', 3),
#  (Decimal('1'), Decimal('19'), 'AGG. ASSAULT', 15),
#  (Decimal('1'), Decimal('20'), 'AGG. ASSAULT', 6),
#  (Decimal('1'), Decimal('21'), 'AGG. ASSAULT', 6),
#  (Decimal('1'), Decimal('22'), 'AGG. ASSAULT', 6),
#  (Decimal('1'), Decimal('23'), 'AGG. ASSAULT', 1),
#  (Decimal('1'), Decimal('24'), 'AGG. ASSAULT', 3),
#  (Decimal('1'), Decimal('25'), 'AGG. ASSAULT', 12),
#  (Decimal('1'), Decimal('26'), 'AGG. ASSAULT', 8),
#  (Decimal('1'), Decimal('27'), 'AGG. ASSAULT', 11),
#  (Decimal('1'), Decimal('28'), 'AGG. ASSAULT', 12),
#  (Decimal('1'), Decimal('29'), 'AGG. ASSAULT', 13),
#  (Decimal('1'), Decimal('30'), 'AGG. ASSAULT', 8),
#  (Decimal('1'), Decimal('31'), 'AGG. ASSAULT', 15),
#  (Decimal('2'), Decimal('1'), 'AGG. ASSAULT', 9),
#  (Decimal('2'), Decimal('2'), 'AGG. ASSAULT', 9),
#  (Decimal('2'), Decimal('3'), 'AGG. ASSAULT', 13),
#  (Decimal('2'), Decimal('4'), 'AGG. ASSAULT', 7),
#  (Decimal('2'), Decimal('5'), 'AGG. ASSAULT', 6),
#  (Decimal('2'), Decimal('6'), 'AGG. ASSAULT', 17),
#  (Decimal('2'), Decimal('7'), 'AGG. ASSAULT', 6),
#  (Decimal('2'), Decimal('8'), 'AGG. ASSAULT', 18),
#  (Decimal('2'), Decimal('9'), 'AGG. ASSAULT', 5),
#  (Decimal('2'), Decimal('10'), 'AGG. ASSAULT', 6),
#  (Decimal('2'), Decimal('11'), 'AGG. ASSAULT', 7),
#  (Decimal('2'), Decimal('12'), 'AGG. ASSAULT', 8),
#  (Decimal('2'), Decimal('13'), 'AGG. ASSAULT', 8),
#  (Decimal('2'), Decimal('14'), 'AGG. ASSAULT', 14),
#  (Decimal('2'), Decimal('15'), 'AGG. ASSAULT', 6),
#  (Decimal('2'), Decimal('16'), 'AGG. ASSAULT', 9),
#  (Decimal('2'), Decimal('17'), 'AGG. ASSAULT', 15),
#  (Decimal('2'), Decimal('18'), 'AGG. ASSAULT', 9),
#  (Decimal('2'), Decimal('19'), 'AGG. ASSAULT', 9),
#  (Decimal('2'), Decimal('20'), 'AGG. ASSAULT', 10),
#  (Decimal('2'), Decimal('21'), 'AGG. ASSAULT', 7),
#  (Decimal('2'), Decimal('22'), 'AGG. ASSAULT', 16),
#  (Decimal('2'), Decimal('23'), 'AGG. ASSAULT', 8),
#  (Decimal('2'), Decimal('24'), 'AGG. ASSAULT', 9),
#  (Decimal('2'), Decimal('25'), 'AGG. ASSAULT', 11),
#  (Decimal('2'), Decimal('26'), 'AGG. ASSAULT', 12),
#  (Decimal('2'), Decimal('27'), 'AGG. ASSAULT', 14),
#  (Decimal('2'), Decimal('28'), 'AGG. ASSAULT', 8),
#  (Decimal('2'), Decimal('29'), 'AGG. ASSAULT', 11),
#  (Decimal('3'), Decimal('1'), 'AGG. ASSAULT', 15),
#  (Decimal('3'), Decimal('2'), 'AGG. ASSAULT', 3),
#  (Decimal('3'), Decimal('3'), 'AGG. ASSAULT', 13),
#  (Decimal('3'), Decimal('4'), 'AGG. ASSAULT', 11),
#  (Decimal('3'), Decimal('5'), 'AGG. ASSAULT', 16),
#  (Decimal('3'), Decimal('6'), 'AGG. ASSAULT', 12),
#  (Decimal('3'), Decimal('7'), 'AGG. ASSAULT', 20),
#  (Decimal('3'), Decimal('8'), 'AGG. ASSAULT', 15),
#  (Decimal('3'), Decimal('9'), 'AGG. ASSAULT', 8),
#  (Decimal('3'), Decimal('10'), 'AGG. ASSAULT', 14),
#  (Decimal('3'), Decimal('11'), 'AGG. ASSAULT', 20),
#  (Decimal('3'), Decimal('12'), 'AGG. ASSAULT', 22),
#  (Decimal('3'), Decimal('13'), 'AGG. ASSAULT', 10),
#  (Decimal('3'), Decimal('14'), 'AGG. ASSAULT', 9),
#  (Decimal('3'), Decimal('15'), 'AGG. ASSAULT', 12),
#  (Decimal('3'), Decimal('16'), 'AGG. ASSAULT', 15),
#  (Decimal('3'), Decimal('17'), 'AGG. ASSAULT', 24),
#  (Decimal('3'), Decimal('18'), 'AGG. ASSAULT', 20),
#  (Decimal('3'), Decimal('19'), 'AGG. ASSAULT', 7),
#  (Decimal('3'), Decimal('20'), 'AGG. ASSAULT', 14),
#  (Decimal('3'), Decimal('21'), 'AGG. ASSAULT', 17),
#  (Decimal('3'), Decimal('22'), 'AGG. ASSAULT', 10),
#  (Decimal('3'), Decimal('23'), 'AGG. ASSAULT', 13),
#  (Decimal('3'), Decimal('24'), 'AGG. ASSAULT', 13),
#  (Decimal('3'), Decimal('25'), 'AGG. ASSAULT', 23),
#  (Decimal('3'), Decimal('26'), 'AGG. ASSAULT', 16),
#  (Decimal('3'), Decimal('27'), 'AGG. ASSAULT', 11),
#  (Decimal('3'), Decimal('28'), 'AGG. ASSAULT', 14),
#  (Decimal('3'), Decimal('29'), 'AGG. ASSAULT', 11),
#  (Decimal('3'), Decimal('30'), 'AGG. ASSAULT', 12),
#  (Decimal('3'), Decimal('31'), 'AGG. ASSAULT', 8),
#  (Decimal('4'), Decimal('1'), 'AGG. ASSAULT', 19),
#  (Decimal('4'), Decimal('2'), 'AGG. ASSAULT', 20),
#  (Decimal('4'), Decimal('3'), 'AGG. ASSAULT', 7),
#  (Decimal('4'), Decimal('4'), 'AGG. ASSAULT', 11),
#  (Decimal('4'), Decimal('5'), 'AGG. ASSAULT', 12),
#  (Decimal('4'), Decimal('6'), 'AGG. ASSAULT', 24),
#  (Decimal('4'), Decimal('7'), 'AGG. ASSAULT', 13),
#  (Decimal('4'), Decimal('8'), 'AGG. ASSAULT', 9),
#  (Decimal('4'), Decimal('9'), 'AGG. ASSAULT', 7),
#  (Decimal('4'), Decimal('10'), 'AGG. ASSAULT', 13),
#  (Decimal('4'), Decimal('11'), 'AGG. ASSAULT', 16),
#  (Decimal('4'), Decimal('12'), 'AGG. ASSAULT', 8),
#  (Decimal('4'), Decimal('13'), 'AGG. ASSAULT', 17),
#  (Decimal('4'), Decimal('14'), 'AGG. ASSAULT', 14),
#  (Decimal('4'), Decimal('15'), 'AGG. ASSAULT', 12),
#  (Decimal('4'), Decimal('16'), 'AGG. ASSAULT', 22),
#  (Decimal('4'), Decimal('17'), 'AGG. ASSAULT', 18),
#  (Decimal('4'), Decimal('18'), 'AGG. ASSAULT', 22),
#  (Decimal('4'), Decimal('19'), 'AGG. ASSAULT', 22),
#  (Decimal('4'), Decimal('20'), 'AGG. ASSAULT', 11),
#  (Decimal('4'), Decimal('21'), 'AGG. ASSAULT', 9),
#  (Decimal('4'), Decimal('22'), 'AGG. ASSAULT', 15),
#  (Decimal('4'), Decimal('23'), 'AGG. ASSAULT', 11),
#  (Decimal('4'), Decimal('24'), 'AGG. ASSAULT', 15),
#  (Decimal('4'), Decimal('25'), 'AGG. ASSAULT', 11),
#  (Decimal('4'), Decimal('26'), 'AGG. ASSAULT', 22),
#  (Decimal('4'), Decimal('27'), 'AGG. ASSAULT', 10),
#  (Decimal('4'), Decimal('28'), 'AGG. ASSAULT', 10),
#  (Decimal('4'), Decimal('29'), 'AGG. ASSAULT', 15),
#  (Decimal('4'), Decimal('30'), 'AGG. ASSAULT', 5),
#  (Decimal('5'), Decimal('1'), 'AGG. ASSAULT', 7),
#  (Decimal('5'), Decimal('2'), 'AGG. ASSAULT', 14),
#  (Decimal('5'), Decimal('3'), 'AGG. ASSAULT', 29),
#  (Decimal('5'), Decimal('4'), 'AGG. ASSAULT', 18),
#  (Decimal('5'), Decimal('5'), 'AGG. ASSAULT', 13),
#  (Decimal('5'), Decimal('6'), 'AGG. ASSAULT', 27),
#  (Decimal('5'), Decimal('7'), 'AGG. ASSAULT', 15),
#  (Decimal('5'), Decimal('8'), 'AGG. ASSAULT', 14),
#  (Decimal('5'), Decimal('9'), 'AGG. ASSAULT', 11),
#  (Decimal('5'), Decimal('10'), 'AGG. ASSAULT', 18),
#  (Decimal('5'), Decimal('11'), 'AGG. ASSAULT', 8),
#  (Decimal('5'), Decimal('12'), 'AGG. ASSAULT', 18),
#  (Decimal('5'), Decimal('13'), 'AGG. ASSAULT', 15),
#  (Decimal('5'), Decimal('14'), 'AGG. ASSAULT', 13),
#  (Decimal('5'), Decimal('15'), 'AGG. ASSAULT', 17),
#  (Decimal('5'), Decimal('16'), 'AGG. ASSAULT', 15),
#  (Decimal('5'), Decimal('17'), 'AGG. ASSAULT', 13),
#  (Decimal('5'), Decimal('18'), 'AGG. ASSAULT', 12),
#  (Decimal('5'), Decimal('19'), 'AGG. ASSAULT', 9),
#  (Decimal('5'), Decimal('20'), 'AGG. ASSAULT', 10),
#  (Decimal('5'), Decimal('21'), 'AGG. ASSAULT', 12),
#  (Decimal('5'), Decimal('22'), 'AGG. ASSAULT', 16),
#  (Decimal('5'), Decimal('23'), 'AGG. ASSAULT', 11),
#  (Decimal('5'), Decimal('24'), 'AGG. ASSAULT', 15),
#  (Decimal('5'), Decimal('25'), 'AGG. ASSAULT', 12),
#  (Decimal('5'), Decimal('26'), 'AGG. ASSAULT', 8),
#  (Decimal('5'), Decimal('27'), 'AGG. ASSAULT', 16),
#  (Decimal('5'), Decimal('28'), 'AGG. ASSAULT', 29),
#  (Decimal('5'), Decimal('29'), 'AGG. ASSAULT', 18),
#  (Decimal('5'), Decimal('30'), 'AGG. ASSAULT', 18),
#  (Decimal('5'), Decimal('31'), 'AGG. ASSAULT', 27),
#  (Decimal('6'), Decimal('1'), 'AGG. ASSAULT', 13),
#  (Decimal('6'), Decimal('2'), 'AGG. ASSAULT', 16),
#  (Decimal('6'), Decimal('3'), 'AGG. ASSAULT', 11),
#  (Decimal('6'), Decimal('4'), 'AGG. ASSAULT', 18),
#  (Decimal('6'), Decimal('5'), 'AGG. ASSAULT', 12),
#  (Decimal('6'), Decimal('6'), 'AGG. ASSAULT', 14),
#  (Decimal('6'), Decimal('7'), 'AGG. ASSAULT', 18),
#  (Decimal('6'), Decimal('8'), 'AGG. ASSAULT', 23),
#  (Decimal('6'), Decimal('9'), 'AGG. ASSAULT', 15),
#  (Decimal('6'), Decimal('10'), 'AGG. ASSAULT', 20),
#  (Decimal('6'), Decimal('11'), 'AGG. ASSAULT', 32),
#  (Decimal('6'), Decimal('12'), 'AGG. ASSAULT', 13),
#  (Decimal('6'), Decimal('13'), 'AGG. ASSAULT', 24),
#  (Decimal('6'), Decimal('14'), 'AGG. ASSAULT', 6),
#  (Decimal('6'), Decimal('15'), 'AGG. ASSAULT', 17),
#  (Decimal('6'), Decimal('16'), 'AGG. ASSAULT', 12),
#  (Decimal('6'), Decimal('17'), 'AGG. ASSAULT', 12),
#  (Decimal('6'), Decimal('18'), 'AGG. ASSAULT', 16),
#  (Decimal('6'), Decimal('19'), 'AGG. ASSAULT', 19),
#  (Decimal('6'), Decimal('20'), 'AGG. ASSAULT', 13),
#  (Decimal('6'), Decimal('21'), 'AGG. ASSAULT', 11),
#  (Decimal('6'), Decimal('22'), 'AGG. ASSAULT', 16),
#  (Decimal('6'), Decimal('23'), 'AGG. ASSAULT', 22),
#  (Decimal('6'), Decimal('24'), 'AGG. ASSAULT', 21),
#  (Decimal('6'), Decimal('25'), 'AGG. ASSAULT', 14),
#  (Decimal('6'), Decimal('26'), 'AGG. ASSAULT', 14),
#  (Decimal('6'), Decimal('27'), 'AGG. ASSAULT', 8),
#  (Decimal('6'), Decimal('28'), 'AGG. ASSAULT', 20),
#  (Decimal('6'), Decimal('29'), 'AGG. ASSAULT', 7),
#  (Decimal('6'), Decimal('30'), 'AGG. ASSAULT', 15),
#  (Decimal('7'), Decimal('1'), 'AGG. ASSAULT', 14),
#  (Decimal('7'), Decimal('2'), 'AGG. ASSAULT', 9),
#  (Decimal('7'), Decimal('3'), 'AGG. ASSAULT', 12),
#  (Decimal('7'), Decimal('4'), 'AGG. ASSAULT', 12),
#  (Decimal('7'), Decimal('5'), 'AGG. ASSAULT', 24),
#  (Decimal('7'), Decimal('6'), 'AGG. ASSAULT', 22),
#  (Decimal('7'), Decimal('7'), 'AGG. ASSAULT', 19),
#  (Decimal('7'), Decimal('8'), 'AGG. ASSAULT', 9),
#  (Decimal('7'), Decimal('9'), 'AGG. ASSAULT', 5),
#  (Decimal('7'), Decimal('10'), 'AGG. ASSAULT', 12),
#  (Decimal('7'), Decimal('11'), 'AGG. ASSAULT', 24),
#  (Decimal('7'), Decimal('12'), 'AGG. ASSAULT', 11),
#  (Decimal('7'), Decimal('13'), 'AGG. ASSAULT', 12),
#  (Decimal('7'), Decimal('14'), 'AGG. ASSAULT', 17),
#  (Decimal('7'), Decimal('15'), 'AGG. ASSAULT', 7),
#  (Decimal('7'), Decimal('16'), 'AGG. ASSAULT', 13),
#  (Decimal('7'), Decimal('17'), 'AGG. ASSAULT', 19),
#  (Decimal('7'), Decimal('18'), 'AGG. ASSAULT', 14),
#  (Decimal('7'), Decimal('19'), 'AGG. ASSAULT', 16),
#  (Decimal('7'), Decimal('20'), 'AGG. ASSAULT', 25),
#  (Decimal('7'), Decimal('21'), 'AGG. ASSAULT', 10),
#  (Decimal('7'), Decimal('22'), 'AGG. ASSAULT', 23),
#  (Decimal('7'), Decimal('23'), 'AGG. ASSAULT', 11),
#  (Decimal('7'), Decimal('24'), 'AGG. ASSAULT', 19),
#  (Decimal('7'), Decimal('25'), 'AGG. ASSAULT', 16),
#  (Decimal('7'), Decimal('26'), 'AGG. ASSAULT', 17),
#  (Decimal('7'), Decimal('27'), 'AGG. ASSAULT', 15),
#  (Decimal('7'), Decimal('28'), 'AGG. ASSAULT', 12),
#  (Decimal('7'), Decimal('29'), 'AGG. ASSAULT', 6),
#  (Decimal('7'), Decimal('30'), 'AGG. ASSAULT', 15),
#  (Decimal('7'), Decimal('31'), 'AGG. ASSAULT', 5),
#  (Decimal('8'), Decimal('1'), 'AGG. ASSAULT', 17),
#  (Decimal('8'), Decimal('2'), 'AGG. ASSAULT', 22),
#  (Decimal('8'), Decimal('3'), 'AGG. ASSAULT', 13),
#  (Decimal('8'), Decimal('4'), 'AGG. ASSAULT', 13),
#  (Decimal('8'), Decimal('5'), 'AGG. ASSAULT', 12),
#  (Decimal('8'), Decimal('6'), 'AGG. ASSAULT', 15),
#  (Decimal('8'), Decimal('7'), 'AGG. ASSAULT', 15),
#  (Decimal('8'), Decimal('8'), 'AGG. ASSAULT', 17),
#  (Decimal('8'), Decimal('9'), 'AGG. ASSAULT', 13),
#  (Decimal('8'), Decimal('10'), 'AGG. ASSAULT', 16),
#  (Decimal('8'), Decimal('11'), 'AGG. ASSAULT', 9),
#  (Decimal('8'), Decimal('12'), 'AGG. ASSAULT', 13),
#  (Decimal('8'), Decimal('13'), 'AGG. ASSAULT', 22),
#  (Decimal('8'), Decimal('14'), 'AGG. ASSAULT', 14),
#  (Decimal('8'), Decimal('15'), 'AGG. ASSAULT', 11),
#  (Decimal('8'), Decimal('16'), 'AGG. ASSAULT', 15),
#  (Decimal('8'), Decimal('17'), 'AGG. ASSAULT', 9),
#  (Decimal('8'), Decimal('18'), 'AGG. ASSAULT', 19),
#  (Decimal('8'), Decimal('19'), 'AGG. ASSAULT', 13),
#  (Decimal('8'), Decimal('20'), 'AGG. ASSAULT', 7),
#  (Decimal('8'), Decimal('21'), 'AGG. ASSAULT', 12),
#  (Decimal('8'), Decimal('22'), 'AGG. ASSAULT', 15),
#  (Decimal('8'), Decimal('23'), 'AGG. ASSAULT', 12),
#  (Decimal('8'), Decimal('24'), 'AGG. ASSAULT', 7),
#  (Decimal('8'), Decimal('25'), 'AGG. ASSAULT', 12),
#  (Decimal('8'), Decimal('26'), 'AGG. ASSAULT', 13),
#  (Decimal('8'), Decimal('27'), 'AGG. ASSAULT', 25),
#  (Decimal('8'), Decimal('28'), 'AGG. ASSAULT', 25),
#  (Decimal('8'), Decimal('29'), 'AGG. ASSAULT', 6),
#  (Decimal('8'), Decimal('30'), 'AGG. ASSAULT', 10),
#  (Decimal('8'), Decimal('31'), 'AGG. ASSAULT', 28),
#  (Decimal('9'), Decimal('1'), 'AGG. ASSAULT', 15),
#  (Decimal('9'), Decimal('2'), 'AGG. ASSAULT', 17),
#  (Decimal('9'), Decimal('3'), 'AGG. ASSAULT', 20),
#  (Decimal('9'), Decimal('4'), 'AGG. ASSAULT', 14),
#  (Decimal('9'), Decimal('5'), 'AGG. ASSAULT', 16),
#  (Decimal('9'), Decimal('6'), 'AGG. ASSAULT', 17),
#  (Decimal('9'), Decimal('7'), 'AGG. ASSAULT', 19),
#  (Decimal('9'), Decimal('8'), 'AGG. ASSAULT', 13),
#  (Decimal('9'), Decimal('9'), 'AGG. ASSAULT', 14),
#  (Decimal('9'), Decimal('10'), 'AGG. ASSAULT', 11),
#  (Decimal('9'), Decimal('11'), 'AGG. ASSAULT', 26),
#  (Decimal('9'), Decimal('12'), 'AGG. ASSAULT', 17),
#  (Decimal('9'), Decimal('13'), 'AGG. ASSAULT', 24),
#  (Decimal('9'), Decimal('14'), 'AGG. ASSAULT', 13),
#  (Decimal('9'), Decimal('15'), 'AGG. ASSAULT', 10),
#  (Decimal('9'), Decimal('16'), 'AGG. ASSAULT', 13),
#  (Decimal('9'), Decimal('17'), 'AGG. ASSAULT', 19),
#  (Decimal('9'), Decimal('18'), 'AGG. ASSAULT', 13),
#  (Decimal('9'), Decimal('19'), 'AGG. ASSAULT', 11),
#  (Decimal('9'), Decimal('20'), 'AGG. ASSAULT', 9),
#  (Decimal('9'), Decimal('21'), 'AGG. ASSAULT', 11),
#  (Decimal('9'), Decimal('22'), 'AGG. ASSAULT', 18),
#  (Decimal('9'), Decimal('23'), 'AGG. ASSAULT', 18),
#  (Decimal('9'), Decimal('24'), 'AGG. ASSAULT', 34),
#  (Decimal('9'), Decimal('25'), 'AGG. ASSAULT', 28),
#  (Decimal('9'), Decimal('26'), 'AGG. ASSAULT', 12),
#  (Decimal('9'), Decimal('27'), 'AGG. ASSAULT', 19),
#  (Decimal('9'), Decimal('28'), 'AGG. ASSAULT', 12),
#  (Decimal('9'), Decimal('29'), 'AGG. ASSAULT', 3),
#  (Decimal('9'), Decimal('30'), 'AGG. ASSAULT', 17),
#  (Decimal('10'), Decimal('1'), 'AGG. ASSAULT', 11),
#  (Decimal('10'), Decimal('2'), 'AGG. ASSAULT', 12),
#  (Decimal('10'), Decimal('3'), 'AGG. ASSAULT', 13),
#  (Decimal('10'), Decimal('4'), 'AGG. ASSAULT', 11),
#  (Decimal('10'), Decimal('5'), 'AGG. ASSAULT', 15),
#  (Decimal('10'), Decimal('6'), 'AGG. ASSAULT', 7),
#  (Decimal('10'), Decimal('7'), 'AGG. ASSAULT', 12),
#  (Decimal('10'), Decimal('8'), 'AGG. ASSAULT', 18),
#  (Decimal('10'), Decimal('9'), 'AGG. ASSAULT', 18),
#  (Decimal('10'), Decimal('10'), 'AGG. ASSAULT', 15),
#  (Decimal('10'), Decimal('11'), 'AGG. ASSAULT', 16),
#  (Decimal('10'), Decimal('12'), 'AGG. ASSAULT', 14),
#  (Decimal('10'), Decimal('13'), 'AGG. ASSAULT', 13),
#  (Decimal('10'), Decimal('14'), 'AGG. ASSAULT', 14),
#  (Decimal('10'), Decimal('15'), 'AGG. ASSAULT', 22),
#  (Decimal('10'), Decimal('16'), 'AGG. ASSAULT', 8),
#  (Decimal('10'), Decimal('17'), 'AGG. ASSAULT', 19),
#  (Decimal('10'), Decimal('18'), 'AGG. ASSAULT', 13),
#  (Decimal('10'), Decimal('19'), 'AGG. ASSAULT', 7),
#  (Decimal('10'), Decimal('20'), 'AGG. ASSAULT', 14),
#  (Decimal('10'), Decimal('21'), 'AGG. ASSAULT', 12),
#  (Decimal('10'), Decimal('22'), 'AGG. ASSAULT', 10),
#  (Decimal('10'), Decimal('23'), 'AGG. ASSAULT', 15),
#  (Decimal('10'), Decimal('24'), 'AGG. ASSAULT', 15),
#  (Decimal('10'), Decimal('25'), 'AGG. ASSAULT', 11),
#  (Decimal('10'), Decimal('26'), 'AGG. ASSAULT', 15),
#  (Decimal('10'), Decimal('27'), 'AGG. ASSAULT', 10),
#  (Decimal('10'), Decimal('28'), 'AGG. ASSAULT', 13),
#  (Decimal('10'), Decimal('29'), 'AGG. ASSAULT', 13),
#  (Decimal('1'), Decimal('1'), 'ARSON', 2),
#  (Decimal('1'), Decimal('5'), 'ARSON', 1),
#  (Decimal('1'), Decimal('7'), 'ARSON', 2),
#  (Decimal('1'), Decimal('8'), 'ARSON', 1),
#  (Decimal('1'), Decimal('9'), 'ARSON', 1),
#  (Decimal('1'), Decimal('12'), 'ARSON', 1),
#  (Decimal('1'), Decimal('15'), 'ARSON', 2),
#  (Decimal('1'), Decimal('16'), 'ARSON', 2),
#  (Decimal('1'), Decimal('18'), 'ARSON', 1),
#  (Decimal('1'), Decimal('25'), 'ARSON', 1),
#  (Decimal('1'), Decimal('31'), 'ARSON', 1),
#  (Decimal('2'), Decimal('1'), 'ARSON', 1),
#  (Decimal('2'), Decimal('2'), 'ARSON', 1),
#  (Decimal('2'), Decimal('9'), 'ARSON', 1),
#  (Decimal('2'), Decimal('10'), 'ARSON', 1),
#  (Decimal('2'), Decimal('14'), 'ARSON', 1),
#  (Decimal('2'), Decimal('17'), 'ARSON', 1),
#  (Decimal('2'), Decimal('19'), 'ARSON', 2),
#  (Decimal('2'), Decimal('22'), 'ARSON', 2),
#  (Decimal('2'), Decimal('23'), 'ARSON', 3),
#  (Decimal('2'), Decimal('29'), 'ARSON', 1),
#  (Decimal('3'), Decimal('2'), 'ARSON', 1),
#  (Decimal('3'), Decimal('6'), 'ARSON', 1),
#  (Decimal('3'), Decimal('8'), 'ARSON', 1),
#  (Decimal('3'), Decimal('10'), 'ARSON', 2),
#  (Decimal('3'), Decimal('12'), 'ARSON', 1),
#  (Decimal('3'), Decimal('14'), 'ARSON', 1),
#  (Decimal('3'), Decimal('16'), 'ARSON', 1),
#  (Decimal('3'), Decimal('18'), 'ARSON', 1),
#  (Decimal('3'), Decimal('20'), 'ARSON', 1),
#  (Decimal('3'), Decimal('22'), 'ARSON', 1),
#  (Decimal('3'), Decimal('26'), 'ARSON', 1),
#  (Decimal('3'), Decimal('27'), 'ARSON', 1),
#  (Decimal('3'), Decimal('28'), 'ARSON', 1),
#  (Decimal('3'), Decimal('29'), 'ARSON', 1),
#  (Decimal('3'), Decimal('30'), 'ARSON', 1),
#  (Decimal('4'), Decimal('4'), 'ARSON', 1),
#  (Decimal('4'), Decimal('5'), 'ARSON', 1),
#  (Decimal('4'), Decimal('6'), 'ARSON', 1),
#  (Decimal('4'), Decimal('7'), 'ARSON', 1),
#  (Decimal('4'), Decimal('9'), 'ARSON', 1),
#  (Decimal('4'), Decimal('10'), 'ARSON', 1),
#  (Decimal('4'), Decimal('12'), 'ARSON', 2),
#  (Decimal('4'), Decimal('13'), 'ARSON', 1),
#  (Decimal('4'), Decimal('15'), 'ARSON', 1),
#  (Decimal('4'), Decimal('16'), 'ARSON', 1),
#  (Decimal('4'), Decimal('17'), 'ARSON', 2),
#  (Decimal('4'), Decimal('19'), 'ARSON', 1),
#  (Decimal('4'), Decimal('20'), 'ARSON', 1),
#  (Decimal('4'), Decimal('21'), 'ARSON', 3),
#  (Decimal('4'), Decimal('22'), 'ARSON', 1),
#  (Decimal('4'), Decimal('23'), 'ARSON', 1),
#  (Decimal('4'), Decimal('24'), 'ARSON', 2),
#  (Decimal('4'), Decimal('26'), 'ARSON', 2),
#  (Decimal('4'), Decimal('27'), 'ARSON', 2),
#  (Decimal('4'), Decimal('28'), 'ARSON', 1),
#  (Decimal('5'), Decimal('2'), 'ARSON', 2),
#  (Decimal('5'), Decimal('5'), 'ARSON', 1),
#  (Decimal('5'), Decimal('7'), 'ARSON', 1),
#  (Decimal('5'), Decimal('8'), 'ARSON', 1),
#  (Decimal('5'), Decimal('12'), 'ARSON', 1),
#  (Decimal('5'), Decimal('15'), 'ARSON', 2),
#  (Decimal('5'), Decimal('16'), 'ARSON', 2),
#  (Decimal('5'), Decimal('19'), 'ARSON', 1),
#  (Decimal('5'), Decimal('21'), 'ARSON', 1),
#  (Decimal('5'), Decimal('22'), 'ARSON', 1),
#  (Decimal('5'), Decimal('23'), 'ARSON', 1),
#  (Decimal('5'), Decimal('24'), 'ARSON', 3),
#  (Decimal('5'), Decimal('26'), 'ARSON', 1),
#  (Decimal('5'), Decimal('28'), 'ARSON', 1),
#  (Decimal('5'), Decimal('29'), 'ARSON', 1),
#  (Decimal('5'), Decimal('30'), 'ARSON', 4),
#  (Decimal('5'), Decimal('31'), 'ARSON', 3),
#  (Decimal('6'), Decimal('1'), 'ARSON', 1),
#  (Decimal('6'), Decimal('2'), 'ARSON', 1),
#  (Decimal('6'), Decimal('3'), 'ARSON', 1),
#  (Decimal('6'), Decimal('5'), 'ARSON', 2),
#  (Decimal('6'), Decimal('6'), 'ARSON', 1),
#  (Decimal('6'), Decimal('9'), 'ARSON', 1),
#  (Decimal('6'), Decimal('10'), 'ARSON', 1),
#  (Decimal('6'), Decimal('11'), 'ARSON', 1),
#  (Decimal('6'), Decimal('12'), 'ARSON', 1),
#  (Decimal('6'), Decimal('15'), 'ARSON', 2),
#  (Decimal('6'), Decimal('16'), 'ARSON', 1),
#  (Decimal('6'), Decimal('18'), 'ARSON', 1),
#  (Decimal('6'), Decimal('19'), 'ARSON', 1),
#  (Decimal('6'), Decimal('20'), 'ARSON', 2),
#  (Decimal('6'), Decimal('21'), 'ARSON', 3),
#  (Decimal('6'), Decimal('22'), 'ARSON', 1),
#  (Decimal('6'), Decimal('23'), 'ARSON', 1),
#  (Decimal('6'), Decimal('25'), 'ARSON', 1),
#  (Decimal('6'), Decimal('26'), 'ARSON', 1),
#  (Decimal('6'), Decimal('27'), 'ARSON', 2),
#  (Decimal('6'), Decimal('28'), 'ARSON', 2),
#  (Decimal('6'), Decimal('29'), 'ARSON', 3),
#  (Decimal('6'), Decimal('30'), 'ARSON', 1),
#  (Decimal('7'), Decimal('2'), 'ARSON', 1),
#  (Decimal('7'), Decimal('3'), 'ARSON', 1),
#  (Decimal('7'), Decimal('7'), 'ARSON', 2),
#  (Decimal('7'), Decimal('9'), 'ARSON', 1),
#  (Decimal('7'), Decimal('12'), 'ARSON', 4),
#  (Decimal('7'), Decimal('13'), 'ARSON', 2),
#  (Decimal('7'), Decimal('14'), 'ARSON', 3),
#  (Decimal('7'), Decimal('17'), 'ARSON', 3),
#  (Decimal('7'), Decimal('21'), 'ARSON', 2),
#  (Decimal('7'), Decimal('23'), 'ARSON', 1),
#  (Decimal('7'), Decimal('25'), 'ARSON', 2),
#  (Decimal('7'), Decimal('28'), 'ARSON', 1),
#  (Decimal('8'), Decimal('3'), 'ARSON', 2),
#  (Decimal('8'), Decimal('4'), 'ARSON', 1),
#  (Decimal('8'), Decimal('7'), 'ARSON', 2),
#  (Decimal('8'), Decimal('8'), 'ARSON', 1),
#  (Decimal('8'), Decimal('9'), 'ARSON', 1),
#  (Decimal('8'), Decimal('13'), 'ARSON', 1),
#  (Decimal('8'), Decimal('15'), 'ARSON', 1),
#  (Decimal('8'), Decimal('17'), 'ARSON', 1),
#  (Decimal('8'), Decimal('19'), 'ARSON', 1),
#  (Decimal('8'), Decimal('21'), 'ARSON', 1),
#  (Decimal('8'), Decimal('24'), 'ARSON', 2),
#  (Decimal('8'), Decimal('27'), 'ARSON', 1),
#  (Decimal('8'), Decimal('28'), 'ARSON', 1),
#  (Decimal('9'), Decimal('3'), 'ARSON', 1),
#  (Decimal('9'), Decimal('4'), 'ARSON', 1),
#  (Decimal('9'), Decimal('6'), 'ARSON', 1),
#  (Decimal('9'), Decimal('9'), 'ARSON', 1),
#  (Decimal('9'), Decimal('10'), 'ARSON', 1),
#  (Decimal('9'), Decimal('12'), 'ARSON', 1),
#  (Decimal('9'), Decimal('14'), 'ARSON', 1),
#  (Decimal('9'), Decimal('15'), 'ARSON', 1),
#  (Decimal('9'), Decimal('16'), 'ARSON', 1),
#  (Decimal('9'), Decimal('17'), 'ARSON', 2),
#  (Decimal('9'), Decimal('18'), 'ARSON', 1),
#  (Decimal('9'), Decimal('19'), 'ARSON', 1),
#  (Decimal('9'), Decimal('21'), 'ARSON', 1),
#  (Decimal('9'), Decimal('22'), 'ARSON', 1),
#  (Decimal('9'), Decimal('23'), 'ARSON', 1),
#  (Decimal('9'), Decimal('26'), 'ARSON', 1),
#  (Decimal('9'), Decimal('27'), 'ARSON', 3),
#  (Decimal('9'), Decimal('28'), 'ARSON', 1),
#  (Decimal('9'), Decimal('29'), 'ARSON', 3),
#  (Decimal('10'), Decimal('1'), 'ARSON', 1),
#  (Decimal('10'), Decimal('2'), 'ARSON', 1),
#  (Decimal('10'), Decimal('5'), 'ARSON', 1),
#  (Decimal('10'), Decimal('6'), 'ARSON', 3),
#  (Decimal('10'), Decimal('7'), 'ARSON', 1),
#  (Decimal('10'), Decimal('8'), 'ARSON', 2),
#  (Decimal('10'), Decimal('9'), 'ARSON', 3),
#  (Decimal('10'), Decimal('10'), 'ARSON', 2),
#  (Decimal('10'), Decimal('13'), 'ARSON', 2),
#  (Decimal('10'), Decimal('14'), 'ARSON', 1),
#  (Decimal('10'), Decimal('15'), 'ARSON', 1),
#  (Decimal('10'), Decimal('20'), 'ARSON', 1),
#  (Decimal('10'), Decimal('23'), 'ARSON', 1),
#  (Decimal('1'), Decimal('2'), 'ASSAULT BY THREAT', 3),
#  (Decimal('1'), Decimal('5'), 'ASSAULT BY THREAT', 3),
#  (Decimal('1'), Decimal('6'), 'ASSAULT BY THREAT', 3),
#  (Decimal('1'), Decimal('7'), 'ASSAULT BY THREAT', 4),
#  (Decimal('1'), Decimal('8'), 'ASSAULT BY THREAT', 1),
#  (Decimal('1'), Decimal('11'), 'ASSAULT BY THREAT', 1),
#  (Decimal('1'), Decimal('12'), 'ASSAULT BY THREAT', 1),
#  (Decimal('1'), Decimal('13'), 'ASSAULT BY THREAT', 2),
#  (Decimal('1'), Decimal('14'), 'ASSAULT BY THREAT', 2),
#  (Decimal('1'), Decimal('15'), 'ASSAULT BY THREAT', 1),
#  (Decimal('1'), Decimal('16'), 'ASSAULT BY THREAT', 1),
#  (Decimal('1'), Decimal('17'), 'ASSAULT BY THREAT', 1),
#  (Decimal('1'), Decimal('19'), 'ASSAULT BY THREAT', 2),
#  (Decimal('1'), Decimal('21'), 'ASSAULT BY THREAT', 4),
#  (Decimal('1'), Decimal('22'), 'ASSAULT BY THREAT', 1),
#  (Decimal('1'), Decimal('23'), 'ASSAULT BY THREAT', 1),
#  (Decimal('1'), Decimal('24'), 'ASSAULT BY THREAT', 3),
#  (Decimal('1'), Decimal('25'), 'ASSAULT BY THREAT', 1),
#  (Decimal('1'), Decimal('27'), 'ASSAULT BY THREAT', 2),
#  (Decimal('1'), Decimal('29'), 'ASSAULT BY THREAT', 2),
#  (Decimal('1'), Decimal('30'), 'ASSAULT BY THREAT', 2),
#  (Decimal('1'), Decimal('31'), 'ASSAULT BY THREAT', 3),
#  (Decimal('2'), Decimal('1'), 'ASSAULT BY THREAT', 1),
#  (Decimal('2'), Decimal('2'), 'ASSAULT BY THREAT', 3),
#  (Decimal('2'), Decimal('3'), 'ASSAULT BY THREAT', 1),
#  (Decimal('2'), Decimal('4'), 'ASSAULT BY THREAT', 2),
#  (Decimal('2'), Decimal('5'), 'ASSAULT BY THREAT', 2),
#  (Decimal('2'), Decimal('6'), 'ASSAULT BY THREAT', 3),
#  (Decimal('2'), Decimal('7'), 'ASSAULT BY THREAT', 2),
#  (Decimal('2'), Decimal('8'), 'ASSAULT BY THREAT', 1),
#  (Decimal('2'), Decimal('10'), 'ASSAULT BY THREAT', 1),
#  (Decimal('2'), Decimal('12'), 'ASSAULT BY THREAT', 1),
#  (Decimal('2'), Decimal('14'), 'ASSAULT BY THREAT', 1),
#  (Decimal('2'), Decimal('16'), 'ASSAULT BY THREAT', 2),
#  (Decimal('2'), Decimal('17'), 'ASSAULT BY THREAT', 4),
#  (Decimal('2'), Decimal('18'), 'ASSAULT BY THREAT', 3),
#  (Decimal('2'), Decimal('19'), 'ASSAULT BY THREAT', 2),
#  (Decimal('2'), Decimal('20'), 'ASSAULT BY THREAT', 1),
#  (Decimal('2'), Decimal('21'), 'ASSAULT BY THREAT', 2),
#  (Decimal('2'), Decimal('22'), 'ASSAULT BY THREAT', 1),
#  (Decimal('2'), Decimal('23'), 'ASSAULT BY THREAT', 1),
#  (Decimal('2'), Decimal('24'), 'ASSAULT BY THREAT', 5),
#  (Decimal('2'), Decimal('27'), 'ASSAULT BY THREAT', 1),
#  (Decimal('2'), Decimal('29'), 'ASSAULT BY THREAT', 2),
#  (Decimal('3'), Decimal('1'), 'ASSAULT BY THREAT', 1),
#  (Decimal('3'), Decimal('2'), 'ASSAULT BY THREAT', 3),
#  (Decimal('3'), Decimal('3'), 'ASSAULT BY THREAT', 4),
#  (Decimal('3'), Decimal('4'), 'ASSAULT BY THREAT', 1),
#  (Decimal('3'), Decimal('8'), 'ASSAULT BY THREAT', 1),
#  (Decimal('3'), Decimal('9'), 'ASSAULT BY THREAT', 2),
#  (Decimal('3'), Decimal('10'), 'ASSAULT BY THREAT', 1),
#  (Decimal('3'), Decimal('11'), 'ASSAULT BY THREAT', 2),
#  (Decimal('3'), Decimal('12'), 'ASSAULT BY THREAT', 1),
#  (Decimal('3'), Decimal('13'), 'ASSAULT BY THREAT', 2),
#  (Decimal('3'), Decimal('14'), 'ASSAULT BY THREAT', 2),
#  (Decimal('3'), Decimal('15'), 'ASSAULT BY THREAT', 3),
#  (Decimal('3'), Decimal('16'), 'ASSAULT BY THREAT', 4),
#  (Decimal('3'), Decimal('17'), 'ASSAULT BY THREAT', 3),
#  (Decimal('3'), Decimal('21'), 'ASSAULT BY THREAT', 2),
#  (Decimal('3'), Decimal('22'), 'ASSAULT BY THREAT', 2),
#  (Decimal('3'), Decimal('24'), 'ASSAULT BY THREAT', 5),
#  (Decimal('3'), Decimal('28'), 'ASSAULT BY THREAT', 1),
#  (Decimal('3'), Decimal('29'), 'ASSAULT BY THREAT', 1),
#  (Decimal('3'), Decimal('30'), 'ASSAULT BY THREAT', 1),
#  (Decimal('3'), Decimal('31'), 'ASSAULT BY THREAT', 2),
#  (Decimal('4'), Decimal('1'), 'ASSAULT BY THREAT', 1),
#  (Decimal('4'), Decimal('3'), 'ASSAULT BY THREAT', 3),
#  (Decimal('4'), Decimal('4'), 'ASSAULT BY THREAT', 3),
#  (Decimal('4'), Decimal('5'), 'ASSAULT BY THREAT', 1),
#  (Decimal('4'), Decimal('6'), 'ASSAULT BY THREAT', 2),
#  (Decimal('4'), Decimal('8'), 'ASSAULT BY THREAT', 4),
#  (Decimal('4'), Decimal('9'), 'ASSAULT BY THREAT', 3),
#  (Decimal('4'), Decimal('11'), 'ASSAULT BY THREAT', 3),
#  (Decimal('4'), Decimal('12'), 'ASSAULT BY THREAT', 1),
#  (Decimal('4'), Decimal('14'), 'ASSAULT BY THREAT', 2),
#  (Decimal('4'), Decimal('16'), 'ASSAULT BY THREAT', 3),
#  (Decimal('4'), Decimal('18'), 'ASSAULT BY THREAT', 1),
#  (Decimal('4'), Decimal('20'), 'ASSAULT BY THREAT', 1),
#  (Decimal('4'), Decimal('21'), 'ASSAULT BY THREAT', 1),
#  (Decimal('4'), Decimal('24'), 'ASSAULT BY THREAT', 1),
#  (Decimal('4'), Decimal('26'), 'ASSAULT BY THREAT', 2),
#  (Decimal('4'), Decimal('27'), 'ASSAULT BY THREAT', 4),
#  (Decimal('4'), Decimal('28'), 'ASSAULT BY THREAT', 2),
#  (Decimal('4'), Decimal('29'), 'ASSAULT BY THREAT', 2),
#  (Decimal('5'), Decimal('2'), 'ASSAULT BY THREAT', 1),
#  (Decimal('5'), Decimal('3'), 'ASSAULT BY THREAT', 2),
#  (Decimal('5'), Decimal('5'), 'ASSAULT BY THREAT', 1),
#  (Decimal('5'), Decimal('6'), 'ASSAULT BY THREAT', 2),
#  (Decimal('5'), Decimal('7'), 'ASSAULT BY THREAT', 1),
#  (Decimal('5'), Decimal('8'), 'ASSAULT BY THREAT', 1),
#  (Decimal('5'), Decimal('9'), 'ASSAULT BY THREAT', 3),
#  (Decimal('5'), Decimal('10'), 'ASSAULT BY THREAT', 2),
#  (Decimal('5'), Decimal('11'), 'ASSAULT BY THREAT', 3),
#  (Decimal('5'), Decimal('12'), 'ASSAULT BY THREAT', 1),
#  (Decimal('5'), Decimal('13'), 'ASSAULT BY THREAT', 2),
#  (Decimal('5'), Decimal('14'), 'ASSAULT BY THREAT', 1),
#  (Decimal('5'), Decimal('16'), 'ASSAULT BY THREAT', 3),
#  (Decimal('5'), Decimal('17'), 'ASSAULT BY THREAT', 1),
#  (Decimal('5'), Decimal('18'), 'ASSAULT BY THREAT', 1),
#  (Decimal('5'), Decimal('19'), 'ASSAULT BY THREAT', 2),
#  (Decimal('5'), Decimal('21'), 'ASSAULT BY THREAT', 3),
#  (Decimal('5'), Decimal('22'), 'ASSAULT BY THREAT', 1),
#  (Decimal('5'), Decimal('25'), 'ASSAULT BY THREAT', 1),
#  (Decimal('5'), Decimal('26'), 'ASSAULT BY THREAT', 1),
#  (Decimal('5'), Decimal('28'), 'ASSAULT BY THREAT', 1),
#  (Decimal('5'), Decimal('29'), 'ASSAULT BY THREAT', 1),
#  (Decimal('5'), Decimal('31'), 'ASSAULT BY THREAT', 5),
#  (Decimal('6'), Decimal('1'), 'ASSAULT BY THREAT', 2),
#  (Decimal('6'), Decimal('2'), 'ASSAULT BY THREAT', 2),
#  (Decimal('6'), Decimal('3'), 'ASSAULT BY THREAT', 3),
#  (Decimal('6'), Decimal('4'), 'ASSAULT BY THREAT', 2),
#  (Decimal('6'), Decimal('5'), 'ASSAULT BY THREAT', 1),
#  (Decimal('6'), Decimal('6'), 'ASSAULT BY THREAT', 2),
#  (Decimal('6'), Decimal('7'), 'ASSAULT BY THREAT', 1),
#  (Decimal('6'), Decimal('8'), 'ASSAULT BY THREAT', 1),
#  (Decimal('6'), Decimal('9'), 'ASSAULT BY THREAT', 2),
#  (Decimal('6'), Decimal('10'), 'ASSAULT BY THREAT', 5),
#  (Decimal('6'), Decimal('14'), 'ASSAULT BY THREAT', 3),
#  (Decimal('6'), Decimal('15'), 'ASSAULT BY THREAT', 2),
#  (Decimal('6'), Decimal('16'), 'ASSAULT BY THREAT', 3),
#  (Decimal('6'), Decimal('17'), 'ASSAULT BY THREAT', 3),
#  (Decimal('6'), Decimal('18'), 'ASSAULT BY THREAT', 5),
#  (Decimal('6'), Decimal('20'), 'ASSAULT BY THREAT', 1),
#  (Decimal('6'), Decimal('22'), 'ASSAULT BY THREAT', 3),
#  (Decimal('6'), Decimal('24'), 'ASSAULT BY THREAT', 1),
#  (Decimal('6'), Decimal('25'), 'ASSAULT BY THREAT', 1),
#  (Decimal('6'), Decimal('26'), 'ASSAULT BY THREAT', 1),
#  (Decimal('6'), Decimal('27'), 'ASSAULT BY THREAT', 2),
#  (Decimal('6'), Decimal('29'), 'ASSAULT BY THREAT', 3),
#  (Decimal('7'), Decimal('1'), 'ASSAULT BY THREAT', 1),
#  (Decimal('7'), Decimal('2'), 'ASSAULT BY THREAT', 4),
#  (Decimal('7'), Decimal('4'), 'ASSAULT BY THREAT', 1),
#  (Decimal('7'), Decimal('5'), 'ASSAULT BY THREAT', 4),
#  (Decimal('7'), Decimal('9'), 'ASSAULT BY THREAT', 3),
#  (Decimal('7'), Decimal('10'), 'ASSAULT BY THREAT', 3),
#  (Decimal('7'), Decimal('11'), 'ASSAULT BY THREAT', 2),
#  (Decimal('7'), Decimal('12'), 'ASSAULT BY THREAT', 3),
#  (Decimal('7'), Decimal('13'), 'ASSAULT BY THREAT', 1),
#  (Decimal('7'), Decimal('14'), 'ASSAULT BY THREAT', 2),
#  (Decimal('7'), Decimal('16'), 'ASSAULT BY THREAT', 1),
#  (Decimal('7'), Decimal('18'), 'ASSAULT BY THREAT', 2),
#  (Decimal('7'), Decimal('19'), 'ASSAULT BY THREAT', 2),
#  (Decimal('7'), Decimal('20'), 'ASSAULT BY THREAT', 1),
#  (Decimal('7'), Decimal('21'), 'ASSAULT BY THREAT', 2),
#  (Decimal('7'), Decimal('22'), 'ASSAULT BY THREAT', 3),
#  (Decimal('7'), Decimal('23'), 'ASSAULT BY THREAT', 3),
#  (Decimal('7'), Decimal('24'), 'ASSAULT BY THREAT', 2),
#  (Decimal('7'), Decimal('25'), 'ASSAULT BY THREAT', 2),
#  (Decimal('7'), Decimal('26'), 'ASSAULT BY THREAT', 1),
#  (Decimal('7'), Decimal('28'), 'ASSAULT BY THREAT', 1),
#  (Decimal('7'), Decimal('29'), 'ASSAULT BY THREAT', 1),
#  (Decimal('7'), Decimal('30'), 'ASSAULT BY THREAT', 5),
#  (Decimal('7'), Decimal('31'), 'ASSAULT BY THREAT', 3),
#  (Decimal('8'), Decimal('2'), 'ASSAULT BY THREAT', 1),
#  (Decimal('8'), Decimal('3'), 'ASSAULT BY THREAT', 1),
#  (Decimal('8'), Decimal('5'), 'ASSAULT BY THREAT', 4),
#  (Decimal('8'), Decimal('6'), 'ASSAULT BY THREAT', 1),
#  (Decimal('8'), Decimal('8'), 'ASSAULT BY THREAT', 2),
#  (Decimal('8'), Decimal('9'), 'ASSAULT BY THREAT', 1),
#  (Decimal('8'), Decimal('11'), 'ASSAULT BY THREAT', 1),
#  (Decimal('8'), Decimal('12'), 'ASSAULT BY THREAT', 1),
#  (Decimal('8'), Decimal('14'), 'ASSAULT BY THREAT', 3),
#  (Decimal('8'), Decimal('15'), 'ASSAULT BY THREAT', 3),
#  (Decimal('8'), Decimal('16'), 'ASSAULT BY THREAT', 4),
#  (Decimal('8'), Decimal('18'), 'ASSAULT BY THREAT', 1),
#  (Decimal('8'), Decimal('19'), 'ASSAULT BY THREAT', 3),
#  (Decimal('8'), Decimal('20'), 'ASSAULT BY THREAT', 2),
#  (Decimal('8'), Decimal('21'), 'ASSAULT BY THREAT', 4),
#  (Decimal('8'), Decimal('22'), 'ASSAULT BY THREAT', 1),
#  (Decimal('8'), Decimal('23'), 'ASSAULT BY THREAT', 1),
#  (Decimal('8'), Decimal('24'), 'ASSAULT BY THREAT', 4),
#  (Decimal('8'), Decimal('25'), 'ASSAULT BY THREAT', 1),
#  (Decimal('8'), Decimal('26'), 'ASSAULT BY THREAT', 2),
#  (Decimal('8'), Decimal('27'), 'ASSAULT BY THREAT', 2),
#  (Decimal('8'), Decimal('28'), 'ASSAULT BY THREAT', 2),
#  (Decimal('8'), Decimal('30'), 'ASSAULT BY THREAT', 2),
#  (Decimal('8'), Decimal('31'), 'ASSAULT BY THREAT', 1),
#  (Decimal('9'), Decimal('1'), 'ASSAULT BY THREAT', 5),
#  (Decimal('9'), Decimal('2'), 'ASSAULT BY THREAT', 1),
#  (Decimal('9'), Decimal('3'), 'ASSAULT BY THREAT', 3),
#  (Decimal('9'), Decimal('5'), 'ASSAULT BY THREAT', 2),
#  (Decimal('9'), Decimal('6'), 'ASSAULT BY THREAT', 4),
#  (Decimal('9'), Decimal('9'), 'ASSAULT BY THREAT', 2),
#  (Decimal('9'), Decimal('10'), 'ASSAULT BY THREAT', 2),
#  (Decimal('9'), Decimal('11'), 'ASSAULT BY THREAT', 1),
#  (Decimal('9'), Decimal('12'), 'ASSAULT BY THREAT', 2),
#  (Decimal('9'), Decimal('13'), 'ASSAULT BY THREAT', 2),
#  (Decimal('9'), Decimal('14'), 'ASSAULT BY THREAT', 5),
#  (Decimal('9'), Decimal('16'), 'ASSAULT BY THREAT', 4),
#  (Decimal('9'), Decimal('17'), 'ASSAULT BY THREAT', 4),
#  (Decimal('9'), Decimal('18'), 'ASSAULT BY THREAT', 3),
#  (Decimal('9'), Decimal('19'), 'ASSAULT BY THREAT', 1),
#  (Decimal('9'), Decimal('20'), 'ASSAULT BY THREAT', 1),
#  (Decimal('9'), Decimal('21'), 'ASSAULT BY THREAT', 5),
#  (Decimal('9'), Decimal('22'), 'ASSAULT BY THREAT', 3),
#  (Decimal('9'), Decimal('24'), 'ASSAULT BY THREAT', 2),
#  (Decimal('9'), Decimal('26'), 'ASSAULT BY THREAT', 4),
#  (Decimal('9'), Decimal('27'), 'ASSAULT BY THREAT', 1),
#  (Decimal('9'), Decimal('28'), 'ASSAULT BY THREAT', 1),
#  (Decimal('9'), Decimal('29'), 'ASSAULT BY THREAT', 1),
#  (Decimal('9'), Decimal('30'), 'ASSAULT BY THREAT', 1),
#  (Decimal('10'), Decimal('1'), 'ASSAULT BY THREAT', 2),
#  (Decimal('10'), Decimal('2'), 'ASSAULT BY THREAT', 2),
#  (Decimal('10'), Decimal('3'), 'ASSAULT BY THREAT', 5),
#  (Decimal('10'), Decimal('4'), 'ASSAULT BY THREAT', 5),
#  (Decimal('10'), Decimal('5'), 'ASSAULT BY THREAT', 7),
#  (Decimal('10'), Decimal('7'), 'ASSAULT BY THREAT', 3),
#  (Decimal('10'), Decimal('8'), 'ASSAULT BY THREAT', 1),
#  (Decimal('10'), Decimal('9'), 'ASSAULT BY THREAT', 1),
#  (Decimal('10'), Decimal('10'), 'ASSAULT BY THREAT', 5),
#  (Decimal('10'), Decimal('11'), 'ASSAULT BY THREAT', 6),
#  (Decimal('10'), Decimal('12'), 'ASSAULT BY THREAT', 1),
#  (Decimal('10'), Decimal('14'), 'ASSAULT BY THREAT', 2),
#  (Decimal('10'), Decimal('15'), 'ASSAULT BY THREAT', 1),
#  (Decimal('10'), Decimal('17'), 'ASSAULT BY THREAT', 5),
#  (Decimal('10'), Decimal('18'), 'ASSAULT BY THREAT', 4),
#  (Decimal('10'), Decimal('19'), 'ASSAULT BY THREAT', 1),
#  (Decimal('10'), Decimal('20'), 'ASSAULT BY THREAT', 3),
#  (Decimal('10'), Decimal('21'), 'ASSAULT BY THREAT', 1),
#  (Decimal('10'), Decimal('24'), 'ASSAULT BY THREAT', 1),
#  (Decimal('10'), Decimal('25'), 'ASSAULT BY THREAT', 1),
#  (Decimal('10'), Decimal('26'), 'ASSAULT BY THREAT', 1),
#  (Decimal('10'), Decimal('27'), 'ASSAULT BY THREAT', 4),
#  (Decimal('10'), Decimal('28'), 'ASSAULT BY THREAT', 1),
#  (Decimal('1'), Decimal('1'), 'AUTO THEFT', 18),
#  (Decimal('1'), Decimal('2'), 'AUTO THEFT', 9),
#  (Decimal('1'), Decimal('3'), 'AUTO THEFT', 13),
#  (Decimal('1'), Decimal('4'), 'AUTO THEFT', 21),
#  (Decimal('1'), Decimal('5'), 'AUTO THEFT', 20),
#  (Decimal('1'), Decimal('6'), 'AUTO THEFT', 18),
#  (Decimal('1'), Decimal('7'), 'AUTO THEFT', 9),
#  (Decimal('1'), Decimal('8'), 'AUTO THEFT', 15),
#  (Decimal('1'), Decimal('9'), 'AUTO THEFT', 21),
#  (Decimal('1'), Decimal('10'), 'AUTO THEFT', 15),
#  (Decimal('1'), Decimal('11'), 'AUTO THEFT', 19),
#  (Decimal('1'), Decimal('12'), 'AUTO THEFT', 14),
#  (Decimal('1'), Decimal('13'), 'AUTO THEFT', 24),
#  (Decimal('1'), Decimal('14'), 'AUTO THEFT', 16),
#  (Decimal('1'), Decimal('15'), 'AUTO THEFT', 11),
#  (Decimal('1'), Decimal('16'), 'AUTO THEFT', 14),
#  (Decimal('1'), Decimal('17'), 'AUTO THEFT', 20),
#  (Decimal('1'), Decimal('18'), 'AUTO THEFT', 18),
#  (Decimal('1'), Decimal('19'), 'AUTO THEFT', 18),
#  (Decimal('1'), Decimal('20'), 'AUTO THEFT', 10),
#  (Decimal('1'), Decimal('21'), 'AUTO THEFT', 14),
#  (Decimal('1'), Decimal('22'), 'AUTO THEFT', 15),
#  (Decimal('1'), Decimal('23'), 'AUTO THEFT', 6),
#  (Decimal('1'), Decimal('24'), 'AUTO THEFT', 7),
#  (Decimal('1'), Decimal('25'), 'AUTO THEFT', 11),
#  (Decimal('1'), Decimal('26'), 'AUTO THEFT', 9),
#  (Decimal('1'), Decimal('27'), 'AUTO THEFT', 12),
#  (Decimal('1'), Decimal('28'), 'AUTO THEFT', 15),
#  (Decimal('1'), Decimal('29'), 'AUTO THEFT', 16),
#  (Decimal('1'), Decimal('30'), 'AUTO THEFT', 8),
#  (Decimal('1'), Decimal('31'), 'AUTO THEFT', 16),
#  (Decimal('2'), Decimal('1'), 'AUTO THEFT', 4),
#  (Decimal('2'), Decimal('2'), 'AUTO THEFT', 13),
#  (Decimal('2'), Decimal('3'), 'AUTO THEFT', 13),
#  (Decimal('2'), Decimal('4'), 'AUTO THEFT', 8),
#  (Decimal('2'), Decimal('5'), 'AUTO THEFT', 19),
#  (Decimal('2'), Decimal('6'), 'AUTO THEFT', 11),
#  (Decimal('2'), Decimal('7'), 'AUTO THEFT', 14),
#  (Decimal('2'), Decimal('8'), 'AUTO THEFT', 13),
#  (Decimal('2'), Decimal('9'), 'AUTO THEFT', 9),
#  (Decimal('2'), Decimal('10'), 'AUTO THEFT', 12),
#  (Decimal('2'), Decimal('11'), 'AUTO THEFT', 8),
#  (Decimal('2'), Decimal('12'), 'AUTO THEFT', 14),
#  (Decimal('2'), Decimal('13'), 'AUTO THEFT', 15),
#  (Decimal('2'), Decimal('14'), 'AUTO THEFT', 10),
#  (Decimal('2'), Decimal('15'), 'AUTO THEFT', 4),
#  (Decimal('2'), Decimal('16'), 'AUTO THEFT', 17),
#  (Decimal('2'), Decimal('17'), 'AUTO THEFT', 14),
#  (Decimal('2'), Decimal('18'), 'AUTO THEFT', 10),
#  (Decimal('2'), Decimal('19'), 'AUTO THEFT', 15),
#  (Decimal('2'), Decimal('20'), 'AUTO THEFT', 14),
#  (Decimal('2'), Decimal('21'), 'AUTO THEFT', 11),
#  (Decimal('2'), Decimal('22'), 'AUTO THEFT', 17),
#  (Decimal('2'), Decimal('23'), 'AUTO THEFT', 8),
#  (Decimal('2'), Decimal('24'), 'AUTO THEFT', 9),
#  (Decimal('2'), Decimal('25'), 'AUTO THEFT', 6),
#  (Decimal('2'), Decimal('26'), 'AUTO THEFT', 8),
#  (Decimal('2'), Decimal('27'), 'AUTO THEFT', 8),
#  (Decimal('2'), Decimal('28'), 'AUTO THEFT', 11),
#  (Decimal('2'), Decimal('29'), 'AUTO THEFT', 7),
#  (Decimal('3'), Decimal('1'), 'AUTO THEFT', 10),
#  (Decimal('3'), Decimal('2'), 'AUTO THEFT', 11),
#  (Decimal('3'), Decimal('3'), 'AUTO THEFT', 7),
#  (Decimal('3'), Decimal('4'), 'AUTO THEFT', 11),
#  (Decimal('3'), Decimal('5'), 'AUTO THEFT', 13),
#  (Decimal('3'), Decimal('6'), 'AUTO THEFT', 16),
#  (Decimal('3'), Decimal('7'), 'AUTO THEFT', 18),
#  (Decimal('3'), Decimal('8'), 'AUTO THEFT', 12),
#  (Decimal('3'), Decimal('9'), 'AUTO THEFT', 15),
#  (Decimal('3'), Decimal('10'), 'AUTO THEFT', 5),
#  (Decimal('3'), Decimal('11'), 'AUTO THEFT', 12),
#  (Decimal('3'), Decimal('12'), 'AUTO THEFT', 19),
#  (Decimal('3'), Decimal('13'), 'AUTO THEFT', 13),
#  (Decimal('3'), Decimal('14'), 'AUTO THEFT', 14),
#  (Decimal('3'), Decimal('15'), 'AUTO THEFT', 11),
#  (Decimal('3'), Decimal('16'), 'AUTO THEFT', 18),
#  (Decimal('3'), Decimal('17'), 'AUTO THEFT', 13),
#  (Decimal('3'), Decimal('18'), 'AUTO THEFT', 17),
#  (Decimal('3'), Decimal('19'), 'AUTO THEFT', 9),
#  (Decimal('3'), Decimal('20'), 'AUTO THEFT', 11),
#  (Decimal('3'), Decimal('21'), 'AUTO THEFT', 17),
#  (Decimal('3'), Decimal('22'), 'AUTO THEFT', 10),
#  (Decimal('3'), Decimal('23'), 'AUTO THEFT', 19),
#  (Decimal('3'), Decimal('24'), 'AUTO THEFT', 24),
#  (Decimal('3'), Decimal('25'), 'AUTO THEFT', 14),
#  (Decimal('3'), Decimal('26'), 'AUTO THEFT', 11),
#  (Decimal('3'), Decimal('27'), 'AUTO THEFT', 17),
#  (Decimal('3'), Decimal('28'), 'AUTO THEFT', 6),
#  (Decimal('3'), Decimal('29'), 'AUTO THEFT', 9),
#  (Decimal('3'), Decimal('30'), 'AUTO THEFT', 14),
#  (Decimal('3'), Decimal('31'), 'AUTO THEFT', 8),
#  (Decimal('4'), Decimal('1'), 'AUTO THEFT', 10),
#  (Decimal('4'), Decimal('2'), 'AUTO THEFT', 13),
#  (Decimal('4'), Decimal('3'), 'AUTO THEFT', 13),
#  (Decimal('4'), Decimal('4'), 'AUTO THEFT', 9),
#  (Decimal('4'), Decimal('5'), 'AUTO THEFT', 16),
#  (Decimal('4'), Decimal('6'), 'AUTO THEFT', 17),
#  (Decimal('4'), Decimal('7'), 'AUTO THEFT', 16),
#  (Decimal('4'), Decimal('8'), 'AUTO THEFT', 13),
#  (Decimal('4'), Decimal('9'), 'AUTO THEFT', 6),
#  (Decimal('4'), Decimal('10'), 'AUTO THEFT', 9),
#  (Decimal('4'), Decimal('11'), 'AUTO THEFT', 18),
#  (Decimal('4'), Decimal('12'), 'AUTO THEFT', 15),
#  (Decimal('4'), Decimal('13'), 'AUTO THEFT', 14),
#  (Decimal('4'), Decimal('14'), 'AUTO THEFT', 12),
#  (Decimal('4'), Decimal('15'), 'AUTO THEFT', 13),
#  (Decimal('4'), Decimal('16'), 'AUTO THEFT', 9),
#  (Decimal('4'), Decimal('17'), 'AUTO THEFT', 11),
#  (Decimal('4'), Decimal('18'), 'AUTO THEFT', 12),
#  (Decimal('4'), Decimal('19'), 'AUTO THEFT', 15),
#  (Decimal('4'), Decimal('20'), 'AUTO THEFT', 13),
#  (Decimal('4'), Decimal('21'), 'AUTO THEFT', 13),
#  (Decimal('4'), Decimal('22'), 'AUTO THEFT', 12),
#  (Decimal('4'), Decimal('23'), 'AUTO THEFT', 12),
#  (Decimal('4'), Decimal('24'), 'AUTO THEFT', 15),
#  (Decimal('4'), Decimal('25'), 'AUTO THEFT', 11),
#  (Decimal('4'), Decimal('26'), 'AUTO THEFT', 10),
#  (Decimal('4'), Decimal('27'), 'AUTO THEFT', 11),
#  (Decimal('4'), Decimal('28'), 'AUTO THEFT', 16),
#  (Decimal('4'), Decimal('29'), 'AUTO THEFT', 10),
#  (Decimal('4'), Decimal('30'), 'AUTO THEFT', 9),
#  (Decimal('5'), Decimal('1'), 'AUTO THEFT', 19),
#  (Decimal('5'), Decimal('2'), 'AUTO THEFT', 14),
#  (Decimal('5'), Decimal('3'), 'AUTO THEFT', 14),
#  (Decimal('5'), Decimal('4'), 'AUTO THEFT', 17),
#  (Decimal('5'), Decimal('5'), 'AUTO THEFT', 17),
#  (Decimal('5'), Decimal('6'), 'AUTO THEFT', 10),
#  (Decimal('5'), Decimal('7'), 'AUTO THEFT', 14),
#  (Decimal('5'), Decimal('8'), 'AUTO THEFT', 12),
#  (Decimal('5'), Decimal('9'), 'AUTO THEFT', 14),
#  (Decimal('5'), Decimal('10'), 'AUTO THEFT', 11),
#  (Decimal('5'), Decimal('11'), 'AUTO THEFT', 13),
#  (Decimal('5'), Decimal('12'), 'AUTO THEFT', 15),
#  (Decimal('5'), Decimal('13'), 'AUTO THEFT', 14),
#  (Decimal('5'), Decimal('14'), 'AUTO THEFT', 8),
#  (Decimal('5'), Decimal('15'), 'AUTO THEFT', 11),
#  (Decimal('5'), Decimal('16'), 'AUTO THEFT', 9),
#  (Decimal('5'), Decimal('17'), 'AUTO THEFT', 6),
#  (Decimal('5'), Decimal('18'), 'AUTO THEFT', 9),
#  (Decimal('5'), Decimal('19'), 'AUTO THEFT', 7),
#  (Decimal('5'), Decimal('20'), 'AUTO THEFT', 13),
#  (Decimal('5'), Decimal('21'), 'AUTO THEFT', 10),
#  (Decimal('5'), Decimal('22'), 'AUTO THEFT', 18),
#  (Decimal('5'), Decimal('23'), 'AUTO THEFT', 12),
#  (Decimal('5'), Decimal('24'), 'AUTO THEFT', 15),
#  (Decimal('5'), Decimal('25'), 'AUTO THEFT', 14),
#  (Decimal('5'), Decimal('26'), 'AUTO THEFT', 17),
#  (Decimal('5'), Decimal('27'), 'AUTO THEFT', 14),
#  (Decimal('5'), Decimal('28'), 'AUTO THEFT', 17),
#  (Decimal('5'), Decimal('29'), 'AUTO THEFT', 13),
#  (Decimal('5'), Decimal('30'), 'AUTO THEFT', 22),
#  (Decimal('5'), Decimal('31'), 'AUTO THEFT', 6),
#  (Decimal('6'), Decimal('1'), 'AUTO THEFT', 6),
#  (Decimal('6'), Decimal('2'), 'AUTO THEFT', 10),
#  (Decimal('6'), Decimal('3'), 'AUTO THEFT', 15),
#  (Decimal('6'), Decimal('4'), 'AUTO THEFT', 11),
#  (Decimal('6'), Decimal('5'), 'AUTO THEFT', 14),
#  (Decimal('6'), Decimal('6'), 'AUTO THEFT', 19),
#  (Decimal('6'), Decimal('7'), 'AUTO THEFT', 22),
#  (Decimal('6'), Decimal('8'), 'AUTO THEFT', 8),
#  (Decimal('6'), Decimal('9'), 'AUTO THEFT', 10),
#  (Decimal('6'), Decimal('10'), 'AUTO THEFT', 17),
#  (Decimal('6'), Decimal('11'), 'AUTO THEFT', 8),
#  (Decimal('6'), Decimal('12'), 'AUTO THEFT', 16),
#  (Decimal('6'), Decimal('13'), 'AUTO THEFT', 16),
#  (Decimal('6'), Decimal('14'), 'AUTO THEFT', 24),
#  (Decimal('6'), Decimal('15'), 'AUTO THEFT', 19),
#  (Decimal('6'), Decimal('16'), 'AUTO THEFT', 12),
#  (Decimal('6'), Decimal('17'), 'AUTO THEFT', 15),
#  (Decimal('6'), Decimal('18'), 'AUTO THEFT', 10),
#  (Decimal('6'), Decimal('19'), 'AUTO THEFT', 7),
#  (Decimal('6'), Decimal('20'), 'AUTO THEFT', 20),
#  (Decimal('6'), Decimal('21'), 'AUTO THEFT', 10),
#  (Decimal('6'), Decimal('22'), 'AUTO THEFT', 13),
#  (Decimal('6'), Decimal('23'), 'AUTO THEFT', 17),
#  (Decimal('6'), Decimal('24'), 'AUTO THEFT', 9),
#  (Decimal('6'), Decimal('25'), 'AUTO THEFT', 24),
#  (Decimal('6'), Decimal('26'), 'AUTO THEFT', 9),
#  (Decimal('6'), Decimal('27'), 'AUTO THEFT', 11),
#  (Decimal('6'), Decimal('28'), 'AUTO THEFT', 13),
#  (Decimal('6'), Decimal('29'), 'AUTO THEFT', 20),
#  (Decimal('6'), Decimal('30'), 'AUTO THEFT', 12),
#  (Decimal('7'), Decimal('1'), 'AUTO THEFT', 10),
#  (Decimal('7'), Decimal('2'), 'AUTO THEFT', 12),
#  (Decimal('7'), Decimal('3'), 'AUTO THEFT', 25),
#  (Decimal('7'), Decimal('4'), 'AUTO THEFT', 18),
#  (Decimal('7'), Decimal('5'), 'AUTO THEFT', 12),
#  (Decimal('7'), Decimal('6'), 'AUTO THEFT', 6),
#  (Decimal('7'), Decimal('7'), 'AUTO THEFT', 12),
#  (Decimal('7'), Decimal('8'), 'AUTO THEFT', 13),
#  (Decimal('7'), Decimal('9'), 'AUTO THEFT', 9),
#  (Decimal('7'), Decimal('10'), 'AUTO THEFT', 11),
#  (Decimal('7'), Decimal('11'), 'AUTO THEFT', 14),
#  (Decimal('7'), Decimal('12'), 'AUTO THEFT', 7),
#  (Decimal('7'), Decimal('13'), 'AUTO THEFT', 13),
#  (Decimal('7'), Decimal('14'), 'AUTO THEFT', 16),
#  (Decimal('7'), Decimal('15'), 'AUTO THEFT', 5),
#  (Decimal('7'), Decimal('16'), 'AUTO THEFT', 19),
#  (Decimal('7'), Decimal('17'), 'AUTO THEFT', 16),
#  (Decimal('7'), Decimal('18'), 'AUTO THEFT', 11),
#  (Decimal('7'), Decimal('19'), 'AUTO THEFT', 20),
#  (Decimal('7'), Decimal('20'), 'AUTO THEFT', 17),
#  (Decimal('7'), Decimal('21'), 'AUTO THEFT', 17),
#  (Decimal('7'), Decimal('22'), 'AUTO THEFT', 9),
#  (Decimal('7'), Decimal('23'), 'AUTO THEFT', 20),
#  (Decimal('7'), Decimal('24'), 'AUTO THEFT', 18),
#  (Decimal('7'), Decimal('25'), 'AUTO THEFT', 15),
#  (Decimal('7'), Decimal('26'), 'AUTO THEFT', 21),
#  (Decimal('7'), Decimal('27'), 'AUTO THEFT', 18),
#  (Decimal('7'), Decimal('28'), 'AUTO THEFT', 17),
#  (Decimal('7'), Decimal('29'), 'AUTO THEFT', 19),
#  (Decimal('7'), Decimal('30'), 'AUTO THEFT', 9),
#  (Decimal('7'), Decimal('31'), 'AUTO THEFT', 12),
#  (Decimal('8'), Decimal('1'), 'AUTO THEFT', 16),
#  (Decimal('8'), Decimal('2'), 'AUTO THEFT', 17),
#  (Decimal('8'), Decimal('3'), 'AUTO THEFT', 11),
#  (Decimal('8'), Decimal('4'), 'AUTO THEFT', 11),
#  (Decimal('8'), Decimal('5'), 'AUTO THEFT', 15),
#  (Decimal('8'), Decimal('6'), 'AUTO THEFT', 20),
#  (Decimal('8'), Decimal('7'), 'AUTO THEFT', 12),
#  (Decimal('8'), Decimal('8'), 'AUTO THEFT', 11),
#  (Decimal('8'), Decimal('9'), 'AUTO THEFT', 12),
#  (Decimal('8'), Decimal('10'), 'AUTO THEFT', 18),
#  (Decimal('8'), Decimal('11'), 'AUTO THEFT', 11),
#  (Decimal('8'), Decimal('12'), 'AUTO THEFT', 11),
#  (Decimal('8'), Decimal('13'), 'AUTO THEFT', 11),
#  (Decimal('8'), Decimal('14'), 'AUTO THEFT', 4),
#  (Decimal('8'), Decimal('15'), 'AUTO THEFT', 25),
#  (Decimal('8'), Decimal('16'), 'AUTO THEFT', 17),
#  (Decimal('8'), Decimal('17'), 'AUTO THEFT', 11),
#  (Decimal('8'), Decimal('18'), 'AUTO THEFT', 14),
#  (Decimal('8'), Decimal('19'), 'AUTO THEFT', 12),
#  (Decimal('8'), Decimal('20'), 'AUTO THEFT', 11),
#  (Decimal('8'), Decimal('21'), 'AUTO THEFT', 15),
#  (Decimal('8'), Decimal('22'), 'AUTO THEFT', 11),
#  (Decimal('8'), Decimal('23'), 'AUTO THEFT', 21),
#  (Decimal('8'), Decimal('24'), 'AUTO THEFT', 18),
#  (Decimal('8'), Decimal('25'), 'AUTO THEFT', 22),
#  (Decimal('8'), Decimal('26'), 'AUTO THEFT', 17),
#  (Decimal('8'), Decimal('27'), 'AUTO THEFT', 13),
#  (Decimal('8'), Decimal('28'), 'AUTO THEFT', 10),
#  (Decimal('8'), Decimal('29'), 'AUTO THEFT', 14),
#  (Decimal('8'), Decimal('30'), 'AUTO THEFT', 19),
#  (Decimal('8'), Decimal('31'), 'AUTO THEFT', 13),
#  (Decimal('9'), Decimal('1'), 'AUTO THEFT', 12),
#  (Decimal('9'), Decimal('2'), 'AUTO THEFT', 16),
#  (Decimal('9'), Decimal('3'), 'AUTO THEFT', 15),
#  (Decimal('9'), Decimal('4'), 'AUTO THEFT', 23),
#  (Decimal('9'), Decimal('5'), 'AUTO THEFT', 10),
#  (Decimal('9'), Decimal('6'), 'AUTO THEFT', 21),
#  (Decimal('9'), Decimal('7'), 'AUTO THEFT', 17),
#  (Decimal('9'), Decimal('8'), 'AUTO THEFT', 9),
#  (Decimal('9'), Decimal('9'), 'AUTO THEFT', 11),
#  (Decimal('9'), Decimal('10'), 'AUTO THEFT', 13),
#  (Decimal('9'), Decimal('11'), 'AUTO THEFT', 19),
#  (Decimal('9'), Decimal('12'), 'AUTO THEFT', 16),
#  (Decimal('9'), Decimal('13'), 'AUTO THEFT', 9),
#  (Decimal('9'), Decimal('14'), 'AUTO THEFT', 12),
#  (Decimal('9'), Decimal('15'), 'AUTO THEFT', 14),
#  (Decimal('9'), Decimal('16'), 'AUTO THEFT', 12),
#  (Decimal('9'), Decimal('17'), 'AUTO THEFT', 15),
#  (Decimal('9'), Decimal('18'), 'AUTO THEFT', 22),
#  (Decimal('9'), Decimal('19'), 'AUTO THEFT', 16),
#  (Decimal('9'), Decimal('20'), 'AUTO THEFT', 13),
#  (Decimal('9'), Decimal('21'), 'AUTO THEFT', 13),
#  (Decimal('9'), Decimal('22'), 'AUTO THEFT', 9),
#  (Decimal('9'), Decimal('23'), 'AUTO THEFT', 25),
#  (Decimal('9'), Decimal('24'), 'AUTO THEFT', 21),
#  (Decimal('9'), Decimal('25'), 'AUTO THEFT', 10),
#  (Decimal('9'), Decimal('26'), 'AUTO THEFT', 11),
#  (Decimal('9'), Decimal('27'), 'AUTO THEFT', 15),
#  (Decimal('9'), Decimal('28'), 'AUTO THEFT', 20),
#  (Decimal('9'), Decimal('29'), 'AUTO THEFT', 17),
#  (Decimal('9'), Decimal('30'), 'AUTO THEFT', 14),
#  (Decimal('10'), Decimal('1'), 'AUTO THEFT', 21),
#  (Decimal('10'), Decimal('2'), 'AUTO THEFT', 15),
#  (Decimal('10'), Decimal('3'), 'AUTO THEFT', 21),
#  (Decimal('10'), Decimal('4'), 'AUTO THEFT', 12),
#  (Decimal('10'), Decimal('5'), 'AUTO THEFT', 13),
#  (Decimal('10'), Decimal('6'), 'AUTO THEFT', 7),
#  (Decimal('10'), Decimal('7'), 'AUTO THEFT', 18),
#  (Decimal('10'), Decimal('8'), 'AUTO THEFT', 17),
#  (Decimal('10'), Decimal('9'), 'AUTO THEFT', 23),
#  (Decimal('10'), Decimal('10'), 'AUTO THEFT', 22),
#  (Decimal('10'), Decimal('11'), 'AUTO THEFT', 11),
#  (Decimal('10'), Decimal('12'), 'AUTO THEFT', 12),
#  (Decimal('10'), Decimal('13'), 'AUTO THEFT', 17),
#  (Decimal('10'), Decimal('14'), 'AUTO THEFT', 18),
#  (Decimal('10'), Decimal('15'), 'AUTO THEFT', 23),
#  (Decimal('10'), Decimal('16'), 'AUTO THEFT', 18),
#  (Decimal('10'), Decimal('17'), 'AUTO THEFT', 26),
#  (Decimal('10'), Decimal('18'), 'AUTO THEFT', 13),
#  (Decimal('10'), Decimal('19'), 'AUTO THEFT', 27),
#  (Decimal('10'), Decimal('20'), 'AUTO THEFT', 18),
#  (Decimal('10'), Decimal('21'), 'AUTO THEFT', 18),
#  (Decimal('10'), Decimal('22'), 'AUTO THEFT', 22),
#  (Decimal('10'), Decimal('23'), 'AUTO THEFT', 21),
#  (Decimal('10'), Decimal('24'), 'AUTO THEFT', 20),
#  (Decimal('10'), Decimal('25'), 'AUTO THEFT', 17),
#  (Decimal('10'), Decimal('26'), 'AUTO THEFT', 23),
#  (Decimal('10'), Decimal('27'), 'AUTO THEFT', 11),
#  (Decimal('10'), Decimal('28'), 'AUTO THEFT', 23),
#  (Decimal('10'), Decimal('29'), 'AUTO THEFT', 8),
#  (Decimal('1'), Decimal('1'), 'BURGLARY', 18),
#  (Decimal('1'), Decimal('2'), 'BURGLARY', 6),
#  (Decimal('1'), Decimal('3'), 'BURGLARY', 22),
#  (Decimal('1'), Decimal('4'), 'BURGLARY', 24),
#  (Decimal('1'), Decimal('5'), 'BURGLARY', 16),
#  (Decimal('1'), Decimal('6'), 'BURGLARY', 23),
#  (Decimal('1'), Decimal('7'), 'BURGLARY', 20),
#  (Decimal('1'), Decimal('8'), 'BURGLARY', 30),
#  (Decimal('1'), Decimal('9'), 'BURGLARY', 15),
#  (Decimal('1'), Decimal('10'), 'BURGLARY', 16),
#  (Decimal('1'), Decimal('11'), 'BURGLARY', 23),
#  (Decimal('1'), Decimal('12'), 'BURGLARY', 24),
#  (Decimal('1'), Decimal('13'), 'BURGLARY', 18),
#  (Decimal('1'), Decimal('14'), 'BURGLARY', 25),
#  (Decimal('1'), Decimal('15'), 'BURGLARY', 18),
#  (Decimal('1'), Decimal('16'), 'BURGLARY', 18),
#  (Decimal('1'), Decimal('17'), 'BURGLARY', 10),
#  ...]

# %%
d = _.DataFrame()
rc('figure', figsize=(20, 8))
splt = sns.barplot(x='description', y='count', data=d)
labels = [l for l in splt.get_xmajorticklabels()]
splt.set_xticklabels(labels, rotation=30)
# Out:
# [<matplotlib.text.Text at 0x7f91d15471d0>,
#  <matplotlib.text.Text at 0x7f91d1540f28>,
#  <matplotlib.text.Text at 0x7f91d1544390>,
#  <matplotlib.text.Text at 0x7f91cf61bfd0>,
#  <matplotlib.text.Text at 0x7f91cf622a58>,
#  <matplotlib.text.Text at 0x7f91cf5a4588>,
#  <matplotlib.text.Text at 0x7f91cf5a70b8>,
#  <matplotlib.text.Text at 0x7f91cf5a7ba8>,
#  <matplotlib.text.Text at 0x7f91cf5ac6d8>,
#  <matplotlib.text.Text at 0x7f91cf5b0208>,
#  <matplotlib.text.Text at 0x7f91cf5b0cf8>,
#  <matplotlib.text.Text at 0x7f91cf5b4828>,
#  <matplotlib.text.Text at 0x7f91cf5b6358>,
#  <matplotlib.text.Text at 0x7f91cf5b6e48>,
#  <matplotlib.text.Text at 0x7f91cf5bb978>]

# %% [markdown]
# Looking at the distribution for the full year, above, we see that the average amount of burglaries per day in June is higher than it is for the rest of the year, which shows how the high number of reports on June 5th skews the data for the month when compared to the rest of the year.
#
# Given this evidence that the high number of burglaries reported on June 5th is an anomaly, we recommend that these reports be investigated further to determine if there is a reason that can be connected to this, or if it is a reporting error.

# %% [markdown]
# ## Bonus (10 points for one of A or B)
#
#
# ### Option A - Automating ETL
#
# Consider the work you did to load your original raw dataset and then transform it into a dimensional model for analysis.  What would it take to automate this process?  How often would you need to update the data?  Could you easily automate any data cleaning steps?  What checks would you need to put in place to ensure quality?  Would humans need to be involved, or could you automate it all?
#
# Discuss.
#
#
# ### Option B - Augmenting dimensions
#
# Considering your dimensional model, what external data could you find to augment it?  As in the case of bike trips, where weather might provide an interesting added dimension/context not present in the original data, you can probably find another source of data to complement your own model.  Identify one such source and add it to your model, demonstrating its value with a few new queries.
