# %% [markdown]
# Amit Talapatra, 10/24/16

# %% [markdown]
# # Exercise 04 - Due Friday, October 21 at 12pm
#
# *Objectives*: Gain experience loading a CSV dataset into a database model you define yourself and using SQL to explore its contents. Explore the data by writing and executing a number of SQL queries using common syntax and functions and describing your findings.
#
# *Grading criteria*: The tasks should all be completed, and questions should all be answered with SQL queries in the space provided, unless a text answer is requested. Results should be correct, according to the embedded tests. The notebook itself should be completely reproducible; from start to finish, another person should be able to use the same code to obtain the same results as yours.  Note that you will receive no more than partial credit if you do not add text/markdown cells explaining your thinking at each major step in each problem.
#
# *Deadline*: Friday, October 21, 12pm. Submit your notebook to Blackboard and push it to your GitHub repository.
#
# ## Setup - obtain data and create database
#
# The US City Open Data Census has data on [restaurant inspections from all over the country](http://us-city.census.okfn.org/dataset/food-safety).  Let's take a look at data from Albuquerque.  *Note*: metadata and other details for this dataset are available at http://data.cabq.gov/business/foodinspections/.
#
# Fyi, to save you a step, I've converted this file into a clean CSV file by using the `dos2unix` command to change its line endings and to switch it to use commas instead of tabs using `csvformat -t inputfile.csv > outputfile.csv`.
#
# First we download the dataset:

# %%
# !wget https://raw.githubusercontent.com/gwsb-istm-6212-fall-2016/syllabus-and-schedule/master/exercises/abq-food-inspections-fy2010.csv
# Out:
# --2016-10-23 20:25:27--  https://raw.githubusercontent.com/gwsb-istm-6212-fall-2016/syllabus-and-schedule/master/exercises/abq-food-inspections-fy2010.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.32.133
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.32.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 5025226 (4.8M) [text/plain]
# Saving to: ‘abq-food-inspections-fy2010.csv.1’
#
# abq-food-inspection 100%[=====================>]   4.79M  --.-KB/s   in 0.08s
#
# 2016-10-23 20:25:27 (58.2 MB/s) - ‘abq-food-inspections-fy2010.csv.1’ saved [5025226/5025226]

# %% [markdown]
# ## Problem 1 - examine the data (35 points)
#
# Use `csvstat` and other tools as you see fit and observe its contents.  Review the metadata definitions linked to above.  Describe what you see:  What do all the columns mean?  Are there null values?  Which columns interest you the most?  Which columns present some complications or questions you would like to ask?

# %% [markdown]
# Insert a combination of code and text/markdown cells here to review the data and describe what you find.

# %% [markdown]
# -------------------------------------------------------------------
# First, I used csvcut to print the indexes and names of each column.

# %%
# !csvcut -n abq-food-inspections-fy2010.csv
# Out:
#   1: FACILITY_NAME
#   2: FACILITY_KEY
#   3: SITE_ADDRESS
#   4: CITY
#   5: STATE
#   6: ZIP
#   7: OWNER_KEY
#   8: OWNER_NAME
#   9: NATURE_OF_BUSINESS
#  10: STREET_NUMBER
#  11: STREET_NAME
#  12: STREET_TYPE
#  13: POST_DIRECTIONAL
#  14: PHONE
#  15: PROGRAM_CATEGORY
#  16: PROGRAM_CATEGORY_DESCRIPTION
#  17: INSPECTION_DATE
#  18: INSPECTION_TYPE
#  19: INSPECTION_DESC
#  20: SERIAL_NUM
#  21: ACTION_CODE
#  22: ACTION_DESC
#  23: RESULT_CODE
#  24: RESULT_DESC
#  25: VIOLATION_CODE
#  26: VIOLATION_DESC
#  27: INSPECTION_MEMO

# %% [markdown]
# I wanted to see how many rows are in the dataset to get a sense of the volume of the data.

# %%
# !wc -l abq-food-inspections-fy2010.csv
# Out:
# 17557 abq-food-inspections-fy2010.csv

# %% [markdown]
# I used csvstat to see some statistics on each column and identify some of the common values in each.
# This showed that SITE_ADDRESS, NATURE_OF_BUSINESS, STREET_NUMBER, STREET_NAME, STREET_TYPE, POST_DIRECTIONAL, PHONE, PROGRAM_CATEGORY_DESCRIPTION, INSPECTION_TYPE, VIOLATION_CODE, VIOLATION_DESC, and INSPECTION_MEMO.

# %%
# !csvstat abq-food-inspections-fy2010.csv
# Out:
#   1. FACILITY_NAME
# 	<class 'str'>
# 	Nulls: False
# 	Unique values: 2615
# 	5 most frequent values:
# 		SMITHS FOOD AND DRUG CENTERS INC:	154
# 		ISOTOPES PARK - OVATIONS:	93
# 		PER EHSII CECELIA GARCIA OOB LA REYNA DEL SUR:	85
# 		ECHO INC:	68
# 		ISLETA AMPHITHEATER:	68
# 	Max length: 77
#   2. FACILITY_KEY
# 	<class 'int'>
# 	Nulls: False
# 	Min: 13
# 	Max: 101482
# 	Sum: 820405773
# 	Mean: 46730.79135338346
# 	Median: 50866.0
# 	Standard Deviation: 32659.794578837962
# 	Unique values: 2835
# 	5 most frequent values:
# 		46323:	93
# 		65863:	85
# 		80949:	68
# 		32817:	68
# 		91825:	66
#   3. SITE_ADDRESS
# 	<class 'str'>
# 	Nulls: True
# 	Unique values: 2456
# 	5 most frequent values:
# 		1601 AVENIDA CESAR CHAVEZ SE:	94
# 		644 OLD COORS BLVD SW:	85
# 		8601 CENTRAL AV NE:	77
# 		2200 SUNPORT BLVD SE:	75
# 		5210 CENTRAL AV SE:	73
# 	Max length: 35
#   4. CITY
# 	<class 'str'>
# 	Nulls: False
# 	Values: ALBUQUERQUE
#   5. STATE
# 	<class 'str'>
# 	Nulls: False
# 	Values: 87, NM
#   6. ZIP
# 	<class 'str'>
# 	Nulls: False
# 	Unique values: 48
# 	5 most frequent values:
# 		87110:	1996
# 		87108:	1976
# 		87102:	1601
# 		87106:	1568
# 		87109:	1552
# 	Max length: 10
#   7. OWNER_KEY
# 	<class 'int'>
# 	Nulls: False
# 	Min: 11
# 	Max: 87302
# 	Sum: 644760848
# 	Mean: 36725.953975848715
# 	Median: 33747.0
# 	Standard Deviation: 29428.207216739836
# 	Unique values: 1892
# 	5 most frequent values:
# 		1838:	792
# 		3537:	321
# 		1272:	228
# 		36280:	156
# 		80274:	155
#   8. OWNER_NAME
# 	<class 'str'>
# 	Nulls: False
# 	Unique values: 1852
# 	5 most frequent values:
# 		APS:	792
# 		SMITHS FOOD AND DRUG CENTERS INC:	321
# 		CIRCLE K STORES INC:	277
# 		ALBERTSONS:	228
# 		WAL MART STORES EAST  LP:	156
# 	Max length: 82
#   9. NATURE_OF_BUSINESS
# 	<class 'str'>
# 	Nulls: True
# 	Unique values: 594
# 	5 most frequent values:
# 		RESTAURANT:	4994
# 		FOOD SERVICE:	691
# 		GROCERY:	618
# 		BAR/RESTAURANT:	508
# 		APS SCHOOL FOOD SERVICE:	470
# 	Max length: 25
#  10. STREET_NUMBER
# 	<class 'str'>
# 	Nulls: True
# 	Unique values: 1349
# 	5 most frequent values:
# 		6600:	216
# 		10000:	152
# 		300:	143
# 		2200:	127
# 		8100:	125
# 	Max length: 7
#  11. STREET_NAME
# 	<class 'str'>
# 	Nulls: True
# 	Unique values: 404
# 	5 most frequent values:
# 		CENTRAL:	1898
# 		MENAUL:	928
# 		COORS:	918
# 		MONTGOMERY:	727
# 		SAN MATEO:	707
# 	Max length: 24
#  12. STREET_TYPE
# 	<class 'str'>
# 	Nulls: True
# 	Unique values: 13
# 	5 most frequent values:
# 		BLVD:	7636
# 		AV:	3005
# 		ST:	2065
# 		RD:	1900
# 		DR:	995
# 	Max length: 4
#  13. POST_DIRECTIONAL
# 	<class 'str'>
# 	Nulls: True
# 	Values: N, NW, SE, SW, NE
#  14. PHONE
# 	<class 'int'>
# 	Nulls: True
# 	Min: 2471094
# 	Max: 505345566137310
# 	Sum: 2608539289633190
# 	Mean: 161719732773.29138
# 	Median: 5053454060.0
# 	Standard Deviation: 8895791545525.992
# 	Unique values: 2279
# 	5 most frequent values:
# 		9153321301:	101
# 		3037929467:	100
# 		5052224033:	94
# 		3109680646:	85
# 		5052426777:	68
#  15. PROGRAM_CATEGORY
# 	<class 'str'>
# 	Nulls: False
# 	Unique values: 25
# 	5 most frequent values:
# 		0406:	7969
# 		0601:	1159
# 		0607:	894
# 		0606:	865
# 		0501:	832
# 	Max length: 4
#  16. PROGRAM_CATEGORY_DESCRIPTION
# 	<class 'str'>
# 	Nulls: True
# 	Unique values: 24
# 	5 most frequent values:
# 		Food Service Establishment:	7969
# 		Retail -Grocery:	1159
# 		Retail - Self Service & Prepackage Foods:	894
# 		Retail - Prepackage Only:	865
# 		School:	832
# 	Max length: 40
#  17. INSPECTION_DATE
# 	<class 'datetime.date'>
# 	Nulls: False
# 	Min: 2009-07-01
# 	Max: 2010-06-30
# 	Unique values: 258
# 	5 most frequent values:
# 		2009-12-16:	184
# 		2009-09-10:	159
# 		2009-09-25:	148
# 		2009-11-04:	133
# 		2009-10-01:	131
#  18. INSPECTION_TYPE
# 	<class 'NoneType'>
# 	Nulls: True
# 	Values:
#  19. INSPECTION_DESC
# 	<class 'str'>
# 	Nulls: False
# 	Unique values: 15
# 	5 most frequent values:
# 		ROUTINE FOOD INSPECTION:	12439
# 		EMERGENCY RESPONSE:	1987
# 		New Business Inspection:	1005
# 		PRE-OPENING FOOD INSPECTION:	743
# 		ADDITIONAL SERVICE PROVIDED:	439
# 	Max length: 32
#  20. SERIAL_NUM
# 	<class 'str'>
# 	Nulls: False
# 	Unique values: 9046
# 	5 most frequent values:
# 		DA0047290:	61
# 		DA0045731:	61
# 		DA0045676:	61
# 		DA0047720:	61
# 		DA0059230:	61
# 	Max length: 9
#  21. ACTION_CODE
# 	<class 'str'>
# 	Nulls: False
# 	Unique values: 8
# 	5 most frequent values:
# 		11:	14080
# 		00:	2800
# 		09:	382
# 		06:	264
# 		10:	21
# 	Max length: 2
#  22. ACTION_DESC
# 	<class 'str'>
# 	Nulls: False
# 	Unique values: 8
# 	5 most frequent values:
# 		APPROVED:	14080
# 		NON-GRADED:	2800
# 		ANNUAL STICKER ISSUED:	382
# 		UNSATISFACTORY:	264
# 		ANNUAL STICKER NOT ISSUED:	21
# 	Max length: 34
#  23. RESULT_CODE
# 	<class 'str'>
# 	Nulls: False
# 	Unique values: 19
# 	5 most frequent values:
# 		03:	14389
# 		00:	2416
# 		05:	214
# 		22:	142
# 		18:	104
# 	Max length: 2
#  24. RESULT_DESC
# 	<class 'str'>
# 	Nulls: False
# 	Unique values: 19
# 	5 most frequent values:
# 		IN COMPLIANCE:	14389
# 		NOT APPLICABLE:	2416
# 		DOWNGRADE:	214
# 		OUT OF BUSINESS:	142
# 		TRAINING RECEIVED:	104
# 	Max length: 37
#  25. VIOLATION_CODE
# 	<class 'str'>
# 	Nulls: True
# 	Unique values: 128
# 	5 most frequent values:
# 		55:	6348
# 		00:	3429
# 		68:	1658
# 		42:	487
# 		35:	441
# 	Max length: 10
#  26. VIOLATION_DESC
# 	<class 'str'>
# 	Nulls: True
# 	Unique values: 70
# 	5 most frequent values:
# 		Additional Comments:	6353
# 		No Violations Found:	3434
# 		Delivered Informational Brochure:	1657
# 		Plumbing: Improperly installed/maintained/supplied:	492
# 		Non-Food contact surfaces:	446
# 	Max length: 50
#  27. INSPECTION_MEMO
# 	<class 'NoneType'>
# 	Nulls: True
# 	Values:
#
# Row count: 17556

# %% [markdown]
# From the metadata, the column meanings are:
#
# FACILITY_NAME: Name of the facility where the inspection occurred
# FACILITY_KEY: ID of the facility where the inspection occurred
# SITE_ADDRESS: Street address of the facility where the inspection occurred
# CITY: City of the facility where the inspection occurred
# STATE: State of the facility where the inspection occurred
# ZIP: Zip of the facility where the inspection occurred
# OWNER_KEY: ID of the Owner of the facility where the inspection occurred at the time of the inspection
# OWNER_NAME: Name of the Owner of the facility where the inspection occurred at the time of the inspection
# NATURE_OF_BUSINESS: The type of business, originally for internal use only, provides information about the business. This is not the information provided on the federal tax form.
# STREET_NUMBER: Street number of the facility where the inspection occurred
# STREET_NAME: Street name of the facility where the inspection occurred
# STREET_TYPE: Street type of the facility where the inspection occurred
# POST_DIRECTIONAL: Postal direction of the facility where the inspection occurred
# PHONE: Phone number of the facility where the inspection occurred
# PROGRAM_CATEGORY: Id that indicates the type of facility permit the inspection was performed
# PROGRAM_CATEGORY_DESCRIPTION: Descript of the id that indicates the type of facility permit the inspection was performed
# INSPECTION_DATE: Date the inspection occurred
# INSPECTION_TYPE: Code for type of inspection
# INSPECTION_DESC: Description of the inspection
# SERIAL_NUM: Unique ID for the inspection daily activity. This is a sequential number assigned chronologically as the data is entered into the system. If there are multiple rows with the same OWNER_ID and INSPECTION_DATE and SERIAL_NUM, it means that there were multiple rows created for one inspection (multiple results were recorded). If there are multiple rows with the same OWNER_ID and INSPECTION_DATE and a different SERIAL_NUM, it means that there were multiple inspections taken on the same day and the highest SERIAL_NUM is intended to be the most recent inspection
# ACTION_CODE: Code of the action taken. If the ACTION_CODE is equal to 00 – NON-GRADED this indicates that the inspector was unable to actually perform an inspection. The RESULT_CODE documents the situation
# ACTION_DESC: Description of the action taken
# RESULT_CODE: Code of the result of the inspection
# RESULT_DESC: Description of the result of the inspection
# VIOLATION_CODE: The code for the violation
# VIOLATION_DESC(NVL(SNV, VD): Description of the violation that was found
# INSPECTION_MEMO: Notes from the inspection made by the inspector

# %% [markdown]
# FACILITY_NAME/FACILITY_KEY will be useful for identifying individual facilities. I'm interested in seeing the relationships between features like NATURE_OF_BUSINESS, PROGRAM_CATEGORY_DESCRIPTION, INSPECTION_DESC, ACTION_DESC, RESULT_DESC, and VIOLATION_DESC. To see how these features differ by location, the ZIP column may be a useful way of grouping facilities.

# %% [markdown]
# ## Problem 2 - define a database model and load the data (35 points)
#
# Based on what you found above, create and connect to a new database, define a database table in it, and load this dataset into it.  You may use either of the methods for this step you have seen in earlier class notebooks.  You may choose to eliminate variables/columns if they are not relevant or interesting to you - explain your reasoning if you do.  Either way, you should load a majority of the columns present in the source dataset into the database and all of its rows.
#
# Once your data has loaded successfully, run a `COUNT(*)` query to verify that all the data has loaded correctly.
#
# Insert a combination of code and text/markdown cells here to connect to your database, define your table, load its data, and verify the loaded records.

# %% [markdown]
# -------------------------------------------------------------------
# First, I created the database in PostgreSQL.

# %%
# %load_ext sql
# !echo 'redspot' | sudo -S service postgresql restart
# !createdb -U dbuser ABQFood
# %sql postgresql://dbuser@localhost:5432/ABQFood
# Out:
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql
# [sudo] password for jovyan: Restarting PostgreSQL 9.5 database server: main.
# createdb: database creation failed: ERROR:  database "ABQFood" already exists
# 'Connected: dbuser@ABQFood'

# %% [markdown]
# Next, I set up the table in the database that I would be transferring my data into.

# %%
# %%sql
# DROP TABLE IF EXISTS ABQFood;
# CREATE TABLE ABQFood (
#     facility_name VARCHAR(100),
#     facility_key INTEGER,
#     site_address VARCHAR(64),
#     city VARCHAR(64),
#     state VARCHAR(64),
#     zipcode VARCHAR(64),
#     owner_key INTEGER,
#     owner_name VARCHAR(100),
#     nature_of_business VARCHAR(64),
#     street_number VARCHAR(64),
#     street_name VARCHAR(64),
#     street_type VARCHAR(64),
#     post_directional VARCHAR(64),
#     phone VARCHAR(64),
#     program_category VARCHAR(64),
#     program_category_description VARCHAR(64),
#     inspection_date TIMESTAMP,
#     inspection_type VARCHAR(64),
#     inspection_desc VARCHAR(64),
#     serial_num VARCHAR(64),
#     action_code VARCHAR(64),
#     action_desc VARCHAR(64),
#     result_code VARCHAR(64),
#     result_desc VARCHAR(64),
#     violation_code VARCHAR(64),
#     violation_desc VARCHAR(64),
#     inspection_memo VARCHAR(64)
# )
# Out:
# Done.
# Done.
# []

# %% [markdown]
# I then loaded the data from the csv file into the database table.

# %%
# %%sql
# COPY ABQFood FROM '/home/jovyan/work/abq-food-inspections-fy2010.csv'
# CSV
# HEADER
# QUOTE '"'
# DELIMITER ',';
# Out:
# 17556 rows affected.
# []

# %% [markdown]
# I used COUNT(*) to verify that all of the rows were loaded into the table correctly.

# %%
# %%sql
# SELECT COUNT(*) FROM ABQFood;
# Out:
# 1 rows affected.
# [(17556,)]

# %% [markdown]
# ## Problem 3 - explore your data (30 points)
#
# Now that the data is loaded, ask some questions of it!  Identify key variables of interest and note their ranges along with other useful descriptive statistics.  Choose and define a few lines of inquiry, execute queries for each, and describe what you find in your result sets.  Use any query techniques we've seen in class, including aggregate functions, transformations, subqueries, or others as appropriate.
#
# If you find interesting patterns, adding plots to your exploration would be useful.
#
# Insert a combination of code and text/markdown cells here to explore your data.

# %% [markdown]
# ---------------------------------------------------------------------
# FACILITY_NAME/FACILITY_KEY will be useful for identifying individual facilities. I'm interested in seeing the relationships between features like NATURE_OF_BUSINESS, PROGRAM_CATEGORY_DESCRIPTION, INSPECTION_DESC, ACTION_DESC, RESULT_DESC, and VIOLATION_DESC. To see how these features differ by location, the ZIP column may be a useful way of grouping facilities.
#
# To start, I wanted to view some of the data to verify that cell contents are formatted correctly for each column.
#
# This cell is also a useful way to check that changes to the table are implemented correctly, so I run it after each transformation that I want to check.

# %%
# %%sql
# SELECT *
# FROM abqfood
# LIMIT 10;
# Out:
# 10 rows affected.
# [('00BSAY IT WITH CAKE', 50534, '10200 GOLF COURSE RD NW STE B', 'ALBUQUERQUE', 'NM', '87114', 47341, 'OOBSAY IT WITH CAKE', 'CAKE DECORATING', '10200', 'GOLF COURSE', 'RD', 'NW', '5058339563', '0405', 'Food Processor', datetime.datetime(2009, 10, 21, 0, 0), None, 'EMERGENCY RESPONSE', 'DA8009125', '00', 'NON-GRADED', '00', 'NOT APPLICABLE', '    68    ', 'Delivered Informational Brochure', None),
#  ('00BSAY IT WITH CAKE', 50534, '10200 GOLF COURSE RD NW STE B', 'ALBUQUERQUE', 'NM', '87114', 47341, 'OOBSAY IT WITH CAKE', 'CAKE DECORATING', '10200', 'GOLF COURSE', 'RD', 'NW', '5058339563', '0405', 'Food Processor', datetime.datetime(2009, 10, 21, 0, 0), None, 'ROUTINE FOOD INSPECTION', 'DA8009123', '11', 'APPROVED', '03', 'IN COMPLIANCE', '    00    ', 'No Violations Found', None),
#  ('00BSAY IT WITH CAKE', 50534, '10200 GOLF COURSE RD NW STE B', 'ALBUQUERQUE', 'NM', '87114', 47341, 'OOBSAY IT WITH CAKE', 'CAKE DECORATING', '10200', 'GOLF COURSE', 'RD', 'NW', '5058339563', '0405', 'Food Processor', datetime.datetime(2009, 10, 21, 0, 0), None, 'ROUTINE FOOD INSPECTION', 'DA8009123', '11', 'APPROVED', '03', 'IN COMPLIANCE', '    55    ', 'Additional Comments', None),
#  ('00BSAY IT WITH CAKE', 50534, '10200 GOLF COURSE RD NW STE B', 'ALBUQUERQUE', 'NM', '87114', 47341, 'OOBSAY IT WITH CAKE', 'CAKE DECORATING', '10200', 'GOLF COURSE', 'RD', 'NW', '5058339563', '0405', 'Food Processor', datetime.datetime(2010, 4, 14, 0, 0), None, 'ROUTINE FOOD INSPECTION', 'DA8010205', '11', 'APPROVED', '03', 'IN COMPLIANCE', '    00    ', 'No Violations Found', None),
#  ('00BSAY IT WITH CAKE', 50534, '10200 GOLF COURSE RD NW STE B', 'ALBUQUERQUE', 'NM', '87114', 47341, 'OOBSAY IT WITH CAKE', 'CAKE DECORATING', '10200', 'GOLF COURSE', 'RD', 'NW', '5058339563', '0405', 'Food Processor', datetime.datetime(2010, 4, 14, 0, 0), None, 'ROUTINE FOOD INSPECTION', 'DA8010205', '11', 'APPROVED', '03', 'IN COMPLIANCE', '    55    ', 'Additional Comments', None),
#  ('2000 VIETNAM RESTAURANT', 31468, '601 SAN MATEO BLVD SE ', 'ALBUQUERQUE', 'NM', '87108', 29294, '2000 VIETMAN RESTAURANT', 'RESTAURANT', '601', 'SAN MATEO', 'BLVD', 'SE', '5052320900', '0406', 'Food Service Establishment', datetime.datetime(2010, 3, 23, 0, 0), None, 'ROUTINE FOOD INSPECTION', 'DA8509472', '11', 'APPROVED', '03', 'IN COMPLIANCE', '    34    ', 'Food contact surfaces', None),
#  ('2000 VIETNAM RESTAURANT', 31468, '601 SAN MATEO BLVD SE ', 'ALBUQUERQUE', 'NM', '87108', 29294, '2000 VIETMAN RESTAURANT', 'RESTAURANT', '601', 'SAN MATEO', 'BLVD', 'SE', '5052320900', '0406', 'Food Service Establishment', datetime.datetime(2010, 3, 23, 0, 0), None, 'ROUTINE FOOD INSPECTION', 'DA8509472', '11', 'APPROVED', '03', 'IN COMPLIANCE', '    35    ', 'Non-Food contact surfaces', None),
#  ('2000 VIETNAM RESTAURANT', 31468, '601 SAN MATEO BLVD SE ', 'ALBUQUERQUE', 'NM', '87108', 29294, '2000 VIETMAN RESTAURANT', 'RESTAURANT', '601', 'SAN MATEO', 'BLVD', 'SE', '5052320900', '0406', 'Food Service Establishment', datetime.datetime(2010, 3, 23, 0, 0), None, 'ROUTINE FOOD INSPECTION', 'DA8509472', '11', 'APPROVED', '03', 'IN COMPLIANCE', '    55    ', 'Additional Comments', None),
#  ('328 CHINESE CUISINE', 72789, '5617 MENAUL BLVD NE STE A', 'ALBUQUERQUE', 'NM', '87110', 66644, '328 CHINESE CUISINE', None, '5617', 'MENAUL', 'BLVD', 'NE', '5058814468', '0406', 'Food Service Establishment', datetime.datetime(2009, 12, 15, 0, 0), None, 'EMERGENCY RESPONSE', 'DA7757250', '00', 'NON-GRADED', '00', 'NOT APPLICABLE', '    68    ', 'Delivered Informational Brochure', None),
#  ('328 CHINESE CUISINE', 72789, '5617 MENAUL BLVD NE STE A', 'ALBUQUERQUE', 'NM', '87110', 66644, '328 CHINESE CUISINE', None, '5617', 'MENAUL', 'BLVD', 'NE', '5058814468', '0406', 'Food Service Establishment', datetime.datetime(2009, 12, 15, 0, 0), None, 'ROUTINE FOOD INSPECTION', 'DA7757248', '11', 'APPROVED', '03', 'IN COMPLIANCE', '    00    ', 'No Violations Found', None)]

# %% [markdown]
# The next set of cells applies a transformation to split the inspection_date into year, month, and day. These are then added to the table as three separate columns.

# %%
# %%sql
# ALTER TABLE abqfood
# ADD COLUMN year NUMERIC;
# Out:
# Done.
# []

# %%
# %%sql
# ALTER TABLE abqfood
# ADD COLUMN month NUMERIC;
# Out:
# Done.
# []

# %%
# %%sql
# ALTER TABLE abqfood
# ADD COLUMN day NUMERIC;
# Out:
# Done.
# []

# %%
# %%sql
# UPDATE abqfood
# SET year = EXTRACT(YEAR FROM inspection_date),
#     month = EXTRACT(MONTH FROM inspection_date),
#     day = EXTRACT(DAY FROM inspection_date);
# Out:
# 17556 rows affected.
# []

# %% [markdown]
# Next, I plotted the number of inspections over time, using the newly created year and month columns.

# %%
# %%sql
# SELECT year, month, COUNT(*) FROM abqfood
# GROUP BY year, month
# ORDER BY year, month ASC
# Out:
# 12 rows affected.
# [(Decimal('2009'), Decimal('7'), 1693),
#  (Decimal('2009'), Decimal('8'), 1440),
#  (Decimal('2009'), Decimal('9'), 2030),
#  (Decimal('2009'), Decimal('10'), 1678),
#  (Decimal('2009'), Decimal('11'), 1706),
#  (Decimal('2009'), Decimal('12'), 2084),
#  (Decimal('2010'), Decimal('1'), 1453),
#  (Decimal('2010'), Decimal('2'), 1336),
#  (Decimal('2010'), Decimal('3'), 1552),
#  (Decimal('2010'), Decimal('4'), 1250),
#  (Decimal('2010'), Decimal('5'), 563),
#  (Decimal('2010'), Decimal('6'), 771)]

# %%
# %matplotlib inline
result = _
result.bar()
# Out:
# <Container object of 12 artists>

# %% [markdown]
# The plot shows that significantly fewer inspections occured in some months. May 2010 was the least busy month in terms of inspections, the winter months had nearly 3-4 times as many inspections. From just this data set, there is too little to say that this is an annual trend. For example, there is a significant difference in the number of inspections in July 2009 compared to June 2010 so it may be that the decline in inspections in the summer does not occur every year to the same extent.

# %% [markdown]
# Next, I wanted to see how certain features of a store correlate with the type of inspection and violation. I started by viewing all of the different inspection types, because it may be useful to filter the data by specific inspection types when looking at violations as violations may be specific to the type of inspection.

# %%
# %%sql
# SELECT inspection_desc, COUNT(*) FROM abqfood
# GROUP BY inspection_desc
# Out:
# 15 rows affected.
# [('New Business Inspection', 1005),
#  ('IMMINENT HEALTH HAZARD', 36),
#  ('MANAGERIAL ASSISTANCE', 54),
#  ('FIRE CALL', 5),
#  ('MOBILE UNIT FOOD INSPECTION', 377),
#  ('E-MAIL', 1),
#  ('PHONE CALL', 247),
#  ('PLAN REVIEW INSPECTION', 4),
#  ('COMPLAINT FOOD INSPECTION', 1),
#  ('PRE-OPENING FOOD INSPECTION', 743),
#  ('FOOD FOLLOW-UP INSPECTION', 143),
#  ('ROUTINE FOOD INSPECTION', 12439),
#  ('EMERGENCY RESPONSE', 1987),
#  ('ADDITIONAL SERVICE PROVIDED', 439),
#  ('FOLLOW-UP DOCUMENTATION RECEIVED', 75)]

# %% [markdown]
# When counting each type of inspection/facility category pairing, we see that routine food inspections at food service establishments are the most common type of observation. When looking for consistent patterns in the data, it may be useful to limit investigations to this subset of inspections and types of facilities.

# %%
# %%sql
# SELECT inspection_desc, program_category_description, COUNT(*) FROM abqfood
# GROUP BY inspection_desc, program_category_description
# Out:
# 186 rows affected.
# [('ADDITIONAL SERVICE PROVIDED', 'Mobile Pre-Packaged', 47),
#  ('New Business Inspection', 'School', 29),
#  ('New Business Inspection', 'Meat Market', 12),
#  ('ADDITIONAL SERVICE PROVIDED', 'Seasonal Venue -Fixed Location', 4),
#  ('FOLLOW-UP DOCUMENTATION RECEIVED', 'Retail - Deli', 1),
#  ('ADDITIONAL SERVICE PROVIDED', 'Non School', 9),
#  ('FOLLOW-UP DOCUMENTATION RECEIVED', 'Institutional Kitchen', 3),
#  ('New Business Inspection', 'Limited Menu', 18),
#  ('EMERGENCY RESPONSE', 'Food Processor', 57),
#  ('FOOD FOLLOW-UP INSPECTION', 'Meat Market', 4),
#  ('New Business Inspection', 'Non School', 18),
#  ('ADDITIONAL SERVICE PROVIDED', 'Limited Menu', 5),
#  ('FOOD FOLLOW-UP INSPECTION', 'School', 2),
#  ('New Business Inspection', 'Mobile Pre-Packaged', 47),
#  ('ADDITIONAL SERVICE PROVIDED', 'School', 8),
#  ('PRE-OPENING FOOD INSPECTION', 'Food Processor', 15),
#  ('ADDITIONAL SERVICE PROVIDED', 'Meat Market', 2),
#  ('PHONE CALL', 'Warehouse', 1),
#  ('MANAGERIAL ASSISTANCE', 'Retail - Prepackage Only', 5),
#  ('FOLLOW-UP DOCUMENTATION RECEIVED', 'Childcare', 5),
#  ('ROUTINE FOOD INSPECTION', 'Warehouse', 111),
#  ('FOLLOW-UP DOCUMENTATION RECEIVED', 'Retail -Grocery', 2),
#  ('MANAGERIAL ASSISTANCE', 'School', 1),
#  ('PRE-OPENING FOOD INSPECTION', 'Institutional Kitchen', 4),
#  ('PRE-OPENING FOOD INSPECTION', 'Retail - Deli', 2),
#  ('New Business Inspection', 'NOT FOR PROFIT KITCHEN PERMIT', 2),
#  ('FIRE CALL', 'Food Service Establishment', 4),
#  ('EMERGENCY RESPONSE', 'Institutional Kitchen', 40),
#  ('EMERGENCY RESPONSE', 'Retail - Deli', 24),
#  ('MANAGERIAL ASSISTANCE', 'Non School', 1),
#  ('FOLLOW-UP DOCUMENTATION RECEIVED', 'Food Processor', 1),
#  ('MANAGERIAL ASSISTANCE', 'Mobile Pre-Packaged', 1),
#  ('FOOD FOLLOW-UP INSPECTION', 'NOT FOR PROFIT KITCHEN PERMIT', 2),
#  ('PHONE CALL', 'Food Service Establishment', 55),
#  ('PRE-OPENING FOOD INSPECTION', 'Seasonal Location -Food Service Permit', 4),
#  ('New Business Inspection', 'Retail - Prepackage Only', 66),
#  ('PRE-OPENING FOOD INSPECTION', 'Childcare', 10),
#  ('New Business Inspection', 'Frozen Food Truck', 48),
#  ('EMERGENCY RESPONSE', 'Seasonal Location -Food Service Permit', 3),
#  ('EMERGENCY RESPONSE', 'Childcare', 98),
#  ('ROUTINE FOOD INSPECTION', 'Food Service Establishment', 5809),
#  ('IMMINENT HEALTH HAZARD', 'Mobile Food Unit', 6),
#  ('FOOD FOLLOW-UP INSPECTION', 'Retail - Prepackage Only', 20),
#  ('ADDITIONAL SERVICE PROVIDED', 'Frozen Food Truck', 5),
#  ('PRE-OPENING FOOD INSPECTION', 'Retail -Grocery', 16),
#  ('ROUTINE FOOD INSPECTION', None, 87),
#  ('EMERGENCY RESPONSE', 'Retail -Grocery', 150),
#  ('ADDITIONAL SERVICE PROVIDED', 'Retail - Prepackage Only', 14),
#  ('FOOD FOLLOW-UP INSPECTION', 'Retail - Meat/Seafood', 3),
#  ('New Business Inspection', 'Retail - Specialty Food Permit', 8),
#  ('ROUTINE FOOD INSPECTION', 'Seasonal Location -Food Service Permit', 60),
#  ('ROUTINE FOOD INSPECTION', 'Childcare', 603),
#  ('New Business Inspection', 'Retail - Self Service & Prepackage Foods', 129),
#  ('ADDITIONAL SERVICE PROVIDED', 'Retail - Meat/Seafood', 4),
#  ('PHONE CALL', 'Retail -Grocery', 26),
#  ('EMERGENCY RESPONSE', 'Food Service Establishment', 952),
#  ('ADDITIONAL SERVICE PROVIDED', 'Retail - Specialty Food Permit', 4),
#  ('PRE-OPENING FOOD INSPECTION', None, 1),
#  ('ADDITIONAL SERVICE PROVIDED', 'Retail - Self Service & Prepackage Foods', 22),
#  ('New Business Inspection', 'Retail - Meat/Seafood', 5),
#  ('EMERGENCY RESPONSE', None, 5),
#  ('PRE-OPENING FOOD INSPECTION', 'Food Service Establishment', 329),
#  ('PHONE CALL', 'Childcare', 5),
#  ('ROUTINE FOOD INSPECTION', 'Retail -Grocery', 899),
#  ('FOOD FOLLOW-UP INSPECTION', 'Retail - Specialty Food Permit', 2),
#  ('ADDITIONAL SERVICE PROVIDED', 'Bar', 19),
#  ('FOOD FOLLOW-UP INSPECTION', 'Mobile Food Unit', 2),
#  ('FIRE CALL', 'Retail -Grocery', 1),
#  ('ADDITIONAL SERVICE PROVIDED', 'Mobile Food Unit', 31),
#  ('ROUTINE FOOD INSPECTION', 'Institutional Kitchen', 296),
#  ('ROUTINE FOOD INSPECTION', 'Retail - Deli', 289),
#  ('New Business Inspection', 'Mobile Food Unit', 38),
#  ('New Business Inspection', 'Bar', 35),
#  ('PHONE CALL', 'Institutional Kitchen', 2),
#  ('PHONE CALL', 'Retail - Deli', 5),
#  ('MANAGERIAL ASSISTANCE', 'Retail - Self Service & Prepackage Foods', 1),
#  ('EMERGENCY RESPONSE', 'Warehouse', 45),
#  ('FOLLOW-UP DOCUMENTATION RECEIVED', 'Food Service Establishment', 41),
#  ('PRE-OPENING FOOD INSPECTION', 'Warehouse', 12),
#  ('COMPLAINT FOOD INSPECTION', 'Mobile Food Unit', 1),
#  ('FOLLOW-UP DOCUMENTATION RECEIVED', None, 1),
#  ('PHONE CALL', 'Food Processor', 12),
#  ('PLAN REVIEW INSPECTION', 'Retail - Prepackage Only', 1),
#  ('New Business Inspection', 'Bakery', 2),
#  ('MANAGERIAL ASSISTANCE', 'Mobile Food Unit', 3),
#  ('ROUTINE FOOD INSPECTION', 'Food Processor', 355),
#  ('E-MAIL', 'Childcare', 1),
#  ('ADDITIONAL SERVICE PROVIDED', 'Bakery', 2),
#  ('FOOD FOLLOW-UP INSPECTION', 'Bakery', 8),
#  ('MANAGERIAL ASSISTANCE', 'Bar', 1),
#  ('ROUTINE FOOD INSPECTION', 'Seasonal Venue -Fixed Location', 173),
#  ('PLAN REVIEW INSPECTION', 'Retail -Grocery', 1),
#  ('ROUTINE FOOD INSPECTION', 'Non School', 225),
#  ('PHONE CALL', 'Meat Market', 1),
#  ('PHONE CALL', 'Mobile Pre-Packaged', 39),
#  ('ROUTINE FOOD INSPECTION', 'Limited Menu', 217),
#  ('EMERGENCY RESPONSE', 'Bakery', 34),
#  ('PHONE CALL', 'Seasonal Venue -Fixed Location', 9),
#  ('ROUTINE FOOD INSPECTION', 'School', 641),
#  ('ROUTINE FOOD INSPECTION', 'Meat Market', 92),
#  ('PHONE CALL', 'Non School', 6),
#  ('PRE-OPENING FOOD INSPECTION', 'Bakery', 2),
#  ('MOBILE UNIT FOOD INSPECTION', 'School', 4),
#  ('MANAGERIAL ASSISTANCE', 'Food Service Establishment', 26),
#  ('New Business Inspection', 'Warehouse', 22),
#  ('FOLLOW-UP DOCUMENTATION RECEIVED', 'Retail - Meat/Seafood', 6),
#  ('ADDITIONAL SERVICE PROVIDED', 'Warehouse', 8),
#  ('FOLLOW-UP DOCUMENTATION RECEIVED', 'Retail - Self Service & Prepackage Foods', 1),
#  ('MOBILE UNIT FOOD INSPECTION', 'Seasonal Venue -Fixed Location', 2),
#  ('MOBILE UNIT FOOD INSPECTION', 'Mobile Pre-Packaged', 300),
#  ('EMERGENCY RESPONSE', 'Bar', 84),
#  ('PRE-OPENING FOOD INSPECTION', 'Mobile Food Unit', 32),
#  ('IMMINENT HEALTH HAZARD', 'Retail -Grocery', 4),
#  ('EMERGENCY RESPONSE', 'Mobile Food Unit', 31),
#  ('PRE-OPENING FOOD INSPECTION', 'Bar', 19),
#  ('MOBILE UNIT FOOD INSPECTION', 'Frozen Food Truck', 14),
#  ('ROUTINE FOOD INSPECTION', 'NOT FOR PROFIT KITCHEN PERMIT', 54),
#  ('PRE-OPENING FOOD INSPECTION', 'Retail - Meat/Seafood', 7),
#  ('MANAGERIAL ASSISTANCE', 'Warehouse', 4),
#  ('New Business Inspection', 'Food Service Establishment', 467),
#  ('EMERGENCY RESPONSE', 'Retail - Meat/Seafood', 20),
#  ('PHONE CALL', 'Retail - Prepackage Only', 23),
#  ('ADDITIONAL SERVICE PROVIDED', 'Food Service Establishment', 190),
#  ('EMERGENCY RESPONSE', 'Retail - Specialty Food Permit', 8),
#  ('EMERGENCY RESPONSE', 'Retail - Self Service & Prepackage Foods', 84),
#  ('IMMINENT HEALTH HAZARD', 'Retail - Deli', 2),
#  ('ADDITIONAL SERVICE PROVIDED', None, 2),
#  ('PRE-OPENING FOOD INSPECTION', 'Retail - Specialty Food Permit', 8),
#  ('ROUTINE FOOD INSPECTION', 'Retail - Prepackage Only', 594),
#  ('FOOD FOLLOW-UP INSPECTION', 'Food Service Establishment', 70),
#  ('PRE-OPENING FOOD INSPECTION', 'Retail - Self Service & Prepackage Foods', 107),
#  ('PHONE CALL', 'Retail - Self Service & Prepackage Foods', 2),
#  ('New Business Inspection', 'Retail -Grocery', 10),
#  ('ADDITIONAL SERVICE PROVIDED', 'Childcare', 7),
#  ('ROUTINE FOOD INSPECTION', 'Retail - Meat/Seafood', 249),
#  ('FOOD FOLLOW-UP INSPECTION', 'Retail -Grocery', 12),
#  ('ROUTINE FOOD INSPECTION', 'Retail - Specialty Food Permit', 83),
#  ('ROUTINE FOOD INSPECTION', 'Retail - Self Service & Prepackage Foods', 548),
#  ('New Business Inspection', 'Childcare', 14),
#  ('PRE-OPENING FOOD INSPECTION', 'Retail - Prepackage Only', 38),
#  ('MOBILE UNIT FOOD INSPECTION', 'Mobile Food Unit', 57),
#  ('PRE-OPENING FOOD INSPECTION', 'Frozen Food Truck', 23),
#  ('EMERGENCY RESPONSE', 'Retail - Prepackage Only', 101),
#  ('ADDITIONAL SERVICE PROVIDED', 'Retail -Grocery', 37),
#  ('ROUTINE FOOD INSPECTION', 'Bar', 672),
#  ('FOOD FOLLOW-UP INSPECTION', 'Retail - Deli', 11),
#  ('FOLLOW-UP DOCUMENTATION RECEIVED', 'Mobile Pre-Packaged', 1),
#  ('MANAGERIAL ASSISTANCE', 'Food Processor', 1),
#  ('ROUTINE FOOD INSPECTION', 'Mobile Food Unit', 82),
#  ('IMMINENT HEALTH HAZARD', 'Food Service Establishment', 24),
#  ('ADDITIONAL SERVICE PROVIDED', 'Institutional Kitchen', 7),
#  ('FOLLOW-UP DOCUMENTATION RECEIVED', 'Non School', 2),
#  ('ADDITIONAL SERVICE PROVIDED', 'Retail - Deli', 2),
#  ('PHONE CALL', 'Bar', 2),
#  ('EMERGENCY RESPONSE', 'NOT FOR PROFIT KITCHEN PERMIT', 13),
#  ('FOLLOW-UP DOCUMENTATION RECEIVED', 'Limited Menu', 2),
#  ('New Business Inspection', 'Institutional Kitchen', 2),
#  ('ROUTINE FOOD INSPECTION', 'Food/Drink Vending - Up to 15 Units', 6),
#  ('New Business Inspection', 'Retail - Deli', 2),
#  ('PHONE CALL', 'Mobile Food Unit', 58),
#  ('FOLLOW-UP DOCUMENTATION RECEIVED', 'Meat Market', 1),
#  ('PRE-OPENING FOOD INSPECTION', 'NOT FOR PROFIT KITCHEN PERMIT', 2),
#  ('FOLLOW-UP DOCUMENTATION RECEIVED', 'School', 5),
#  ('MANAGERIAL ASSISTANCE', 'Retail -Grocery', 1),
#  ('MANAGERIAL ASSISTANCE', 'Childcare', 5),
#  ('FOLLOW-UP DOCUMENTATION RECEIVED', 'Retail - Prepackage Only', 3),
#  ('EMERGENCY RESPONSE', 'Mobile Pre-Packaged', 11),
#  ('PRE-OPENING FOOD INSPECTION', 'Seasonal Venue -Fixed Location', 9),
#  ('PLAN REVIEW INSPECTION', 'Food Service Establishment', 2),
#  ('PRE-OPENING FOOD INSPECTION', 'Non School', 8),
#  ('PHONE CALL', 'Bakery', 1),
#  ('New Business Inspection', 'Food Processor', 31),
#  ('EMERGENCY RESPONSE', 'Seasonal Venue -Fixed Location', 6),
#  ('PRE-OPENING FOOD INSPECTION', 'Mobile Pre-Packaged', 69),
#  ('EMERGENCY RESPONSE', 'Non School', 50),
#  ('ADDITIONAL SERVICE PROVIDED', 'Food Processor', 10),
#  ('PRE-OPENING FOOD INSPECTION', 'School', 17),
#  ('MANAGERIAL ASSISTANCE', 'Institutional Kitchen', 3),
#  ('EMERGENCY RESPONSE', 'Limited Menu', 41),
#  ('MANAGERIAL ASSISTANCE', 'Retail - Deli', 1),
#  ('ROUTINE FOOD INSPECTION', 'Bakery', 294),
#  ('PRE-OPENING FOOD INSPECTION', 'Meat Market', 4),
#  ('EMERGENCY RESPONSE', 'School', 125),
#  ('EMERGENCY RESPONSE', 'Meat Market', 5),
#  ('FOOD FOLLOW-UP INSPECTION', 'Food Processor', 7),
#  ('PRE-OPENING FOOD INSPECTION', 'Limited Menu', 5)]

# %% [markdown]
# I'm curious to see if this subset has any correlation between violation type and location. For this, I can look at the 'violation_desc' and 'zipcode' variables. First, I want to see how many zip codes there are in this dataset.

# %%
# %%sql
# SELECT zipcode FROM abqfood
# GROUP BY zipcode
# Out:
# 48 rows affected.
# [('87197',),
#  ('87106',),
#  ('87187',),
#  ('87114',),
#  ('871147005',),
#  ('87107',),
#  ('871101922',),
#  ('871084174',),
#  ('87100',),
#  ('871104973',),
#  ('871147010',),
#  ('871087121',),
#  ('871094620',),
#  ('87120',),
#  ('87108',),
#  ('87111',),
#  ('87112',),
#  ('87104',),
#  ('87111-3146',),
#  ('87109',),
#  ('871221303',),
#  ('87158',),
#  ('871104546',),
#  ('871145010',),
#  ('87121',),
#  ('87123',),
#  ('87017',),
#  ('87102',),
#  ('871023114',),
#  ('87113',),
#  ('87116',),
#  ('87117',),
#  ('87101',),
#  ('871085004',),
#  ('87119',),
#  ('871084815',),
#  ('871124722',),
#  ('87110',),
#  ('87124',),
#  ('87122',),
#  ('87103',),
#  ('871131512',),
#  ('871222949',),
#  ('871118200',),
#  ('87105',),
#  ('871113971',),
#  ('871112648',),
#  ('87192',)]

# %% [markdown]
# Some of these zipcodes include detail beyond the first five digits. To make it easier to interpret data based on location, I want to remove the extra digits from some of these zipcodes so that I can sort the data only by the five-digit zip code classification.

# %% [markdown]
# ## Bonus (10 points)
#
# We have seen a few simple techniques for normalizing data in class.  Choose a column or set of columns that might be redundant and normalize them out to another table:
#
# * Identify the columns to normalize in the source data table
# * Create one or more new tables to hold the normalized records
# * Extract data into the new tables
# * Re-insert the new foreign key references from the new table into the source table
